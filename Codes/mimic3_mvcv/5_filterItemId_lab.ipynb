# %% [markdown]
# # Filter Itemid Lab
#
# This script is used for filtering itemids from TABLE LABEVENTS.
#
# 1. We check number of units of each itemid and choose the major unit as the target of unit conversion.
# 2. In this step we get 3 kinds of features:
#     - numerical features
#     - categorical features
#     - ratio features, this usually happens in blood pressure measurement, such as "135/70".
#
# ## Output
#
# 1. itemid of observations for labevents.
# 2. unit of measurement for each itemid.

# %%
from __future__ import print_function

import psycopg2
import datetime
import sys
from operator import itemgetter, attrgetter, methodcaller
import numpy as np
import itertools
import os.path
import matplotlib.pyplot as plt
import math
from multiprocessing import Pool, cpu_count

from utils import getConnection

# %matplotlib inline

# %%
conn = getConnection()
    
_adm = np.load('res/admission_ids.npy').tolist()
admission_ids = _adm['admission_ids']
admission_ids_txt = _adm['admission_ids_txt']

db = np.load('res/itemids.npy').tolist()
input_itemid = db['input']
output_itemid = db['output']
chart_itemid = db['chart']
lab_itemid = db['lab']
microbio_itemid = db['microbio']
prescript_itemid = db['prescript']

# %%
def stat_lab_unit_task(i, admission_ids_txt):
    conn = getConnection()
    cur = conn.cursor()
    cur.execute('SELECT coalesce(valueuom,\'\'), count(*) FROM mimiciii.labevents WHERE itemid = '+ str(i) +' and hadm_id in (select * from admission_ids) group by valueuom')
    outputunits = cur.fetchall()
    outputunits = sorted(outputunits, key=lambda tup: tup[1])
    outputunits.reverse()
    
    cur = conn.cursor()
    cur.execute('SELECT count(*) FROM mimiciii.labevents WHERE itemid = '+ str(i) +' and hadm_id in (select * from admission_ids) and valuenum is null')
    notnum = cur.fetchone()
    
    cur = conn.cursor()
    cur.execute('SELECT count(*) FROM mimiciii.labevents WHERE itemid = '+ str(i) +' and hadm_id in (select * from admission_ids) and valuenum is not null')
    total = cur.fetchone()
    
    return (i, outputunits, notnum, total)

p = Pool(cpu_count() * 2)
results = [p.apply_async(stat_lab_unit_task, args=(i, admission_ids_txt)) for i in lab_itemid]
results = [x.get() for x in results]
np.save('res/filtered_lab_raw.npy', {'raw': results})
print('saved!')
# Out:
# saved!

# %%
valid_lab = []
valid_lab_unit = []
dropped_id = []
multiple_units = []
results = np.load('res/filtered_lab_raw.npy').tolist()['raw']
for x in results:
    i, outputunits, notnum, total = x[0], x[1], x[2], x[3]
    totaltemp = 0
    unitnum = 0
    for o in outputunits:
        totaltemp += o[1]
        if o[0] is not '':
            unitnum += 1
    if(totaltemp == 0 ): 
        print("LAB "+str(i) + "\t 0 units")
        continue
    percentage = float(outputunits[0][1]) / totaltemp *100.
    
    print("LAB "+ str(i) + "\t" + "{:.2f}%".format(percentage) + "\t" + str(outputunits[0][1])+"/"+str(totaltemp)+" : "+ str(outputunits))
    if unitnum > 1:
        multiple_units.append((i, percentage, totaltemp, outputunits))
    
    percentage =float(total[0])*100 / (notnum[0]+total[0])
    print("LAB\t\t" + "{:.4f}".format(percentage)+ "\tNOTNUM=\t" + str(notnum[0]) + "\tNUM=\t" + str(total[0]))
    
    if(percentage < 95): 
        dropped_id.append(i);
        print('dropped\n')
        continue;
        
    print('')
    valid_lab.append(i);
    valid_lab_unit.append(outputunits[0][0])
# Out:
# LAB 51029	100.00%	9/9 : [('mg/dL', 9)]
# LAB		100.0000	NOTNUM=	0	NUM=	9
#
# LAB 50903	99.97%	6668/6670 : [('Ratio', 6668), ('', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	6670
#
# LAB 50800	100.00%	398697/398697 : [('', 398697)]
# LAB		0.0000	NOTNUM=	398697	NUM=	0
# dropped
#
# LAB 51438	100.00%	1176/1176 : [('#/uL', 1176)]
# LAB		99.8299	NOTNUM=	2	NUM=	1174
#
# LAB 51183	100.00%	165/165 : [('', 165)]
# LAB		0.0000	NOTNUM=	165	NUM=	0
# dropped
#
# LAB 51387	100.00%	71/71 : [('%', 71)]
# LAB		100.0000	NOTNUM=	0	NUM=	71
#
# LAB 51506	100.00%	66052/66052 : [('', 66052)]
# LAB		0.0000	NOTNUM=	66052	NUM=	0
# dropped
#
# LAB 50816	56.03%	71189/127046 : [('%', 71189), ('', 55857)]
# LAB		99.8898	NOTNUM=	140	NUM=	126906
#
# LAB 50935	90.80%	8491/9351 : [('mg/dL', 8491), ('MG/DL', 860)]
# LAB		86.5897	NOTNUM=	1254	NUM=	8097
# dropped
#
# LAB 51132	100.00%	482/482 : [('#/uL', 482)]
# LAB		100.0000	NOTNUM=	0	NUM=	482
#
# LAB 50868	100.00%	608346/608366 : [('mEq/L', 608346), ('', 20)]
# LAB		99.9988	NOTNUM=	7	NUM=	608359
#
# LAB 51337	100.00%	130/130 : [('', 130)]
# LAB		0.0000	NOTNUM=	130	NUM=	0
# dropped
#
# LAB 51379	100.00%	416/416 : [('%', 416)]
# LAB		100.0000	NOTNUM=	0	NUM=	416
#
# LAB 51307	100.00%	91/91 : [('', 91)]
# LAB		0.0000	NOTNUM=	91	NUM=	0
# dropped
#
# LAB 50832	62.50%	5/8 : [('mm Hg', 5), ('', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	8
#
# LAB 51105	68.65%	289/421 : [('mg/dL', 289), ('MG/DL', 132)]
# LAB		99.7625	NOTNUM=	1	NUM=	420
#
# LAB 51486	100.00%	64229/64229 : [('', 64229)]
# LAB		0.0016	NOTNUM=	64228	NUM=	1
# dropped
#
# LAB 51453	100.00%	517/517 : [('%', 517)]
# LAB		100.0000	NOTNUM=	0	NUM=	517
#
# LAB 51502	100.00%	20/20 : [('', 20)]
# LAB		0.0000	NOTNUM=	20	NUM=	0
# dropped
#
# LAB 51306	100.00%	58/58 : [('', 58)]
# LAB		0.0000	NOTNUM=	58	NUM=	0
# dropped
#
# LAB 51436	100.00%	1751/1751 : [('%', 1751)]
# LAB		99.8858	NOTNUM=	2	NUM=	1749
#
# LAB 51084	100.00%	56/56 : [('mg/dL', 56)]
# LAB		98.2143	NOTNUM=	1	NUM=	55
#
# LAB 51175	100.00%	17/17 : [('#/uL', 17)]
# LAB		100.0000	NOTNUM=	0	NUM=	17
#
# LAB 50874	100.00%	292/292 : [('', 292)]
# LAB		0.0000	NOTNUM=	292	NUM=	0
# dropped
#
# LAB 51075	100.00%	7076/7076 : [('', 7076)]
# LAB		0.0000	NOTNUM=	7076	NUM=	0
# dropped
#
# LAB 51053	100.00%	1835/1835 : [('mg/dL', 1835)]
# LAB		100.0000	NOTNUM=	0	NUM=	1835
#
# LAB 50954	100.00%	80083/80083 : [('IU/L', 80083)]
# LAB		99.9963	NOTNUM=	3	NUM=	80080
#
# LAB 51496	100.00%	26/26 : [('%', 26)]
# LAB		100.0000	NOTNUM=	0	NUM=	26
#
# LAB 51462	100.00%	5578/5578 : [('', 5578)]
# LAB		0.0000	NOTNUM=	5578	NUM=	0
# dropped
#
# LAB 51037	100.00%	8/8 : [('mg/dL', 8)]
# LAB		100.0000	NOTNUM=	0	NUM=	8
#
# LAB 50983	100.00%	641853/641873 : [('mEq/L', 641853), ('', 20)]
# LAB		99.9914	NOTNUM=	55	NUM=	641818
#
# LAB 50936	 0 units
# LAB 51282	100.00%	2/2 : [('/mm3', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	2
#
# LAB 51240	100.00%	4878/4878 : [('', 4878)]
# LAB		0.1025	NOTNUM=	4873	NUM=	5
# dropped
#
# LAB 51426	100.00%	368/368 : [('', 368)]
# LAB		0.0000	NOTNUM=	368	NUM=	0
# dropped
#
# LAB 51518	100.00%	1256/1256 : [('', 1256)]
# LAB		0.0796	NOTNUM=	1255	NUM=	1
# dropped
#
# LAB 51353	100.00%	36/36 : [('%', 36)]
# LAB		100.0000	NOTNUM=	0	NUM=	36
#
# LAB 51119	100.00%	6/6 : [('%', 6)]
# LAB		100.0000	NOTNUM=	0	NUM=	6
#
# LAB 51155	100.00%	57/57 : [('', 57)]
# LAB		0.0000	NOTNUM=	57	NUM=	0
# dropped
#
# LAB 50864	93.21%	783/840 : [('ng/mL', 783), ('nG/ML', 57)]
# LAB		94.6429	NOTNUM=	45	NUM=	795
# dropped
#
# LAB 51468	100.00%	6/6 : [('', 6)]
# LAB		0.0000	NOTNUM=	6	NUM=	0
# dropped
#
# LAB 51157	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 50853	100.00%	74/74 : [('ng/mL', 74)]
# LAB		100.0000	NOTNUM=	0	NUM=	74
#
# LAB 51466	81.71%	53882/65945 : [('', 53882), ('mg/dL', 12063)]
# LAB		0.0000	NOTNUM=	65945	NUM=	0
# dropped
#
# LAB 51209	100.00%	29/29 : [('%', 29)]
# LAB		96.5517	NOTNUM=	1	NUM=	28
#
# LAB 51124	100.00%	51/51 : [('%', 51)]
# LAB		100.0000	NOTNUM=	0	NUM=	51
#
# LAB 50998	100.00%	10902/10902 : [('mg/dL', 10902)]
# LAB		99.6423	NOTNUM=	39	NUM=	10863
#
# LAB 51146	99.99%	109471/109478 : [('%', 109471), ('', 7)]
# LAB		99.9872	NOTNUM=	14	NUM=	109464
#
# LAB 51381	100.00%	22/22 : [('%', 22)]
# LAB		100.0000	NOTNUM=	0	NUM=	22
#
# LAB 51010	100.00%	6574/6574 : [('pg/mL', 6574)]
# LAB		95.1628	NOTNUM=	318	NUM=	6256
#
# LAB 51366	100.00%	27/27 : [('%', 27)]
# LAB		100.0000	NOTNUM=	0	NUM=	27
#
# LAB 51383	100.00%	373/373 : [('#/uL', 373)]
# LAB		100.0000	NOTNUM=	0	NUM=	373
#
# LAB 50968	99.88%	863/864 : [('ug/mL', 863), ('', 1)]
# LAB		93.2870	NOTNUM=	58	NUM=	806
# dropped
#
# LAB 51110	100.00%	127/127 : [('%', 127)]
# LAB		100.0000	NOTNUM=	0	NUM=	127
#
# LAB 51212	100.00%	11/11 : [('%', 11)]
# LAB		100.0000	NOTNUM=	0	NUM=	11
#
# LAB 51327	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 51363	100.00%	3695/3695 : [('#/uL', 3695)]
# LAB		100.0000	NOTNUM=	0	NUM=	3695
#
# LAB 50957	100.00%	661/661 : [('mmol/L', 661)]
# LAB		90.7716	NOTNUM=	61	NUM=	600
# dropped
#
# LAB 51131	100.00%	569/569 : [('#/uL', 569)]
# LAB		100.0000	NOTNUM=	0	NUM=	569
#
# LAB 51236	100.00%	594/594 : [('', 594)]
# LAB		0.0000	NOTNUM=	594	NUM=	0
# dropped
#
# LAB 51407	100.00%	11/11 : [('', 11)]
# LAB		0.0000	NOTNUM=	11	NUM=	0
# dropped
#
# LAB 51036	100.00%	11/11 : [('U/L', 11)]
# LAB		100.0000	NOTNUM=	0	NUM=	11
#
# LAB 51102	100.00%	3476/3476 : [('mg/dL', 3476)]
# LAB		96.0299	NOTNUM=	138	NUM=	3338
#
# LAB 51230	100.00%	140/140 : [('', 140)]
# LAB		0.0000	NOTNUM=	140	NUM=	0
# dropped
#
# LAB 50924	93.14%	9963/10697 : [('ng/mL', 9963), ('ng/ml', 734)]
# LAB		94.1666	NOTNUM=	624	NUM=	10073
# dropped
#
# LAB 51280	100.00%	18/18 : [('sec', 18)]
# LAB		94.4444	NOTNUM=	1	NUM=	17
# dropped
#
# LAB 51531	 0 units
# LAB 51433	100.00%	43/43 : [('%', 43)]
# LAB		100.0000	NOTNUM=	0	NUM=	43
#
# LAB 50942	100.00%	1645/1645 : [('', 1645)]
# LAB		0.0000	NOTNUM=	1645	NUM=	0
# dropped
#
# LAB 51031	100.00%	5/5 : [('mg/dL', 5)]
# LAB		100.0000	NOTNUM=	0	NUM=	5
#
# LAB 51234	100.00%	173/173 : [('', 173)]
# LAB		0.0000	NOTNUM=	173	NUM=	0
# dropped
#
# LAB 50801	72.89%	15877/21783 : [('mm Hg', 15877), ('', 5906)]
# LAB		99.9908	NOTNUM=	2	NUM=	21781
#
# LAB 51458	100.00%	2138/2138 : [('#/uL', 2138)]
# LAB		100.0000	NOTNUM=	0	NUM=	2138
#
# LAB 50803	100.00%	8434/8434 : [('mEq/L', 8434)]
# LAB		99.9526	NOTNUM=	4	NUM=	8430
#
# LAB 51489	100.00%	134/134 : [('#/hpf', 134)]
# LAB		44.0299	NOTNUM=	75	NUM=	59
# dropped
#
# LAB 50896	95.06%	327/344 : [('ug/dL', 327), ('uG/DL', 17)]
# LAB		100.0000	NOTNUM=	0	NUM=	344
#
# LAB 51133	100.00%	603/603 : [('#/uL', 603)]
# LAB		100.0000	NOTNUM=	0	NUM=	603
#
# LAB 50939	100.00%	548/548 : [('', 548)]
# LAB		0.0000	NOTNUM=	548	NUM=	0
# dropped
#
# LAB 50829	100.00%	262/262 : [('', 262)]
# LAB		0.0000	NOTNUM=	262	NUM=	0
# dropped
#
# LAB 51073	100.00%	43/43 : [('Ratio', 43)]
# LAB		100.0000	NOTNUM=	0	NUM=	43
#
# LAB 51286	100.00%	8/8 : [('', 8)]
# LAB		0.0000	NOTNUM=	8	NUM=	0
# dropped
#
# LAB 51048	100.00%	6/6 : [('mEq/L', 6)]
# LAB		100.0000	NOTNUM=	0	NUM=	6
#
# LAB 50901	100.00%	19/19 : [('', 19)]
# LAB		0.0000	NOTNUM=	19	NUM=	0
# dropped
#
# LAB 50906	100.00%	543/543 : [('mg/dL', 543)]
# LAB		87.2928	NOTNUM=	69	NUM=	474
# dropped
#
# LAB 51097	99.99%	10002/10003 : [('mEq/L', 10002), ('', 1)]
# LAB		99.3202	NOTNUM=	68	NUM=	9935
#
# LAB 51331	100.00%	52/52 : [('', 52)]
# LAB		0.0000	NOTNUM=	52	NUM=	0
# dropped
#
# LAB 51405	100.00%	23/23 : [('', 23)]
# LAB		0.0000	NOTNUM=	23	NUM=	0
# dropped
#
# LAB 51233	100.00%	37846/37846 : [('', 37846)]
# LAB		0.0026	NOTNUM=	37845	NUM=	1
# dropped
#
# LAB 50815	100.00%	11934/11934 : [('L/min', 11934)]
# LAB		100.0000	NOTNUM=	0	NUM=	11934
#
# LAB 51372	100.00%	156/156 : [('', 156)]
# LAB		0.0000	NOTNUM=	156	NUM=	0
# dropped
#
# LAB 50852	100.00%	7143/7143 : [('%', 7143)]
# LAB		99.9860	NOTNUM=	1	NUM=	7142
#
# LAB 51011	100.00%	22/22 : [('mg/dL', 22)]
# LAB		90.9091	NOTNUM=	2	NUM=	20
# dropped
#
# LAB 51517	100.00%	236/236 : [('#/lpf', 236)]
# LAB		22.8814	NOTNUM=	182	NUM=	54
# dropped
#
# LAB 51092	100.00%	7046/7046 : [('', 7046)]
# LAB		0.0000	NOTNUM=	7046	NUM=	0
# dropped
#
# LAB 51077	100.00%	694/694 : [('mg/dL', 694)]
# LAB		98.4150	NOTNUM=	11	NUM=	683
#
# LAB 51045	100.00%	55/55 : [('mg/dL', 55)]
# LAB		100.0000	NOTNUM=	0	NUM=	55
#
# LAB 51309	100.00%	59/59 : [('', 59)]
# LAB		0.0000	NOTNUM=	59	NUM=	0
# dropped
#
# LAB 51304	100.00%	3/3 : [('', 3)]
# LAB		0.0000	NOTNUM=	3	NUM=	0
# dropped
#
# LAB 51442	100.00%	92/92 : [('%', 92)]
# LAB		100.0000	NOTNUM=	0	NUM=	92
#
# LAB 51130	100.00%	500/500 : [('#/uL', 500)]
# LAB		100.0000	NOTNUM=	0	NUM=	500
#
# LAB 51315	100.00%	124/124 : [('', 124)]
# LAB		0.0000	NOTNUM=	124	NUM=	0
# dropped
#
# LAB 51519	100.00%	62074/62074 : [('', 62074)]
# LAB		0.0789	NOTNUM=	62025	NUM=	49
# dropped
#
# LAB 50937	57.17%	542/948 : [('Pos/Neg', 542), ('', 406)]
# LAB		0.0000	NOTNUM=	948	NUM=	0
# dropped
#
# LAB 51085	100.00%	383/383 : [('+/-', 383)]
# LAB		0.0000	NOTNUM=	383	NUM=	0
# dropped
#
# LAB 51412	100.00%	258/258 : [('', 258)]
# LAB		0.0000	NOTNUM=	258	NUM=	0
# dropped
#
# LAB 51065	100.00%	82/82 : [('mEq/L', 82)]
# LAB		95.1220	NOTNUM=	4	NUM=	78
#
# LAB 51255	100.00%	45208/45210 : [('%', 45208), ('', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	45210
#
# LAB 51006	100.00%	617264/617284 : [('mg/dL', 617264), ('', 20)]
# LAB		99.9953	NOTNUM=	29	NUM=	617255
#
# LAB 51425	100.00%	368/368 : [('', 368)]
# LAB		0.0000	NOTNUM=	368	NUM=	0
# dropped
#
# LAB 50830	89.47%	34/38 : [('mm Hg', 34), ('', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	38
#
# LAB 50931	100.00%	595616/595635 : [('mg/dL', 595616), ('', 19)]
# LAB		99.9935	NOTNUM=	39	NUM=	595596
#
# LAB 51027	100.00%	46/46 : [('mEq/L', 46)]
# LAB		91.3043	NOTNUM=	4	NUM=	42
# dropped
#
# LAB 51268	100.00%	31235/31235 : [('', 31235)]
# LAB		0.0000	NOTNUM=	31235	NUM=	0
# dropped
#
# LAB 51439	100.00%	1325/1325 : [('#/uL', 1325)]
# LAB		99.8491	NOTNUM=	2	NUM=	1323
#
# LAB 50854	100.00%	1172/1172 : [('', 1172)]
# LAB		0.0853	NOTNUM=	1171	NUM=	1
# dropped
#
# LAB 51192	100.00%	113/113 : [('', 113)]
# LAB		0.0000	NOTNUM=	113	NUM=	0
# dropped
#
# LAB 50959	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51100	100.00%	21883/21884 : [('mEq/L', 21883), ('', 1)]
# LAB		90.6553	NOTNUM=	2045	NUM=	19839
# dropped
#
# LAB 50842	100.00%	941/941 : [('mg/dL', 941)]
# LAB		99.7875	NOTNUM=	2	NUM=	939
#
# LAB 51300	100.00%	598/598 : [('K/uL', 598)]
# LAB		100.0000	NOTNUM=	0	NUM=	598
#
# LAB 50965	100.00%	1697/1697 : [('pg/mL', 1697)]
# LAB		98.2322	NOTNUM=	30	NUM=	1667
#
# LAB 51156	100.00%	64/64 : [('', 64)]
# LAB		0.0000	NOTNUM=	64	NUM=	0
# dropped
#
# LAB 51487	100.00%	65904/65904 : [('', 65904)]
# LAB		0.0000	NOTNUM=	65904	NUM=	0
# dropped
#
# LAB 51293	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51218	100.00%	9126/9126 : [('#/uL', 9126)]
# LAB		99.9562	NOTNUM=	4	NUM=	9122
#
# LAB 51344	100.00%	229/229 : [('%', 229)]
# LAB		100.0000	NOTNUM=	0	NUM=	229
#
# LAB 50848	100.00%	52/52 : [('mEq/L', 52)]
# LAB		100.0000	NOTNUM=	0	NUM=	52
#
# LAB 50932	100.00%	79/79 : [('', 79)]
# LAB		0.0000	NOTNUM=	79	NUM=	0
# dropped
#
# LAB 51416	100.00%	180/180 : [('', 180)]
# LAB		0.0000	NOTNUM=	180	NUM=	0
# dropped
#
# LAB 51314	100.00%	100/100 : [('', 100)]
# LAB		0.0000	NOTNUM=	100	NUM=	0
# dropped
#
# LAB 50969	99.88%	803/804 : [('%', 803), ('', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	804
#
# LAB 51277	100.00%	572351/572369 : [('%', 572351), ('', 18)]
# LAB		99.9465	NOTNUM=	306	NUM=	572063
#
# LAB 50856	100.00%	6816/6816 : [('ug/mL', 6816)]
# LAB		13.4830	NOTNUM=	5897	NUM=	919
# dropped
#
# LAB 51050	100.00%	10/10 : [('mEq/L', 10)]
# LAB		100.0000	NOTNUM=	0	NUM=	10
#
# LAB 51463	100.00%	50019/50019 : [('', 50019)]
# LAB		1.5414	NOTNUM=	49248	NUM=	771
# dropped
#
# LAB 50886	100.00%	118/118 : [('', 118)]
# LAB		0.0000	NOTNUM=	118	NUM=	0
# dropped
#
# LAB 51411	100.00%	463/463 : [('', 463)]
# LAB		0.0000	NOTNUM=	463	NUM=	0
# dropped
#
# LAB 51332	100.00%	104/104 : [('', 104)]
# LAB		0.0000	NOTNUM=	104	NUM=	0
# dropped
#
# LAB 51252	100.00%	35848/35848 : [('', 35848)]
# LAB		0.0000	NOTNUM=	35848	NUM=	0
# dropped
#
# LAB 51003	86.29%	57280/66384 : [('ng/mL', 57280), ('ng/ml', 9104)]
# LAB		77.8305	NOTNUM=	14717	NUM=	51667
# dropped
#
# LAB 50949	100.00%	1257/1257 : [('mg/dL', 1257)]
# LAB		98.8862	NOTNUM=	14	NUM=	1243
#
# LAB 51063	100.00%	58/58 : [('mOsm/kg', 58)]
# LAB		98.2759	NOTNUM=	1	NUM=	57
#
# LAB 51126	100.00%	1/1 : [('%', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 50880	100.00%	9103/9103 : [('', 9103)]
# LAB		0.0000	NOTNUM=	9103	NUM=	0
# dropped
#
# LAB 50929	100.00%	5897/5897 : [('ug/mL', 5897)]
# LAB		93.8782	NOTNUM=	361	NUM=	5536
# dropped
#
# LAB 50966	100.00%	1493/1493 : [('ug/mL', 1493)]
# LAB		95.1105	NOTNUM=	73	NUM=	1420
#
# LAB 51393	100.00%	18/18 : [('', 18)]
# LAB		0.0000	NOTNUM=	18	NUM=	0
# dropped
#
# LAB 51302	100.00%	88/88 : [('%', 88)]
# LAB		100.0000	NOTNUM=	0	NUM=	88
#
# LAB 51021	100.00%	5/5 : [('mg/dL', 5)]
# LAB		100.0000	NOTNUM=	0	NUM=	5
#
# LAB 51208	100.00%	45/45 : [('%', 45)]
# LAB		100.0000	NOTNUM=	0	NUM=	45
#
# LAB 51140	100.00%	225/225 : [('%', 225)]
# LAB		100.0000	NOTNUM=	0	NUM=	225
#
# LAB 51224	100.00%	110/110 : [('%', 110)]
# LAB		100.0000	NOTNUM=	0	NUM=	110
#
# LAB 51154	100.00%	54/54 : [('', 54)]
# LAB		0.0000	NOTNUM=	54	NUM=	0
# dropped
#
# LAB 51161	100.00%	10/10 : [('', 10)]
# LAB		0.0000	NOTNUM=	10	NUM=	0
# dropped
#
# LAB 51413	100.00%	29/29 : [('', 29)]
# LAB		0.0000	NOTNUM=	29	NUM=	0
# dropped
#
# LAB 51272	100.00%	52/52 : [('%', 52)]
# LAB		100.0000	NOTNUM=	0	NUM=	52
#
# LAB 51088	100.00%	382/382 : [('mg/dL', 382)]
# LAB		99.7382	NOTNUM=	1	NUM=	381
#
# LAB 51421	100.00%	9/9 : [('', 9)]
# LAB		0.0000	NOTNUM=	9	NUM=	0
# dropped
#
# LAB 51414	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 50843	100.00%	1010/1010 : [('IU/L', 1010)]
# LAB		99.8020	NOTNUM=	2	NUM=	1008
#
# LAB 51184	100.00%	165/165 : [('', 165)]
# LAB		13.3333	NOTNUM=	143	NUM=	22
# dropped
#
# LAB 51342	100.00%	249/249 : [('', 249)]
# LAB		0.0000	NOTNUM=	249	NUM=	0
# dropped
#
# LAB 51202	100.00%	27/27 : [('%', 27)]
# LAB		100.0000	NOTNUM=	0	NUM=	27
#
# LAB 50861	100.00%	148479/148480 : [('IU/L', 148479), ('', 1)]
# LAB		99.9825	NOTNUM=	26	NUM=	148454
#
# LAB 51182	100.00%	52/52 : [('', 52)]
# LAB		0.0000	NOTNUM=	52	NUM=	0
# dropped
#
# LAB 51188	100.00%	64/64 : [('', 64)]
# LAB		4.6875	NOTNUM=	61	NUM=	3
# dropped
#
# LAB 51033	 0 units
# LAB 51318	100.00%	3/3 : [('', 3)]
# LAB		0.0000	NOTNUM=	3	NUM=	0
# dropped
#
# LAB 51525	 0 units
# LAB 51249	100.00%	573491/573509 : [('%', 573491), ('', 18)]
# LAB		99.9730	NOTNUM=	155	NUM=	573354
#
# LAB 51041	100.00%	74/74 : [('mEq/L', 74)]
# LAB		91.8919	NOTNUM=	6	NUM=	68
# dropped
#
# LAB 51360	100.00%	3688/3688 : [('%', 3688)]
# LAB		100.0000	NOTNUM=	0	NUM=	3688
#
# LAB 51289	100.00%	63/63 : [(' ', 63)]
# LAB		100.0000	NOTNUM=	0	NUM=	63
#
# LAB 51396	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51330	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 51333	100.00%	47/47 : [('', 47)]
# LAB		0.0000	NOTNUM=	47	NUM=	0
# dropped
#
# LAB 51169	100.00%	4/4 : [('%', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 51099	100.00%	2896/2896 : [('Ratio', 2896)]
# LAB		100.0000	NOTNUM=	0	NUM=	2896
#
# LAB 51427	100.00%	1751/1751 : [('%', 1751)]
# LAB		99.8858	NOTNUM=	2	NUM=	1749
#
# LAB 51074	100.00%	7043/7043 : [('', 7043)]
# LAB		0.0000	NOTNUM=	7043	NUM=	0
# dropped
#
# LAB 50840	100.00%	6/6 : [('mg/dL', 6)]
# LAB		100.0000	NOTNUM=	0	NUM=	6
#
# LAB 50890	100.00%	810/810 : [('mg/dL', 810)]
# LAB		99.5062	NOTNUM=	4	NUM=	806
#
# LAB 51066	100.00%	16/16 : [('mg/24hr', 16)]
# LAB		100.0000	NOTNUM=	0	NUM=	16
#
# LAB 51189	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51187	100.00%	23/23 : [('', 23)]
# LAB		0.0000	NOTNUM=	23	NUM=	0
# dropped
#
# LAB 51238	100.00%	148/148 : [('', 148)]
# LAB		0.0000	NOTNUM=	148	NUM=	0
# dropped
#
# LAB 51090	100.00%	7022/7022 : [('', 7022)]
# LAB		0.0000	NOTNUM=	7022	NUM=	0
# dropped
#
# LAB 51537	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 51180	100.00%	658/658 : [('%', 658)]
# LAB		86.3222	NOTNUM=	90	NUM=	568
# dropped
#
# LAB 51297	100.00%	471/471 : [('sec', 471)]
# LAB		100.0000	NOTNUM=	0	NUM=	471
#
# LAB 51058	100.00%	15/15 : [('mEq/L', 15)]
# LAB		100.0000	NOTNUM=	0	NUM=	15
#
# LAB 51113	100.00%	2/2 : [('%', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	2
#
# LAB 51478	99.99%	67502/67506 : [('mg/dL', 67502), ('', 4)]
# LAB		11.3353	NOTNUM=	59854	NUM=	7652
# dropped
#
# LAB 51216	100.00%	1210/1210 : [('', 1210)]
# LAB		0.0000	NOTNUM=	1210	NUM=	0
# dropped
#
# LAB 51555	 0 units
# LAB 51452	100.00%	56/56 : [('%', 56)]
# LAB		100.0000	NOTNUM=	0	NUM=	56
#
# LAB 51226	100.00%	110/110 : [('%', 110)]
# LAB		100.0000	NOTNUM=	0	NUM=	110
#
# LAB 50877	80.95%	68/84 : [('IU/mL', 68), ('', 16)]
# LAB		13.0952	NOTNUM=	73	NUM=	11
# dropped
#
# LAB 50988	100.00%	44/44 : [('ng/dL', 44)]
# LAB		100.0000	NOTNUM=	0	NUM=	44
#
# LAB 51323	100.00%	61/61 : [('', 61)]
# LAB		0.0000	NOTNUM=	61	NUM=	0
# dropped
#
# LAB 51329	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51457	100.00%	1999/1999 : [('#/uL', 1999)]
# LAB		100.0000	NOTNUM=	0	NUM=	1999
#
# LAB 51178	100.00%	65/65 : [('%', 65)]
# LAB		0.0000	NOTNUM=	65	NUM=	0
# dropped
#
# LAB 51477	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 51437	100.00%	3/3 : [('%', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	3
#
# LAB 51449	100.00%	9/9 : [('%', 9)]
# LAB		100.0000	NOTNUM=	0	NUM=	9
#
# LAB 50846	100.00%	2/2 : [('mOsm/kg', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	2
#
# LAB 50995	88.89%	3280/3690 : [('ng/dL', 3280), ('ng/dl', 408), ('', 2)]
# LAB		99.0786	NOTNUM=	34	NUM=	3656
#
# LAB 51227	100.00%	110/110 : [('%', 110)]
# LAB		100.0000	NOTNUM=	0	NUM=	110
#
# LAB 50989	86.96%	20/23 : [('pg/mL', 20), ('ng/dL', 3)]
# LAB		69.5652	NOTNUM=	7	NUM=	16
# dropped
#
# LAB 51499	100.00%	270/270 : [('', 270)]
# LAB		0.0000	NOTNUM=	270	NUM=	0
# dropped
#
# LAB 51179	100.00%	8/8 : [('', 8)]
# LAB		0.0000	NOTNUM=	8	NUM=	0
# dropped
#
# LAB 50973	92.63%	176/190 : [('ng/mL', 176), ('nG/mL', 14)]
# LAB		98.4211	NOTNUM=	3	NUM=	187
#
# LAB 51465	100.00%	65/65 : [('', 65)]
# LAB		0.0000	NOTNUM=	65	NUM=	0
# dropped
#
# LAB 50851	100.00%	14/14 : [('mg/dL', 14)]
# LAB		100.0000	NOTNUM=	0	NUM=	14
#
# LAB 51044	100.00%	53/53 : [('mg/dL', 53)]
# LAB		100.0000	NOTNUM=	0	NUM=	53
#
# LAB 51321	100.00%	99/99 : [('', 99)]
# LAB		0.0000	NOTNUM=	99	NUM=	0
# dropped
#
# LAB 51448	100.00%	1243/1243 : [('%', 1243)]
# LAB		100.0000	NOTNUM=	0	NUM=	1243
#
# LAB 51076	73.00%	619/848 : [('mEq/L', 619), ('', 229)]
# LAB		12.0283	NOTNUM=	746	NUM=	102
# dropped
#
# LAB 50902	100.00%	631658/631678 : [('mEq/L', 631658), ('', 20)]
# LAB		99.9915	NOTNUM=	54	NUM=	631624
#
# LAB 51143	100.00%	45263/45265 : [('%', 45263), ('', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	45265
#
# LAB 51473	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 51533	 0 units
# LAB 50964	93.11%	16472/17690 : [('mOsm/kg', 16472), ('MOSM/KG', 741), ('MOSM/L', 477)]
# LAB		99.9943	NOTNUM=	1	NUM=	17689
#
# LAB 51500	100.00%	9/9 : [('', 9)]
# LAB		0.0000	NOTNUM=	9	NUM=	0
# dropped
#
# LAB 50810	100.00%	86676/86677 : [('%', 86676), ('', 1)]
# LAB		99.9977	NOTNUM=	2	NUM=	86675
#
# LAB 51215	100.00%	93/93 : [('', 93)]
# LAB		0.0000	NOTNUM=	93	NUM=	0
# dropped
#
# LAB 51064	100.00%	83/83 : [('mEq/L', 83)]
# LAB		91.5663	NOTNUM=	7	NUM=	76
# dropped
#
# LAB 50882	100.00%	618598/618618 : [('mEq/L', 618598), ('', 20)]
# LAB		99.9704	NOTNUM=	183	NUM=	618435
#
# LAB 50867	100.00%	49246/49246 : [('IU/L', 49246)]
# LAB		99.9878	NOTNUM=	6	NUM=	49240
#
# LAB 51456	100.00%	5/5 : [('%', 5)]
# LAB		100.0000	NOTNUM=	0	NUM=	5
#
# LAB 51040	100.00%	9/9 : [('mg/dL', 9)]
# LAB		100.0000	NOTNUM=	0	NUM=	9
#
# LAB 50818	95.88%	465561/485552 : [('mm Hg', 465561), ('MM HG', 19971), ('', 20)]
# LAB		99.9825	NOTNUM=	85	NUM=	485467
#
# LAB 51347	100.00%	569/569 : [('%', 569)]
# LAB		100.0000	NOTNUM=	0	NUM=	569
#
# LAB 51020	100.00%	10/10 : [('IU/L', 10)]
# LAB		100.0000	NOTNUM=	0	NUM=	10
#
# LAB 50921	100.00%	10/10 : [('pg/mL', 10)]
# LAB		90.0000	NOTNUM=	1	NUM=	9
# dropped
#
# LAB 51039	100.00%	11/11 : [('mOsm/kg', 11)]
# LAB		100.0000	NOTNUM=	0	NUM=	11
#
# LAB 50938	100.00%	579/579 : [('', 579)]
# LAB		0.0000	NOTNUM=	579	NUM=	0
# dropped
#
# LAB 51068	98.23%	111/113 : [('mg/24hr', 111), ('mg/24hours', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	113
#
# LAB 50835	100.00%	1183/1183 : [('g/dL', 1183)]
# LAB		53.4235	NOTNUM=	551	NUM=	632
# dropped
#
# LAB 51221	100.00%	693767/693788 : [('%', 693767), ('', 21)]
# LAB		99.9906	NOTNUM=	65	NUM=	693723
#
# LAB 50879	100.00%	9051/9051 : [('', 9051)]
# LAB		0.0000	NOTNUM=	9051	NUM=	0
# dropped
#
# LAB 51420	100.00%	214/214 : [('', 214)]
# LAB		0.0000	NOTNUM=	214	NUM=	0
# dropped
#
# LAB 51056	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51173	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51128	88.72%	2218/2500 : [('#/uL', 2218), ('#/CU MM', 282)]
# LAB		100.0000	NOTNUM=	0	NUM=	2500
#
# LAB 51385	100.00%	56/56 : [('%', 56)]
# LAB		100.0000	NOTNUM=	0	NUM=	56
#
# LAB 50910	100.00%	101644/101648 : [('IU/L', 101644), ('', 4)]
# LAB		99.9921	NOTNUM=	8	NUM=	101640
#
# LAB 51535	 0 units
# LAB 51194	100.00%	570/570 : [('%', 570)]
# LAB		84.3860	NOTNUM=	89	NUM=	481
# dropped
#
# LAB 50827	100.00%	76995/76995 : [('', 76995)]
# LAB		0.0000	NOTNUM=	76995	NUM=	0
# dropped
#
# LAB 50809	100.00%	193250/193253 : [('mg/dL', 193250), ('', 3)]
# LAB		99.9384	NOTNUM=	119	NUM=	193134
#
# LAB 50999	100.00%	9028/9028 : [('', 9028)]
# LAB		0.0000	NOTNUM=	9028	NUM=	0
# dropped
#
# LAB 50967	100.00%	19868/19868 : [('ug/mL', 19868)]
# LAB		97.8458	NOTNUM=	428	NUM=	19440
#
# LAB 50914	100.00%	4809/4809 : [('ng/mL', 4809)]
# LAB		98.1701	NOTNUM=	88	NUM=	4721
#
# LAB 51034	100.00%	432/432 : [('mg/dL', 432)]
# LAB		100.0000	NOTNUM=	0	NUM=	432
#
# LAB 51400	100.00%	256/256 : [('', 256)]
# LAB		0.0000	NOTNUM=	256	NUM=	0
# dropped
#
# LAB 51042	100.00%	79/79 : [('mEq/L', 79)]
# LAB		98.7342	NOTNUM=	1	NUM=	78
#
# LAB 51529	100.00%	15/15 : [('mg/dL', 15)]
# LAB		100.0000	NOTNUM=	0	NUM=	15
#
# LAB 50991	100.00%	50/50 : [('ng/mL', 50)]
# LAB		86.0000	NOTNUM=	7	NUM=	43
# dropped
#
# LAB 51325	100.00%	174/174 : [('', 174)]
# LAB		0.0000	NOTNUM=	174	NUM=	0
# dropped
#
# LAB 50953	100.00%	10863/10863 : [('ug/dL', 10863)]
# LAB		100.0000	NOTNUM=	0	NUM=	10863
#
# LAB 51312	100.00%	10/10 : [('', 10)]
# LAB		0.0000	NOTNUM=	10	NUM=	0
# dropped
#
# LAB 51354	100.00%	26/26 : [('%', 26)]
# LAB		100.0000	NOTNUM=	0	NUM=	26
#
# LAB 51163	100.00%	9/9 : [('%', 9)]
# LAB		100.0000	NOTNUM=	0	NUM=	9
#
# LAB 50819	100.00%	86685/86685 : [('', 86685)]
# LAB		100.0000	NOTNUM=	0	NUM=	86685
#
# LAB 51091	100.00%	267/267 : [('', 267)]
# LAB		0.0000	NOTNUM=	267	NUM=	0
# dropped
#
# LAB 51291	100.00%	40/40 : [('', 40)]
# LAB		0.0000	NOTNUM=	40	NUM=	0
# dropped
#
# LAB 50806	100.00%	46037/46038 : [('mEq/L', 46037), ('', 1)]
# LAB		99.9826	NOTNUM=	8	NUM=	46030
#
# LAB 51112	100.00%	56/56 : [('%', 56)]
# LAB		100.0000	NOTNUM=	0	NUM=	56
#
# LAB 51258	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51115	100.00%	153/153 : [('%', 153)]
# LAB		90.8497	NOTNUM=	14	NUM=	139
# dropped
#
# LAB 51373	100.00%	365/365 : [('', 365)]
# LAB		0.0000	NOTNUM=	365	NUM=	0
# dropped
#
# LAB 51507	100.00%	140/140 : [('#/lpf', 140)]
# LAB		72.1429	NOTNUM=	39	NUM=	101
# dropped
#
# LAB 51474	100.00%	2568/2568 : [('', 2568)]
# LAB		0.0000	NOTNUM=	2568	NUM=	0
# dropped
#
# LAB 51106	100.00%	66/66 : [('mg/dL', 66)]
# LAB		100.0000	NOTNUM=	0	NUM=	66
#
# LAB 51023	100.00%	8/8 : [('IU/L', 8)]
# LAB		100.0000	NOTNUM=	0	NUM=	8
#
# LAB 51482	100.00%	12341/12341 : [('#/lpf', 12341)]
# LAB		59.0714	NOTNUM=	5051	NUM=	7290
# dropped
#
# LAB 51298	100.00%	86/86 : [('%', 86)]
# LAB		100.0000	NOTNUM=	0	NUM=	86
#
# LAB 51247	100.00%	57/57 : [('', 57)]
# LAB		0.0000	NOTNUM=	57	NUM=	0
# dropped
#
# LAB 50978	100.00%	1098/1098 : [('ng/mL', 1098)]
# LAB		98.9071	NOTNUM=	12	NUM=	1086
#
# LAB 50926	75.86%	66/87 : [('mIU/mL', 66), ('mIU/L', 21)]
# LAB		85.0575	NOTNUM=	13	NUM=	74
# dropped
#
# LAB 51441	100.00%	109/109 : [('%', 109)]
# LAB		100.0000	NOTNUM=	0	NUM=	109
#
# LAB 51356	100.00%	10/10 : [('%', 10)]
# LAB		100.0000	NOTNUM=	0	NUM=	10
#
# LAB 50883	100.00%	35870/35870 : [('mg/dL', 35870)]
# LAB		99.9052	NOTNUM=	34	NUM=	35836
#
# LAB 50955	100.00%	2316/2316 : [('', 2316)]
# LAB		0.0000	NOTNUM=	2316	NUM=	0
# dropped
#
# LAB 51375	100.00%	416/416 : [('%', 416)]
# LAB		100.0000	NOTNUM=	0	NUM=	416
#
# LAB 51345	100.00%	109/109 : [('%', 109)]
# LAB		100.0000	NOTNUM=	0	NUM=	109
#
# LAB 51526	 0 units
# LAB 50933	100.00%	13110/13110 : [('', 13110)]
# LAB		0.0000	NOTNUM=	13110	NUM=	0
# dropped
#
# LAB 51368	100.00%	34/34 : [('%', 34)]
# LAB		100.0000	NOTNUM=	0	NUM=	34
#
# LAB 50912	100.00%	619602/619622 : [('mg/dL', 619602), ('', 20)]
# LAB		99.9798	NOTNUM=	125	NUM=	619497
#
# LAB 51239	100.00%	147/147 : [('', 147)]
# LAB		0.0000	NOTNUM=	147	NUM=	0
# dropped
#
# LAB 51005	94.86%	332/350 : [('Ratio', 332), ('RATIO', 18)]
# LAB		99.7143	NOTNUM=	1	NUM=	349
#
# LAB 51165	100.00%	4/4 : [('%', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 51349	100.00%	1/1 : [('%', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 51536	 0 units
# LAB 51071	100.00%	7055/7055 : [('', 7055)]
# LAB		0.0000	NOTNUM=	7055	NUM=	0
# dropped
#
# LAB 51079	100.00%	7104/7104 : [('', 7104)]
# LAB		0.0000	NOTNUM=	7104	NUM=	0
# dropped
#
# LAB 51114	100.00%	418/418 : [('%', 418)]
# LAB		100.0000	NOTNUM=	0	NUM=	418
#
# LAB 51428	100.00%	975/975 : [('%', 975)]
# LAB		100.0000	NOTNUM=	0	NUM=	975
#
# LAB 51408	100.00%	54/54 : [('', 54)]
# LAB		1.8519	NOTNUM=	53	NUM=	1
# dropped
#
# LAB 51078	99.99%	8834/8835 : [('mEq/L', 8834), ('', 1)]
# LAB		96.0498	NOTNUM=	349	NUM=	8486
#
# LAB 51199	100.00%	149/149 : [('#/uL', 149)]
# LAB		100.0000	NOTNUM=	0	NUM=	149
#
# LAB 51435	100.00%	7/7 : [('%', 7)]
# LAB		100.0000	NOTNUM=	0	NUM=	7
#
# LAB 51516	99.99%	61280/61284 : [('#/hpf', 61280), ('', 4)]
# LAB		48.9230	NOTNUM=	31302	NUM=	29982
# dropped
#
# LAB 50963	99.90%	4857/4862 : [('pg/mL', 4857), ('', 5)]
# LAB		98.0255	NOTNUM=	96	NUM=	4766
#
# LAB 50946	100.00%	432/432 : [('mIU/mL', 432)]
# LAB		18.5185	NOTNUM=	352	NUM=	80
# dropped
#
# LAB 51158	100.00%	59/59 : [('', 59)]
# LAB		0.0000	NOTNUM=	59	NUM=	0
# dropped
#
# LAB 51281	100.00%	18/18 : [('sec', 18)]
# LAB		88.8889	NOTNUM=	2	NUM=	16
# dropped
#
# LAB 51359	100.00%	16/16 : [('%', 16)]
# LAB		100.0000	NOTNUM=	0	NUM=	16
#
# LAB 51270	100.00%	34/34 : [('%', 34)]
# LAB		100.0000	NOTNUM=	0	NUM=	34
#
# LAB 51055	100.00%	1/1 : [('U/L', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 51069	100.00%	480/480 : [('mg/dL', 480)]
# LAB		94.5833	NOTNUM=	26	NUM=	454
# dropped
#
# LAB 51122	100.00%	41/41 : [('%', 41)]
# LAB		100.0000	NOTNUM=	0	NUM=	41
#
# LAB 51228	100.00%	175/175 : [('U/mL', 175)]
# LAB		86.8571	NOTNUM=	23	NUM=	152
# dropped
#
# LAB 51470	100.00%	16/16 : [('', 16)]
# LAB		0.0000	NOTNUM=	16	NUM=	0
# dropped
#
# LAB 50956	100.00%	51163/51163 : [('IU/L', 51163)]
# LAB		99.9805	NOTNUM=	10	NUM=	51153
#
# LAB 50820	95.56%	501298/524600 : [('units', 501298), ('UNITS', 23277), ('', 25)]
# LAB		99.9828	NOTNUM=	90	NUM=	524510
#
# LAB 51479	100.00%	5758/5758 : [('#/lpf', 5758)]
# LAB		42.1327	NOTNUM=	3332	NUM=	2426
# dropped
#
# LAB 50996	96.39%	160/166 : [('units', 160), ('', 6)]
# LAB		95.1807	NOTNUM=	8	NUM=	158
#
# LAB 51287	100.00%	7242/7242 : [('', 7242)]
# LAB		0.0000	NOTNUM=	7242	NUM=	0
# dropped
#
# LAB 51232	100.00%	206/206 : [('%', 206)]
# LAB		100.0000	NOTNUM=	0	NUM=	206
#
# LAB 51197	100.00%	833/833 : [('', 833)]
# LAB		0.0000	NOTNUM=	833	NUM=	0
# dropped
#
# LAB 51350	100.00%	13/13 : [('', 13)]
# LAB		0.0000	NOTNUM=	13	NUM=	0
# dropped
#
# LAB 51174	100.00%	17/17 : [('%', 17)]
# LAB		100.0000	NOTNUM=	0	NUM=	17
#
# LAB 51523	100.00%	6403/6403 : [('', 6403)]
# LAB		0.0000	NOTNUM=	6403	NUM=	0
# dropped
#
# LAB 51278	100.00%	2024/2024 : [('', 2024)]
# LAB		0.0000	NOTNUM=	2024	NUM=	0
# dropped
#
# LAB 51520	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 50917	100.00%	6449/6449 : [('ng/mL', 6449)]
# LAB		97.7826	NOTNUM=	143	NUM=	6306
#
# LAB 51002	99.96%	8913/8917 : [('ng/ml', 8913), ('', 4)]
# LAB		52.4167	NOTNUM=	4243	NUM=	4674
# dropped
#
# LAB 51259	100.00%	1342/1342 : [('%', 1342)]
# LAB		100.0000	NOTNUM=	0	NUM=	1342
#
# LAB 51284	100.00%	1794/1794 : [('%', 1794)]
# LAB		99.8885	NOTNUM=	2	NUM=	1792
#
# LAB 50960	100.00%	559502/559517 : [('mg/dL', 559502), ('', 15)]
# LAB		99.9941	NOTNUM=	33	NUM=	559484
#
# LAB 51054	100.00%	2033/2033 : [('IU/L', 2033)]
# LAB		100.0000	NOTNUM=	0	NUM=	2033
#
# LAB 50990	54.45%	104/191 : [('ug/ml', 104), ('ug/mL', 87)]
# LAB		80.1047	NOTNUM=	38	NUM=	153
# dropped
#
# LAB 51220	100.00%	28/28 : [('', 28)]
# LAB		0.0000	NOTNUM=	28	NUM=	0
# dropped
#
# LAB 50908	100.00%	21234/21235 : [('%', 21234), ('', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	21235
#
# LAB 51339	100.00%	145/145 : [('', 145)]
# LAB		0.0000	NOTNUM=	145	NUM=	0
# dropped
#
# LAB 50869	100.00%	7/7 : [('units', 7)]
# LAB		100.0000	NOTNUM=	0	NUM=	7
#
# LAB 51490	100.00%	10/10 : [('', 10)]
# LAB		0.0000	NOTNUM=	10	NUM=	0
# dropped
#
# LAB 51265	100.00%	598950/598968 : [('K/uL', 598950), ('', 18)]
# LAB		99.9785	NOTNUM=	129	NUM=	598839
#
# LAB 51512	100.00%	9515/9515 : [('', 9515)]
# LAB		0.0315	NOTNUM=	9512	NUM=	3
# dropped
#
# LAB 51460	100.00%	132/132 : [('', 132)]
# LAB		0.0000	NOTNUM=	132	NUM=	0
# dropped
#
# LAB 51121	100.00%	3/3 : [('%', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	3
#
# LAB 50922	100.00%	6746/6746 : [('mg/dL', 6746)]
# LAB		26.4305	NOTNUM=	4963	NUM=	1783
# dropped
#
# LAB 50873	100.00%	1155/1155 : [('', 1155)]
# LAB		0.0000	NOTNUM=	1155	NUM=	0
# dropped
#
# LAB 50881	100.00%	124/124 : [('mg/L', 124)]
# LAB		100.0000	NOTNUM=	0	NUM=	124
#
# LAB 51515	100.00%	93/93 : [('#/lpf', 93)]
# LAB		23.6559	NOTNUM=	71	NUM=	22
# dropped
#
# LAB 50899	100.00%	469/469 : [('ug/mL', 469)]
# LAB		89.7655	NOTNUM=	48	NUM=	421
# dropped
#
# LAB 51271	100.00%	246/246 : [('%', 246)]
# LAB		100.0000	NOTNUM=	0	NUM=	246
#
# LAB 51391	100.00%	20/20 : [('', 20)]
# LAB		0.0000	NOTNUM=	20	NUM=	0
# dropped
#
# LAB 51237	100.00%	378568/378568 : [('', 378568)]
# LAB		99.9374	NOTNUM=	237	NUM=	378331
#
# LAB 51032	100.00%	255/255 : [('mg/dL', 255)]
# LAB		100.0000	NOTNUM=	0	NUM=	255
#
# LAB 51467	100.00%	24/24 : [('#/lpf', 24)]
# LAB		95.8333	NOTNUM=	1	NUM=	23
#
# LAB 50826	100.00%	83298/83298 : [('', 83298)]
# LAB		100.0000	NOTNUM=	0	NUM=	83298
#
# LAB 51511	100.00%	30/30 : [('', 30)]
# LAB		0.0000	NOTNUM=	30	NUM=	0
# dropped
#
# LAB 51257	100.00%	14441/14441 : [('%', 14441)]
# LAB		99.9862	NOTNUM=	2	NUM=	14439
#
# LAB 50930	100.00%	1843/1843 : [('g/dL', 1843)]
# LAB		100.0000	NOTNUM=	0	NUM=	1843
#
# LAB 51443	100.00%	3/3 : [('%', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	3
#
# LAB 51135	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 50825	100.00%	128699/128699 : [('', 128699)]
# LAB		99.8803	NOTNUM=	154	NUM=	128545
#
# LAB 50893	100.00%	484694/484701 : [('mg/dL', 484694), ('', 7)]
# LAB		99.9950	NOTNUM=	24	NUM=	484677
#
# LAB 51273	100.00%	127/127 : [('%', 127)]
# LAB		100.0000	NOTNUM=	0	NUM=	127
#
# LAB 51513	100.00%	838/838 : [('', 838)]
# LAB		0.5967	NOTNUM=	833	NUM=	5
# dropped
#
# LAB 51035	100.00%	394/394 : [('IU/L', 394)]
# LAB		99.4924	NOTNUM=	2	NUM=	392
#
# LAB 51004	 0 units
# LAB 51308	100.00%	3/3 : [('', 3)]
# LAB		0.0000	NOTNUM=	3	NUM=	0
# dropped
#
# LAB 50894	100.00%	5/5 : [('pg/mL', 5)]
# LAB		100.0000	NOTNUM=	0	NUM=	5
#
# LAB 51009	99.98%	47877/47886 : [('ug/mL', 47877), ('', 9)]
# LAB		99.3255	NOTNUM=	323	NUM=	47563
#
# LAB 51007	99.99%	11387/11388 : [('mg/dL', 11387), ('', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	11388
#
# LAB 50871	100.00%	232/232 : [('', 232)]
# LAB		0.0000	NOTNUM=	232	NUM=	0
# dropped
#
# LAB 51025	100.00%	390/390 : [('g/dL', 390)]
# LAB		92.0513	NOTNUM=	31	NUM=	359
# dropped
#
# LAB 51380	100.00%	11/11 : [('%', 11)]
# LAB		100.0000	NOTNUM=	0	NUM=	11
#
# LAB 51488	100.00%	13/13 : [('#/hpf', 13)]
# LAB		53.8462	NOTNUM=	6	NUM=	7
# dropped
#
# LAB 51370	100.00%	156/156 : [('', 156)]
# LAB		0.0000	NOTNUM=	156	NUM=	0
# dropped
#
# LAB 50821	95.88%	465595/485586 : [('mm Hg', 465595), ('MM HG', 19971), ('', 20)]
# LAB		99.9794	NOTNUM=	100	NUM=	485486
#
# LAB 51171	100.00%	6/6 : [('', 6)]
# LAB		0.0000	NOTNUM=	6	NUM=	0
# dropped
#
# LAB 51181	100.00%	482/482 : [('Ratio', 482)]
# LAB		100.0000	NOTNUM=	0	NUM=	482
#
# LAB 50920	100.00%	24626/24626 : [('', 24626)]
# LAB		0.0000	NOTNUM=	24626	NUM=	0
# dropped
#
# LAB 51316	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 50889	83.34%	2931/3517 : [('mg/L', 2931), ('mg/dL', 565), ('MG/DL', 19), ('', 2)]
# LAB		95.3369	NOTNUM=	164	NUM=	3353
#
# LAB 51406	73.39%	91/124 : [('#/uL', 91), ('', 33)]
# LAB		38.7097	NOTNUM=	76	NUM=	48
# dropped
#
# LAB 50947	100.00%	4/4 : [('U', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 50958	76.32%	58/76 : [('mIU/mL', 58), ('mIU/L', 18)]
# LAB		65.7895	NOTNUM=	26	NUM=	50
# dropped
#
# LAB 51067	96.41%	322/334 : [('mg/24hr', 322), ('mg/24hours', 12)]
# LAB		100.0000	NOTNUM=	0	NUM=	334
#
# LAB 51172	100.00%	92/92 : [('', 92)]
# LAB		0.0000	NOTNUM=	92	NUM=	0
# dropped
#
# LAB 51394	100.00%	14/14 : [('', 14)]
# LAB		0.0000	NOTNUM=	14	NUM=	0
# dropped
#
# LAB 51444	100.00%	593/593 : [('%', 593)]
# LAB		100.0000	NOTNUM=	0	NUM=	593
#
# LAB 51086	100.00%	421/421 : [('', 421)]
# LAB		0.0000	NOTNUM=	421	NUM=	0
# dropped
#
# LAB 50916	81.82%	9/11 : [('ug/dL', 9), ('nG/mL', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	11
#
# LAB 50834	100.00%	1/1 : [('mEq/L', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 50847	100.00%	43/43 : [('mEq/L', 43)]
# LAB		100.0000	NOTNUM=	0	NUM=	43
#
# LAB 50813	100.00%	178043/178044 : [('mmol/L', 178043), ('', 1)]
# LAB		99.9517	NOTNUM=	86	NUM=	177958
#
# LAB 51000	85.67%	11588/13526 : [('mg/dL', 11588), ('MG/DL', 1936), ('', 2)]
# LAB		99.9926	NOTNUM=	1	NUM=	13525
#
# LAB 51429	100.00%	414/414 : [('%', 414)]
# LAB		100.0000	NOTNUM=	0	NUM=	414
#
# LAB 51222	100.00%	577032/577050 : [('g/dL', 577032), ('', 18)]
# LAB		99.9816	NOTNUM=	106	NUM=	576944
#
# LAB 51070	100.00%	453/453 : [('mg/g', 453)]
# LAB		100.0000	NOTNUM=	0	NUM=	453
#
# LAB 51299	100.00%	83/83 : [('%', 83)]
# LAB		72.2892	NOTNUM=	23	NUM=	60
# dropped
#
# LAB 50828	100.00%	59806/59806 : [('', 59806)]
# LAB		0.0000	NOTNUM=	59806	NUM=	0
# dropped
#
# LAB 51125	100.00%	2499/2499 : [('%', 2499)]
# LAB		100.0000	NOTNUM=	0	NUM=	2499
#
# LAB 51399	100.00%	180/180 : [('', 180)]
# LAB		0.0000	NOTNUM=	180	NUM=	0
# dropped
#
# LAB 51193	100.00%	50/50 : [('', 50)]
# LAB		0.0000	NOTNUM=	50	NUM=	0
# dropped
#
# LAB 51445	100.00%	228/228 : [('%', 228)]
# LAB		93.8596	NOTNUM=	14	NUM=	214
# dropped
#
# LAB 51109	100.00%	66/66 : [('mL', 66)]
# LAB		100.0000	NOTNUM=	0	NUM=	66
#
# LAB 51104	100.00%	11416/11416 : [('mg/dL', 11416)]
# LAB		99.9912	NOTNUM=	1	NUM=	11415
#
# LAB 50865	100.00%	137/137 : [('ug/mL', 137)]
# LAB		100.0000	NOTNUM=	0	NUM=	137
#
# LAB 51046	100.00%	962/962 : [('g/dL', 962)]
# LAB		77.3389	NOTNUM=	218	NUM=	744
# dropped
#
# LAB 51019	100.00%	1/1 : [('g/dL', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 51225	100.00%	35/35 : [('%', 35)]
# LAB		60.0000	NOTNUM=	14	NUM=	21
# dropped
#
# LAB 51210	100.00%	10/10 : [('%', 10)]
# LAB		100.0000	NOTNUM=	0	NUM=	10
#
# LAB 50863	100.00%	146257/146258 : [('IU/L', 146257), ('', 1)]
# LAB		99.9966	NOTNUM=	5	NUM=	146253
#
# LAB 51120	100.00%	2499/2499 : [('%', 2499)]
# LAB		100.0000	NOTNUM=	0	NUM=	2499
#
# LAB 51335	100.00%	75/75 : [('', 75)]
# LAB		0.0000	NOTNUM=	75	NUM=	0
# dropped
#
# LAB 51081	100.00%	66/66 : [('mg/dL', 66)]
# LAB		100.0000	NOTNUM=	0	NUM=	66
# LAB 51098	74.78%	605/809 : [('+/-', 605), ('', 204)]
# LAB		0.1236	NOTNUM=	808	NUM=	1
# dropped
#
# LAB 51248	100.00%	573354/573372 : [('pg', 573354), ('', 18)]
# LAB		99.9438	NOTNUM=	322	NUM=	573050
#
# LAB 51301	100.00%	577702/577720 : [('K/uL', 577702), ('', 18)]
# LAB		99.9505	NOTNUM=	286	NUM=	577434
#
# LAB 51402	100.00%	215/215 : [('', 215)]
# LAB		0.0000	NOTNUM=	215	NUM=	0
# dropped
#
# LAB 51303	100.00%	125/125 : [('', 125)]
# LAB		0.0000	NOTNUM=	125	NUM=	0
# dropped
#
# LAB 50824	100.00%	69025/69026 : [('mEq/L', 69025), ('', 1)]
# LAB		99.9855	NOTNUM=	10	NUM=	69016
#
# LAB 50948	100.00%	381/381 : [('', 381)]
# LAB		0.0000	NOTNUM=	381	NUM=	0
# dropped
#
# LAB 51534	 0 units
# LAB 51176	100.00%	670/670 : [('%', 670)]
# LAB		77.7612	NOTNUM=	149	NUM=	521
# dropped
#
# LAB 50855	100.00%	1172/1172 : [('', 1172)]
# LAB		0.0853	NOTNUM=	1171	NUM=	1
# dropped
#
# LAB 51095	100.00%	884/884 : [('mg/dL', 884)]
# LAB		96.0407	NOTNUM=	35	NUM=	849
#
# LAB 51311	100.00%	3/3 : [('', 3)]
# LAB		0.0000	NOTNUM=	3	NUM=	0
# dropped
#
# LAB 51392	100.00%	37/37 : [('', 37)]
# LAB		0.0000	NOTNUM=	37	NUM=	0
# dropped
#
# LAB 51361	100.00%	3/3 : [('%', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	3
#
# LAB 50833	50.00%	1/2 : [('mEq/L', 1), ('', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	2
#
# LAB 50919	100.00%	4962/4962 : [('', 4962)]
# LAB		0.0000	NOTNUM=	4962	NUM=	0
# dropped
#
# LAB 50892	100.00%	175/175 : [('U/mL', 175)]
# LAB		99.4286	NOTNUM=	1	NUM=	174
#
# LAB 50839	100.00%	40/40 : [('mEq/L', 40)]
# LAB		100.0000	NOTNUM=	0	NUM=	40
#
# LAB 51168	100.00%	171/171 : [('', 171)]
# LAB		8.1871	NOTNUM=	157	NUM=	14
# dropped
#
# LAB 51319	100.00%	130/130 : [('', 130)]
# LAB		0.0000	NOTNUM=	130	NUM=	0
# dropped
#
# LAB 51229	100.00%	429/429 : [('U/mL', 429)]
# LAB		85.7809	NOTNUM=	61	NUM=	368
# dropped
#
# LAB 51326	100.00%	124/124 : [('', 124)]
# LAB		0.0000	NOTNUM=	124	NUM=	0
# dropped
#
# LAB 51292	100.00%	2016/2016 : [('', 2016)]
# LAB		0.0000	NOTNUM=	2016	NUM=	0
# dropped
#
# LAB 51403	100.00%	5/5 : [('', 5)]
# LAB		0.0000	NOTNUM=	5	NUM=	0
# dropped
#
# LAB 51219	100.00%	101/101 : [('', 101)]
# LAB		0.0000	NOTNUM=	101	NUM=	0
# dropped
#
# LAB 51334	100.00%	59/59 : [('', 59)]
# LAB		0.0000	NOTNUM=	59	NUM=	0
# dropped
#
# LAB 51384	100.00%	416/416 : [('#/uL', 416)]
# LAB		100.0000	NOTNUM=	0	NUM=	416
#
# LAB 51263	100.00%	305/305 : [('%', 305)]
# LAB		100.0000	NOTNUM=	0	NUM=	305
#
# LAB 51204	100.00%	47/47 : [('%', 47)]
# LAB		100.0000	NOTNUM=	0	NUM=	47
#
# LAB 51422	100.00%	279/279 : [('%', 279)]
# LAB		93.9068	NOTNUM=	17	NUM=	262
# dropped
#
# LAB 51528	 0 units
# LAB 50895	100.00%	350/350 : [('Ratio', 350)]
# LAB		99.7143	NOTNUM=	1	NUM=	349
#
# LAB 51343	100.00%	269/269 : [('%', 269)]
# LAB		100.0000	NOTNUM=	0	NUM=	269
#
# LAB 51242	100.00%	2/2 : [('%', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51185	100.00%	8/8 : [('%', 8)]
# LAB		100.0000	NOTNUM=	0	NUM=	8
#
# LAB 51376	100.00%	140/140 : [('%', 140)]
# LAB		100.0000	NOTNUM=	0	NUM=	140
#
# LAB 50884	100.00%	35166/35166 : [('mg/dL', 35166)]
# LAB		99.9801	NOTNUM=	7	NUM=	35159
#
# LAB 50994	90.12%	1997/2216 : [('ug/dL', 1997), ('uG/DL', 219)]
# LAB		99.6841	NOTNUM=	7	NUM=	2209
#
# LAB 51159	100.00%	54/54 : [('', 54)]
# LAB		0.0000	NOTNUM=	54	NUM=	0
# dropped
#
# LAB 51404	100.00%	308/308 : [('', 308)]
# LAB		14.9351	NOTNUM=	262	NUM=	46
# dropped
#
# LAB 51256	99.99%	109476/109483 : [('%', 109476), ('', 7)]
# LAB		99.9872	NOTNUM=	14	NUM=	109469
#
# LAB 51295	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51260	100.00%	9761/9761 : [('', 9761)]
# LAB		0.0000	NOTNUM=	9761	NUM=	0
# dropped
#
# LAB 51294	100.00%	4294/4294 : [('', 4294)]
# LAB		0.0000	NOTNUM=	4294	NUM=	0
# dropped
#
# LAB 51152	100.00%	144/144 : [('', 144)]
# LAB		0.6944	NOTNUM=	143	NUM=	1
# dropped
#
# LAB 50909	99.88%	12302/12317 : [('ug/dL', 12302), ('', 15)]
# LAB		99.7970	NOTNUM=	25	NUM=	12292
#
# LAB 51266	100.00%	30161/30161 : [('', 30161)]
# LAB		0.0000	NOTNUM=	30161	NUM=	0
# dropped
#
# LAB 51164	100.00%	183/183 : [('', 183)]
# LAB		14.2077	NOTNUM=	157	NUM=	26
# dropped
#
# LAB 50802	100.00%	485586/485606 : [('mEq/L', 485586), ('', 20)]
# LAB		99.9759	NOTNUM=	117	NUM=	485489
#
# LAB 51129	100.00%	1/1 : [('%', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 50943	100.00%	2106/2106 : [('', 2106)]
# LAB		0.0000	NOTNUM=	2106	NUM=	0
# dropped
#
# LAB 51362	100.00%	3647/3647 : [('#/uL', 3647)]
# LAB		100.0000	NOTNUM=	0	NUM=	3647
#
# LAB 51186	100.00%	8/8 : [('#/uL', 8)]
# LAB		100.0000	NOTNUM=	0	NUM=	8
#
# LAB 51147	100.00%	964/964 : [('', 964)]
# LAB		0.0000	NOTNUM=	964	NUM=	0
# dropped
#
# LAB 50913	100.00%	197/197 : [('', 197)]
# LAB		0.0000	NOTNUM=	197	NUM=	0
# dropped
#
# LAB 51223	100.00%	41/41 : [('%', 41)]
# LAB		100.0000	NOTNUM=	0	NUM=	41
#
# LAB 50934	100.00%	4/4 : [('U', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 51365	100.00%	11/11 : [('%', 11)]
# LAB		100.0000	NOTNUM=	0	NUM=	11
#
# LAB 50860	 0 units
# LAB 50904	99.97%	6715/6717 : [('mg/dL', 6715), ('', 2)]
# LAB		99.9702	NOTNUM=	2	NUM=	6715
#
# LAB 51231	100.00%	463/463 : [('', 463)]
# LAB		0.0000	NOTNUM=	463	NUM=	0
# dropped
#
# LAB 51103	100.00%	1822/1822 : [('', 1822)]
# LAB		0.0000	NOTNUM=	1822	NUM=	0
# dropped
#
# LAB 51348	100.00%	56/56 : [('%', 56)]
# LAB		100.0000	NOTNUM=	0	NUM=	56
#
# LAB 51276	100.00%	153/153 : [('U/g/Hb', 153)]
# LAB		100.0000	NOTNUM=	0	NUM=	153
#
# LAB 50822	100.00%	187018/187020 : [('mEq/L', 187018), ('', 2)]
# LAB		99.9717	NOTNUM=	53	NUM=	186967
#
# LAB 51495	100.00%	32/32 : [('', 32)]
# LAB		0.0000	NOTNUM=	32	NUM=	0
# dropped
#
# LAB 51504	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51493	99.99%	60879/60883 : [('#/hpf', 60879), ('', 4)]
# LAB		48.6376	NOTNUM=	31271	NUM=	29612
# dropped
#
# LAB 50981	100.00%	6385/6385 : [('mg/dL', 6385)]
# LAB		5.4033	NOTNUM=	6040	NUM=	345
# dropped
#
# LAB 51355	100.00%	3692/3692 : [('%', 3692)]
# LAB		100.0000	NOTNUM=	0	NUM=	3692
#
# LAB 51022	100.00%	32/32 : [('mg/dL', 32)]
# LAB		96.8750	NOTNUM=	1	NUM=	31
#
# LAB 51481	100.00%	108/108 : [('', 108)]
# LAB		0.0000	NOTNUM=	108	NUM=	0
# dropped
#
# LAB 51472	100.00%	4/4 : [('', 4)]
# LAB		0.0000	NOTNUM=	4	NUM=	0
# dropped
#
# LAB 51492	99.99%	72628/72632 : [('mg/dL', 72628), ('', 4)]
# LAB		38.7722	NOTNUM=	44471	NUM=	28161
# dropped
#
# LAB 51207	100.00%	32/32 : [('', 32)]
# LAB		0.0000	NOTNUM=	32	NUM=	0
# dropped
#
# LAB 51262	100.00%	150/150 : [('', 150)]
# LAB		0.0000	NOTNUM=	150	NUM=	0
# dropped
#
# LAB 50900	100.00%	700/700 : [('ng/mL', 700)]
# LAB		95.2857	NOTNUM=	33	NUM=	667
#
# LAB 51177	100.00%	59/59 : [('', 59)]
# LAB		0.0000	NOTNUM=	59	NUM=	0
# dropped
#
# LAB 50836	100.00%	893/893 : [('IU/L', 893)]
# LAB		98.5442	NOTNUM=	13	NUM=	880
#
# LAB 51480	100.00%	4/4 : [('%', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 50974	90.12%	456/506 : [('ng/mL', 456), ('ug/L', 50)]
# LAB		90.1186	NOTNUM=	50	NUM=	456
# dropped
#
# LAB 50992	100.00%	67/67 : [('IU/mL', 67)]
# LAB		53.7313	NOTNUM=	31	NUM=	36
# dropped
#
# LAB 51062	100.00%	51/51 : [('mEq/L', 51)]
# LAB		94.1176	NOTNUM=	3	NUM=	48
# dropped
#
# LAB 51245	100.00%	603/603 : [('%', 603)]
# LAB		100.0000	NOTNUM=	0	NUM=	603
#
# LAB 51211	100.00%	8/8 : [('%', 8)]
# LAB		0.0000	NOTNUM=	8	NUM=	0
# dropped
#
# LAB 51093	99.99%	16191/16192 : [('mOsm/kg', 16191), ('', 1)]
# LAB		99.9815	NOTNUM=	3	NUM=	16189
#
# LAB 51052	100.00%	247/247 : [('mg/dL', 247)]
# LAB		99.5951	NOTNUM=	1	NUM=	246
#
# LAB 51461	100.00%	17/17 : [('', 17)]
# LAB		0.0000	NOTNUM=	17	NUM=	0
# dropped
#
# LAB 50862	100.00%	99002/99005 : [('g/dL', 99002), ('', 3)]
# LAB		99.9657	NOTNUM=	34	NUM=	98971
#
# LAB 51269	100.00%	1834/1834 : [('%', 1834)]
# LAB		100.0000	NOTNUM=	0	NUM=	1834
#
# LAB 51264	100.00%	395/395 : [('', 395)]
# LAB		0.2532	NOTNUM=	394	NUM=	1
# dropped
#
# LAB 51357	100.00%	132/132 : [('%', 132)]
# LAB		100.0000	NOTNUM=	0	NUM=	132
#
# LAB 51340	100.00%	128/128 : [('', 128)]
# LAB		0.0000	NOTNUM=	128	NUM=	0
# dropped
#
# LAB 50986	100.00%	11130/11130 : [('ng/mL', 11130)]
# LAB		98.4996	NOTNUM=	167	NUM=	10963
#
# LAB 51196	94.44%	3380/3579 : [('ng/mL', 3380), ('', 199)]
# LAB		60.7991	NOTNUM=	1403	NUM=	2176
# dropped
#
# LAB 51250	100.00%	573351/573369 : [('fL', 573351), ('', 18)]
# LAB		99.9431	NOTNUM=	326	NUM=	573043
#
# LAB 50925	100.00%	4981/4981 : [('ng/mL', 4981)]
# LAB		85.5049	NOTNUM=	722	NUM=	4259
# dropped
#
# LAB 51305	100.00%	75/75 : [('', 75)]
# LAB		0.0000	NOTNUM=	75	NUM=	0
# dropped
#
# LAB 51138	100.00%	368/368 : [('GPL', 368)]
# LAB		97.8261	NOTNUM=	8	NUM=	360
#
# LAB 50977	100.00%	7/7 : [('ug/mL', 7)]
# LAB		100.0000	NOTNUM=	0	NUM=	7
#
# LAB 51491	100.00%	82285/82289 : [('units', 82285), ('', 4)]
# LAB		99.9635	NOTNUM=	30	NUM=	82259
#
# LAB 50905	99.97%	6328/6330 : [('mg/dL', 6328), ('', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	6330
#
# LAB 51018	100.00%	3378/3378 : [('mg/dL', 3378)]
# LAB		99.4967	NOTNUM=	17	NUM=	3361
#
# LAB 51364	100.00%	6/6 : [('%', 6)]
# LAB		100.0000	NOTNUM=	0	NUM=	6
#
# LAB 50997	100.00%	1238/1238 : [('ug/mL', 1238)]
# LAB		98.2229	NOTNUM=	22	NUM=	1216
#
# LAB 51190	100.00%	23/23 : [('', 23)]
# LAB		0.0000	NOTNUM=	23	NUM=	0
# dropped
#
# LAB 51503	100.00%	202/202 : [('', 202)]
# LAB		0.0000	NOTNUM=	202	NUM=	0
# dropped
#
# LAB 51127	88.43%	2156/2438 : [('#/uL', 2156), ('#/CU MM', 282)]
# LAB		100.0000	NOTNUM=	0	NUM=	2438
#
# LAB 51310	100.00%	73/73 : [('', 73)]
# LAB		0.0000	NOTNUM=	73	NUM=	0
# dropped
#
# LAB 51251	100.00%	45248/45250 : [('%', 45248), ('', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	45250
#
# LAB 51296	100.00%	5336/5336 : [('', 5336)]
# LAB		0.0000	NOTNUM=	5336	NUM=	0
# dropped
#
# LAB 50950	100.00%	1564/1564 : [('mg/dL', 1564)]
# LAB		100.0000	NOTNUM=	0	NUM=	1564
#
# LAB 51430	100.00%	12/12 : [('%', 12)]
# LAB		100.0000	NOTNUM=	0	NUM=	12
#
# LAB 51060	100.00%	226/226 : [('mg/dL', 226)]
# LAB		100.0000	NOTNUM=	0	NUM=	226
#
# LAB 51096	100.00%	18/18 : [('+/-', 18)]
# LAB		0.0000	NOTNUM=	18	NUM=	0
# dropped
#
# LAB 51446	100.00%	2137/2137 : [('%', 2137)]
# LAB		100.0000	NOTNUM=	0	NUM=	2137
#
# LAB 50915	100.00%	978/978 : [('ng/mL', 978)]
# LAB		93.6605	NOTNUM=	62	NUM=	916
# dropped
#
# LAB 51401	100.00%	5/5 : [('', 5)]
# LAB		0.0000	NOTNUM=	5	NUM=	0
# dropped
#
# LAB 51328	100.00%	53/53 : [('', 53)]
# LAB		0.0000	NOTNUM=	53	NUM=	0
# dropped
#
# LAB 51469	100.00%	825/825 : [('', 825)]
# LAB		0.0000	NOTNUM=	825	NUM=	0
# dropped
#
# LAB 51386	100.00%	106/106 : [('%', 106)]
# LAB		100.0000	NOTNUM=	0	NUM=	106
#
# LAB 51142	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51061	100.00%	37/37 : [('mEq/L', 37)]
# LAB		72.9730	NOTNUM=	10	NUM=	27
# dropped
#
# LAB 51134	100.00%	1819/1819 : [('', 1819)]
# LAB		0.0000	NOTNUM=	1819	NUM=	0
# dropped
#
# LAB 51235	100.00%	123/123 : [('', 123)]
# LAB		0.0000	NOTNUM=	123	NUM=	0
# dropped
#
# LAB 51317	100.00%	75/75 : [('', 75)]
# LAB		0.0000	NOTNUM=	75	NUM=	0
# dropped
#
# LAB 51313	100.00%	142/142 : [('', 142)]
# LAB		0.0000	NOTNUM=	142	NUM=	0
# dropped
#
# LAB 50918	100.00%	120/120 : [('U/mL', 120)]
# LAB		0.0000	NOTNUM=	120	NUM=	0
# dropped
#
# LAB 51398	100.00%	449/449 : [('', 449)]
# LAB		10.2450	NOTNUM=	403	NUM=	46
# dropped
#
# LAB 51028	100.00%	250/250 : [('mg/dL', 250)]
# LAB		100.0000	NOTNUM=	0	NUM=	250
#
# LAB 51341	100.00%	128/128 : [('', 128)]
# LAB		0.0000	NOTNUM=	128	NUM=	0
# dropped
#
# LAB 51137	100.00%	37485/37485 : [('', 37485)]
# LAB		0.0053	NOTNUM=	37483	NUM=	2
# dropped
#
# LAB 51476	99.99%	59805/59809 : [('#/hpf', 59805), ('', 4)]
# LAB		53.8782	NOTNUM=	27585	NUM=	32224
# dropped
#
# LAB 51275	100.00%	403555/403567 : [('sec', 403555), ('', 12)]
# LAB		99.7002	NOTNUM=	1210	NUM=	402357
#
# LAB 51201	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51508	100.00%	66589/66589 : [('', 66589)]
# LAB		0.0015	NOTNUM=	66588	NUM=	1
# dropped
#
# LAB 51261	100.00%	743/743 : [('', 743)]
# LAB		0.0000	NOTNUM=	743	NUM=	0
# dropped
#
# LAB 51191	100.00%	51/51 : [('', 51)]
# LAB		0.0000	NOTNUM=	51	NUM=	0
# dropped
#
# LAB 51501	100.00%	3650/3650 : [('#/hpf', 3650)]
# LAB		23.7534	NOTNUM=	2783	NUM=	867
# dropped
#
# LAB 51118	100.00%	1489/1489 : [('%', 1489)]
# LAB		100.0000	NOTNUM=	0	NUM=	1489
#
# LAB 51322	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 50872	100.00%	538/538 : [('', 538)]
# LAB		0.0000	NOTNUM=	538	NUM=	0
# dropped
#
# LAB 50844	100.00%	11/11 : [('U/L', 11)]
# LAB		100.0000	NOTNUM=	0	NUM=	11
#
# LAB 51101	100.00%	66/66 : [('hrs', 66)]
# LAB		100.0000	NOTNUM=	0	NUM=	66
#
# LAB 50857	100.00%	1012/1012 : [('', 1012)]
# LAB		0.0988	NOTNUM=	1011	NUM=	1
# dropped
#
# LAB 50970	100.00%	489974/489990 : [('mg/dL', 489974), ('', 16)]
# LAB		99.9931	NOTNUM=	34	NUM=	489956
#
# LAB 50907	99.97%	7222/7224 : [('mg/dL', 7222), ('', 2)]
# LAB		99.9862	NOTNUM=	1	NUM=	7223
#
# LAB 50980	90.97%	433/476 : [('IU/mL', 433), ('I.U.', 43)]
# LAB		85.5042	NOTNUM=	69	NUM=	407
# dropped
#
# LAB 51241	100.00%	45/45 : [('Score', 45)]
# LAB		100.0000	NOTNUM=	0	NUM=	45
#
# LAB 51043	100.00%	440/440 : [('g/dL', 440)]
# LAB		99.3182	NOTNUM=	3	NUM=	437
#
# LAB 51254	99.99%	109476/109483 : [('%', 109476), ('', 7)]
# LAB		99.9872	NOTNUM=	14	NUM=	109469
#
# LAB 51116	100.00%	2499/2499 : [('%', 2499)]
# LAB		100.0000	NOTNUM=	0	NUM=	2499
#
# LAB 51195	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51012	100.00%	3/3 : [('mg/dL', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	3
#
# LAB 50891	100.00%	851/851 : [('mg/dL', 851)]
# LAB		99.1774	NOTNUM=	7	NUM=	844
#
# LAB 51378	100.00%	1/1 : [('%', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 51395	100.00%	22/22 : [('', 22)]
# LAB		0.0000	NOTNUM=	22	NUM=	0
# dropped
#
# LAB 50982	100.00%	12/12 : [('nmol/L', 12)]
# LAB		100.0000	NOTNUM=	0	NUM=	12
#
# LAB 51505	100.00%	896/896 : [('', 896)]
# LAB		0.0000	NOTNUM=	896	NUM=	0
# dropped
#
# LAB 51151	100.00%	7083/7083 : [('', 7083)]
# LAB		0.0000	NOTNUM=	7083	NUM=	0
# dropped
#
# LAB 51485	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 50911	100.00%	89876/89879 : [('ng/mL', 89876), ('', 3)]
# LAB		72.6021	NOTNUM=	24625	NUM=	65254
# dropped
#
# LAB 50972	100.00%	180/180 : [('ug/mL', 180)]
# LAB		97.2222	NOTNUM=	5	NUM=	175
#
# LAB 50817	80.38%	138308/172066 : [('%', 138308), ('', 33758)]
# LAB		99.9686	NOTNUM=	54	NUM=	172012
#
# LAB 51279	100.00%	573358/573376 : [('m/uL', 573358), ('', 18)]
# LAB		99.9442	NOTNUM=	320	NUM=	573056
#
# LAB 51424	100.00%	401/401 : [('', 401)]
# LAB		0.0000	NOTNUM=	401	NUM=	0
# dropped
#
# LAB 51206	100.00%	324/324 : [('%', 324)]
# LAB		98.4568	NOTNUM=	5	NUM=	319
#
# LAB 51057	100.00%	13/13 : [('mEq/L', 13)]
# LAB		100.0000	NOTNUM=	0	NUM=	13
#
# LAB 50811	100.00%	86674/86675 : [('g/dL', 86674), ('', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	86675
#
# LAB 51423	100.00%	225/225 : [('', 225)]
# LAB		0.0000	NOTNUM=	225	NUM=	0
# dropped
#
# LAB 50979	100.00%	11033/11033 : [('', 11033)]
# LAB		0.0000	NOTNUM=	11033	NUM=	0
# dropped
#
# LAB 51150	100.00%	404/404 : [('', 404)]
# LAB		0.7426	NOTNUM=	401	NUM=	3
# dropped
#
# LAB 51108	100.00%	677/677 : [('mL', 677)]
# LAB		99.8523	NOTNUM=	1	NUM=	676
#
# LAB 51024	100.00%	15/15 : [('g/dL', 15)]
# LAB		100.0000	NOTNUM=	0	NUM=	15
#
# LAB 51136	100.00%	2/2 : [('%', 2)]
# LAB		100.0000	NOTNUM=	0	NUM=	2
#
# LAB 50993	89.25%	13178/14766 : [('uIU/mL', 13178), ('uU/ML', 1586), ('', 2)]
# LAB		98.7403	NOTNUM=	186	NUM=	14580
#
# LAB 51418	100.00%	50/50 : [('', 50)]
# LAB		2.0000	NOTNUM=	49	NUM=	1
# dropped
#
# LAB 50859	100.00%	1/1 : [('IU/L', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 51170	100.00%	4/4 : [('#/uL', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 50866	100.00%	3165/3165 : [('umol/L', 3165)]
# LAB		99.0521	NOTNUM=	30	NUM=	3135
#
# LAB 51080	100.00%	65/65 : [('mL/min', 65)]
# LAB		100.0000	NOTNUM=	0	NUM=	65
#
# LAB 50941	100.00%	2292/2292 : [('', 2292)]
# LAB		0.0000	NOTNUM=	2292	NUM=	0
# dropped
#
# LAB 51038	100.00%	27/27 : [('', 27)]
# LAB		11.1111	NOTNUM=	24	NUM=	3
# dropped
#
# LAB 50940	100.00%	2278/2278 : [('', 2278)]
# LAB		0.0000	NOTNUM=	2278	NUM=	0
# dropped
#
# LAB 51111	100.00%	106/106 : [('%', 106)]
# LAB		100.0000	NOTNUM=	0	NUM=	106
#
# LAB 51253	100.00%	1/1 : [('#/uL', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 51285	100.00%	4/4 : [('pg', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 51440	100.00%	131/131 : [('%', 131)]
# LAB		100.0000	NOTNUM=	0	NUM=	131
#
# LAB 51388	100.00%	253/253 : [('', 253)]
# LAB		0.0000	NOTNUM=	253	NUM=	0
# dropped
#
# LAB 51167	100.00%	111/111 : [('', 111)]
# LAB		0.0000	NOTNUM=	111	NUM=	0
# dropped
#
# LAB 50971	100.00%	669859/669880 : [('mEq/L', 669859), ('', 21)]
# LAB		99.9548	NOTNUM=	303	NUM=	669577
#
# LAB 50849	100.00%	1407/1407 : [('g/dL', 1407)]
# LAB		99.1471	NOTNUM=	12	NUM=	1395
#
# LAB 51083	100.00%	7/7 : [('', 7)]
# LAB		14.2857	NOTNUM=	6	NUM=	1
# dropped
#
# LAB 50875	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51532	100.00%	1/1 : [('%', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 51367	100.00%	3/3 : [('%', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	3
#
# LAB 51397	100.00%	24/24 : [('', 24)]
# LAB		0.0000	NOTNUM=	24	NUM=	0
# dropped
#
# LAB 51288	100.00%	3669/3669 : [('mm/hr', 3669)]
# LAB		100.0000	NOTNUM=	0	NUM=	3669
#
# LAB 51351	100.00%	3696/3696 : [('%', 3696)]
# LAB		100.0000	NOTNUM=	0	NUM=	3696
#
# LAB 50898	100.00%	51/51 : [('U/mL', 51)]
# LAB		100.0000	NOTNUM=	0	NUM=	51
#
# LAB 50805	100.00%	1942/1942 : [('%', 1942)]
# LAB		98.9186	NOTNUM=	21	NUM=	1921
#
# LAB 51431	100.00%	1751/1751 : [('%', 1751)]
# LAB		99.8858	NOTNUM=	2	NUM=	1749
#
# LAB 51243	100.00%	374/374 : [('', 374)]
# LAB		0.0000	NOTNUM=	374	NUM=	0
# dropped
#
# LAB 51432	100.00%	6/6 : [('%', 6)]
# LAB		100.0000	NOTNUM=	0	NUM=	6
#
# LAB 51352	100.00%	966/966 : [('%', 966)]
# LAB		100.0000	NOTNUM=	0	NUM=	966
#
# LAB 51198	100.00%	309/309 : [('', 309)]
# LAB		0.0000	NOTNUM=	309	NUM=	0
# dropped
#
# LAB 51382	100.00%	416/416 : [('%', 416)]
# LAB		100.0000	NOTNUM=	0	NUM=	416
#
# LAB 50841	100.00%	448/448 : [('mg/dL', 448)]
# LAB		99.7768	NOTNUM=	1	NUM=	447
#
# LAB 51389	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 50962	100.00%	180/180 : [('ug/mL', 180)]
# LAB		97.2222	NOTNUM=	5	NUM=	175
#
# LAB 51014	100.00%	3280/3280 : [('mg/dL', 3280)]
# LAB		99.9085	NOTNUM=	3	NUM=	3277
#
# LAB 50976	100.00%	4174/4174 : [('g/dL', 4174)]
# LAB		99.9760	NOTNUM=	1	NUM=	4173
#
# LAB 51026	100.00%	669/669 : [('IU/L', 669)]
# LAB		98.3558	NOTNUM=	11	NUM=	658
#
# LAB 51153	100.00%	4/4 : [('', 4)]
# LAB		0.0000	NOTNUM=	4	NUM=	0
# dropped
#
# LAB 51419	100.00%	520/520 : [('%', 520)]
# LAB		100.0000	NOTNUM=	0	NUM=	520
#
# LAB 50814	100.00%	1972/1972 : [('%', 1972)]
# LAB		97.9209	NOTNUM=	41	NUM=	1931
#
# LAB 51160	100.00%	30/30 : [('', 30)]
# LAB		3.3333	NOTNUM=	29	NUM=	1
# dropped
#
# LAB 51374	100.00%	156/156 : [('', 156)]
# LAB		0.0000	NOTNUM=	156	NUM=	0
# dropped
#
# LAB 50961	100.00%	193/193 : [('umol/L', 193)]
# LAB		89.6373	NOTNUM=	20	NUM=	173
# dropped
#
# LAB 50812	100.00%	161016/161016 : [('', 161016)]
# LAB		0.0000	NOTNUM=	161016	NUM=	0
# dropped
#
# LAB 51274	93.02%	351831/378229 : [('sec', 351831), ('SECONDS', 26382), ('', 16)]
# LAB		99.9640	NOTNUM=	136	NUM=	378093
#
# LAB 51346	100.00%	10/10 : [('%', 10)]
# LAB		100.0000	NOTNUM=	0	NUM=	10
#
# LAB 50885	100.00%	173846/173847 : [('mg/dL', 173846), ('', 1)]
# LAB		99.9908	NOTNUM=	16	NUM=	173831
#
# LAB 50951	100.00%	1151/1151 : [('mg/dL', 1151)]
# LAB		99.6525	NOTNUM=	4	NUM=	1147
#
# LAB 51030	100.00%	64/64 : [('mEq/L', 64)]
# LAB		98.4375	NOTNUM=	1	NUM=	63
#
# LAB 51008	100.00%	2145/2145 : [('ug/mL', 2145)]
# LAB		95.2914	NOTNUM=	101	NUM=	2044
#
# LAB 51217	100.00%	49/49 : [('', 49)]
# LAB		0.0000	NOTNUM=	49	NUM=	0
# dropped
#
# LAB 50850	100.00%	80/80 : [('mg/dL', 80)]
# LAB		100.0000	NOTNUM=	0	NUM=	80
#
# LAB 51148	100.00%	2166/2166 : [('%', 2166)]
# LAB		100.0000	NOTNUM=	0	NUM=	2166
#
# LAB 51464	60.07%	39592/65911 : [('EU/dL', 39592), ('mg/dL', 26315), ('', 4)]
# LAB		0.0000	NOTNUM=	65911	NUM=	0
# dropped
#
# LAB 51498	100.00%	82057/82061 : [(' ', 82057), ('', 4)]
# LAB		97.6834	NOTNUM=	1901	NUM=	80160
#
# LAB 51450	100.00%	2137/2137 : [('%', 2137)]
# LAB		100.0000	NOTNUM=	0	NUM=	2137
#
# LAB 50975	100.00%	1089/1089 : [('', 1089)]
# LAB		0.0000	NOTNUM=	1089	NUM=	0
# dropped
#
# LAB 50808	100.00%	246200/246208 : [('mmol/L', 246200), ('', 8)]
# LAB		99.9785	NOTNUM=	53	NUM=	246155
#
# LAB 51338	100.00%	178/178 : [('', 178)]
# LAB		0.0000	NOTNUM=	178	NUM=	0
# dropped
#
# LAB 51451	100.00%	9/9 : [('%', 9)]
# LAB		100.0000	NOTNUM=	0	NUM=	9
#
# LAB 51530	 0 units
# LAB 51514	64.92%	44172/68043 : [('mg/dL', 44172), ('EU/dL', 23867), ('', 4)]
# LAB		28.8347	NOTNUM=	48423	NUM=	19620
# dropped
#
# LAB 51059	100.00%	2057/2057 : [('g/dL', 2057)]
# LAB		99.7083	NOTNUM=	6	NUM=	2051
#
# LAB 51320	100.00%	67/67 : [('', 67)]
# LAB		0.0000	NOTNUM=	67	NUM=	0
# dropped
#
# LAB 50823	100.00%	21824/21824 : [('', 21824)]
# LAB		99.9863	NOTNUM=	3	NUM=	21821
#
# LAB 51415	100.00%	20/20 : [('', 20)]
# LAB		0.0000	NOTNUM=	20	NUM=	0
# dropped
#
# LAB 51369	100.00%	54/54 : [('%', 54)]
# LAB		94.4444	NOTNUM=	3	NUM=	51
# dropped
#
# LAB 51358	100.00%	236/236 : [('%', 236)]
# LAB		100.0000	NOTNUM=	0	NUM=	236
#
# LAB 51417	100.00%	10/10 : [('', 10)]
# LAB		0.0000	NOTNUM=	10	NUM=	0
# dropped
#
# LAB 51483	100.00%	1/1 : [('', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 50944	100.00%	873/873 : [('', 873)]
# LAB		0.0000	NOTNUM=	873	NUM=	0
# dropped
#
# LAB 50952	100.00%	11277/11277 : [('ug/dL', 11277)]
# LAB		99.9379	NOTNUM=	7	NUM=	11270
#
# LAB 50945	100.00%	354/354 : [('umol/L', 354)]
# LAB		100.0000	NOTNUM=	0	NUM=	354
#
# LAB 51434	100.00%	504/504 : [('%', 504)]
# LAB		100.0000	NOTNUM=	0	NUM=	504
#
# LAB 51290	100.00%	10/10 : [('', 10)]
# LAB		0.0000	NOTNUM=	10	NUM=	0
# dropped
#
# LAB 51454	100.00%	67/67 : [('%', 67)]
# LAB		100.0000	NOTNUM=	0	NUM=	67
#
# LAB 50927	100.00%	1359/1359 : [('IU/L', 1359)]
# LAB		100.0000	NOTNUM=	0	NUM=	1359
#
# LAB 51390	100.00%	22/22 : [('', 22)]
# LAB		0.0000	NOTNUM=	22	NUM=	0
# dropped
#
# LAB 50845	100.00%	7/7 : [('', 7)]
# LAB		0.0000	NOTNUM=	7	NUM=	0
# dropped
#
# LAB 51377	100.00%	16/16 : [('%', 16)]
# LAB		100.0000	NOTNUM=	0	NUM=	16
#
# LAB 51017	100.00%	108/108 : [('', 108)]
# LAB		0.0000	NOTNUM=	108	NUM=	0
# dropped
#
# LAB 50838	100.00%	654/654 : [('mg/dL', 654)]
# LAB		100.0000	NOTNUM=	0	NUM=	654
#
# LAB 51267	100.00%	35634/35634 : [('', 35634)]
# LAB		0.0056	NOTNUM=	35632	NUM=	2
# dropped
#
# LAB 51471	100.00%	129/129 : [('#/lpf', 129)]
# LAB		79.0698	NOTNUM=	27	NUM=	102
# dropped
#
# LAB 51049	100.00%	68/68 : [('mg/dL', 68)]
# LAB		100.0000	NOTNUM=	0	NUM=	68
#
# LAB 51162	100.00%	9/9 : [('#/uL', 9)]
# LAB		100.0000	NOTNUM=	0	NUM=	9
#
# LAB 51166	100.00%	4/4 : [('#/uL', 4)]
# LAB		100.0000	NOTNUM=	0	NUM=	4
#
# LAB 51203	100.00%	38/38 : [('%', 38)]
# LAB		94.7368	NOTNUM=	2	NUM=	36
# dropped
#
# LAB 51484	99.99%	67843/67847 : [('mg/dL', 67843), ('', 4)]
# LAB		13.1782	NOTNUM=	58906	NUM=	8941
# dropped
#
# LAB 51047	100.00%	627/627 : [('IU/L', 627)]
# LAB		100.0000	NOTNUM=	0	NUM=	627
#
# LAB 51521	 0 units
# LAB 51082	100.00%	22879/22880 : [('mg/dL', 22879), ('', 1)]
# LAB		99.9694	NOTNUM=	7	NUM=	22873
#
# LAB 51475	100.00%	2/2 : [('#/lpf', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51205	100.00%	51/51 : [('%', 51)]
# LAB		100.0000	NOTNUM=	0	NUM=	51
#
# LAB 51459	100.00%	1/1 : [('%', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 50878	100.00%	148395/148396 : [('IU/L', 148395), ('', 1)]
# LAB		99.9946	NOTNUM=	8	NUM=	148388
#
# LAB 51244	99.99%	109476/109483 : [('%', 109476), ('', 7)]
# LAB		99.9872	NOTNUM=	14	NUM=	109469
#
# LAB 50837	100.00%	39/39 : [('mEq/L', 39)]
# LAB		92.3077	NOTNUM=	3	NUM=	36
# dropped
#
# LAB 51213	100.00%	4821/4821 : [('ug/mL', 4821)]
# LAB		0.0000	NOTNUM=	4821	NUM=	0
# dropped
#
# LAB 51494	100.00%	46/46 : [('#/lpf', 46)]
# LAB		23.9130	NOTNUM=	35	NUM=	11
# dropped
#
# LAB 51144	99.99%	56457/56460 : [('%', 56457), ('', 3)]
# LAB		100.0000	NOTNUM=	0	NUM=	56460
#
# LAB 51283	100.00%	7127/7127 : [('%', 7127)]
# LAB		99.9860	NOTNUM=	1	NUM=	7126
#
# LAB 50831	81.77%	915/1119 : [('units', 915), ('', 204)]
# LAB		99.6425	NOTNUM=	4	NUM=	1115
#
# LAB 51001	90.22%	1402/1554 : [('ng/dL', 1402), ('NG/DL', 152)]
# LAB		97.4260	NOTNUM=	40	NUM=	1514
#
# LAB 50876	100.00%	246/246 : [('', 246)]
# LAB		0.0000	NOTNUM=	246	NUM=	0
# dropped
#
# LAB 51072	100.00%	43/43 : [('U/L', 43)]
# LAB		100.0000	NOTNUM=	0	NUM=	43
#
# LAB 51123	100.00%	323/323 : [('%', 323)]
# LAB		100.0000	NOTNUM=	0	NUM=	323
#
# LAB 50804	95.85%	465453/485594 : [('mEq/L', 465453), ('MEQ/L', 20121), ('', 20)]
# LAB		99.9784	NOTNUM=	105	NUM=	485489
#
# LAB 50858	100.00%	1/1 : [('IU/L', 1)]
# LAB		0.0000	NOTNUM=	1	NUM=	0
# dropped
#
# LAB 51246	100.00%	37309/37309 : [('', 37309)]
# LAB		0.0000	NOTNUM=	37309	NUM=	0
# dropped
#
# LAB 51094	100.00%	664/664 : [('', 664)]
# LAB		100.0000	NOTNUM=	0	NUM=	664
#
# LAB 51087	100.00%	27946/27946 : [('', 27946)]
# LAB		2.4225	NOTNUM=	27269	NUM=	677
# dropped
#
# LAB 51051	100.00%	272/272 : [('mg/dL', 272)]
# LAB		100.0000	NOTNUM=	0	NUM=	272
#
# LAB 51149	100.00%	33/33 : [('min', 33)]
# LAB		96.9697	NOTNUM=	1	NUM=	32
#
# LAB 51336	100.00%	45/45 : [('', 45)]
# LAB		0.0000	NOTNUM=	45	NUM=	0
# dropped
#
# LAB 50887	100.00%	10863/10863 : [('', 10863)]
# LAB		0.0000	NOTNUM=	10863	NUM=	0
# dropped
#
# LAB 51409	100.00%	4/4 : [('', 4)]
# LAB		50.0000	NOTNUM=	2	NUM=	2
# dropped
#
# LAB 51139	100.00%	368/368 : [('MPL', 368)]
# LAB		97.8261	NOTNUM=	8	NUM=	360
#
# LAB 51510	100.00%	103/103 : [('', 103)]
# LAB		0.9709	NOTNUM=	102	NUM=	1
# dropped
#
# LAB 51214	100.00%	43687/43687 : [('mg/dL', 43687)]
# LAB		99.8558	NOTNUM=	63	NUM=	43624
#
# LAB 51141	100.00%	2/2 : [('', 2)]
# LAB		0.0000	NOTNUM=	2	NUM=	0
# dropped
#
# LAB 51117	100.00%	1652/1652 : [('%', 1652)]
# LAB		100.0000	NOTNUM=	0	NUM=	1652
#
# LAB 51324	100.00%	55/55 : [('', 55)]
# LAB		0.0000	NOTNUM=	55	NUM=	0
# dropped
#
# LAB 50870	100.00%	1/1 : [('units', 1)]
# LAB		100.0000	NOTNUM=	0	NUM=	1
#
# LAB 51200	99.99%	109474/109481 : [('%', 109474), ('', 7)]
# LAB		99.9872	NOTNUM=	14	NUM=	109467
#
# LAB 51497	100.00%	1508/1508 : [('#/hpf', 1508)]
# LAB		8.6207	NOTNUM=	1378	NUM=	130
# dropped
#
# LAB 51145	100.00%	2759/2759 : [('', 2759)]
# LAB		0.0000	NOTNUM=	2759	NUM=	0
# dropped
#
# LAB 51455	100.00%	2137/2137 : [('%', 2137)]
# LAB		100.0000	NOTNUM=	0	NUM=	2137
#
# LAB 51015	100.00%	364/364 : [('IU/L', 364)]
# LAB		99.7253	NOTNUM=	1	NUM=	363
#
# LAB 50928	100.00%	49/49 : [('pg/mL', 49)]
# LAB		100.0000	NOTNUM=	0	NUM=	49
#
# LAB 50888	 0 units
# LAB 51410	100.00%	10/10 : [('', 10)]
# LAB		0.0000	NOTNUM=	10	NUM=	0
# dropped
#
# LAB 51016	100.00%	12/12 : [('', 12)]
# LAB		8.3333	NOTNUM=	11	NUM=	1
# dropped
#
# LAB 51089	100.00%	91/91 : [('', 91)]
# LAB		0.0000	NOTNUM=	91	NUM=	0
# dropped
#
# LAB 51447	100.00%	1245/1245 : [('%', 1245)]
# LAB		100.0000	NOTNUM=	0	NUM=	1245

# %%
print(valid_lab, valid_lab_unit)
np.save('res/filtered_lab.npy',{'id':valid_lab,'unit':valid_lab_unit})
print('saved!')
# Out:
# [51029, 50903, 51438, 51387, 50816, 51132, 50868, 51379, 50832, 51105, 51453, 51436, 51084, 51175, 51053, 50954, 51496, 51037, 50983, 51282, 51353, 51119, 50853, 51209, 51124, 50998, 51146, 51381, 51010, 51366, 51383, 51110, 51212, 51363, 51131, 51036, 51102, 51433, 51031, 50801, 51458, 50803, 50896, 51133, 51073, 51048, 51097, 50815, 50852, 51077, 51045, 51442, 51130, 51065, 51255, 51006, 50830, 50931, 51439, 50842, 51300, 50965, 51218, 51344, 50848, 50969, 51277, 51050, 50949, 51063, 51126, 50966, 51302, 51021, 51208, 51140, 51224, 51272, 51088, 50843, 51202, 50861, 51249, 51360, 51289, 51169, 51099, 51427, 50840, 50890, 51066, 51297, 51058, 51113, 51452, 51226, 50988, 51457, 51437, 51449, 50846, 50995, 51227, 50973, 50851, 51044, 51448, 50902, 51143, 50964, 50810, 50882, 50867, 51456, 51040, 50818, 51347, 51020, 51039, 51068, 51221, 51128, 51385, 50910, 50809, 50967, 50914, 51034, 51042, 51529, 50953, 51354, 51163, 50819, 50806, 51112, 51106, 51023, 51298, 50978, 51441, 51356, 50883, 51375, 51345, 51368, 50912, 51005, 51165, 51349, 51114, 51428, 51078, 51199, 51435, 50963, 51359, 51270, 51055, 51122, 50956, 50820, 50996, 51232, 51174, 50917, 51259, 51284, 50960, 51054, 50908, 50869, 51265, 51121, 50881, 51271, 51237, 51032, 51467, 50826, 51257, 50930, 51443, 50825, 50893, 51273, 51035, 50894, 51009, 51007, 51380, 50821, 51181, 50889, 50947, 51067, 51444, 50916, 50834, 50847, 50813, 51000, 51429, 51222, 51070, 51125, 51109, 51104, 50865, 51019, 51210, 50863, 51120, 51081, 51248, 51301, 50824, 51095, 51361, 50833, 50892, 50839, 51384, 51263, 51204, 50895, 51343, 51185, 51376, 50884, 50994, 51256, 50909, 50802, 51129, 51362, 51186, 51223, 50934, 51365, 50904, 51348, 51276, 50822, 51355, 51022, 50900, 50836, 51480, 51245, 51093, 51052, 50862, 51269, 51357, 50986, 51250, 51138, 50977, 51491, 50905, 51018, 51364, 50997, 51127, 51251, 50950, 51430, 51060, 51446, 51386, 51028, 51275, 51118, 50844, 51101, 50970, 50907, 51241, 51043, 51254, 51116, 51012, 50891, 51378, 50982, 50972, 50817, 51279, 51206, 51057, 50811, 51108, 51024, 51136, 50993, 51170, 50866, 51080, 51111, 51253, 51285, 51440, 50971, 50849, 51532, 51367, 51288, 51351, 50898, 50805, 51431, 51432, 51352, 51382, 50841, 50962, 51014, 50976, 51026, 51419, 50814, 51274, 51346, 50885, 50951, 51030, 51008, 50850, 51148, 51498, 51450, 50808, 51451, 51059, 50823, 51358, 50952, 50945, 51434, 51454, 50927, 51377, 50838, 51049, 51162, 51166, 51047, 51082, 51205, 51459, 50878, 51244, 51144, 51283, 50831, 51001, 51072, 51123, 50804, 51094, 51051, 51149, 51139, 51214, 51117, 50870, 51200, 51455, 51015, 50928, 51447] ['mg/dL', 'Ratio', '#/uL', '%', '%', '#/uL', 'mEq/L', '%', 'mm Hg', 'mg/dL', '%', '%', 'mg/dL', '#/uL', 'mg/dL', 'IU/L', '%', 'mg/dL', 'mEq/L', '/mm3', '%', '%', 'ng/mL', '%', '%', 'mg/dL', '%', '%', 'pg/mL', '%', '#/uL', '%', '%', '#/uL', '#/uL', 'U/L', 'mg/dL', '%', 'mg/dL', 'mm Hg', '#/uL', 'mEq/L', 'ug/dL', '#/uL', 'Ratio', 'mEq/L', 'mEq/L', 'L/min', '%', 'mg/dL', 'mg/dL', '%', '#/uL', 'mEq/L', '%', 'mg/dL', 'mm Hg', 'mg/dL', '#/uL', 'mg/dL', 'K/uL', 'pg/mL', '#/uL', '%', 'mEq/L', '%', '%', 'mEq/L', 'mg/dL', 'mOsm/kg', '%', 'ug/mL', '%', 'mg/dL', '%', '%', '%', '%', 'mg/dL', 'IU/L', '%', 'IU/L', '%', '%', ' ', '%', 'Ratio', '%', 'mg/dL', 'mg/dL', 'mg/24hr', 'sec', 'mEq/L', '%', '%', '%', 'ng/dL', '#/uL', '%', '%', 'mOsm/kg', 'ng/dL', '%', 'ng/mL', 'mg/dL', 'mg/dL', '%', 'mEq/L', '%', 'mOsm/kg', '%', 'mEq/L', 'IU/L', '%', 'mg/dL', 'mm Hg', '%', 'IU/L', 'mOsm/kg', 'mg/24hr', '%', '#/uL', '%', 'IU/L', 'mg/dL', 'ug/mL', 'ng/mL', 'mg/dL', 'mEq/L', 'mg/dL', 'ug/dL', '%', '%', '', 'mEq/L', '%', 'mg/dL', 'IU/L', '%', 'ng/mL', '%', '%', 'mg/dL', '%', '%', '%', 'mg/dL', 'Ratio', '%', '%', '%', '%', 'mEq/L', '#/uL', '%', 'pg/mL', '%', '%', 'U/L', '%', 'IU/L', 'units', 'units', '%', '%', 'ng/mL', '%', '%', 'mg/dL', 'IU/L', '%', 'units', 'K/uL', '%', 'mg/L', '%', '', 'mg/dL', '#/lpf', '', '%', 'g/dL', '%', '', 'mg/dL', '%', 'IU/L', 'pg/mL', 'ug/mL', 'mg/dL', '%', 'mm Hg', 'Ratio',  ...
# saved!

# %% [markdown]
# All the units are convertible, so keep all of them.

# %%
for i, percentage, totaltemp, outputunits in sorted(multiple_units, key=lambda x: x[1]):
    print("LAB "+ str(i) + "\t" + "{:.2f}%".format(percentage) + "\t" + str(outputunits[0][1])+"/"+str(totaltemp)+" : "+ str(outputunits))
# Out:
# LAB 50990	54.45%	104/191 : [('ug/ml', 104), ('ug/mL', 87)]
# LAB 51464	60.07%	39592/65911 : [('EU/dL', 39592), ('mg/dL', 26315), ('', 4)]
# LAB 51514	64.92%	44172/68043 : [('mg/dL', 44172), ('EU/dL', 23867), ('', 4)]
# LAB 51105	68.65%	289/421 : [('mg/dL', 289), ('MG/DL', 132)]
# LAB 50926	75.86%	66/87 : [('mIU/mL', 66), ('mIU/L', 21)]
# LAB 50958	76.32%	58/76 : [('mIU/mL', 58), ('mIU/L', 18)]
# LAB 50916	81.82%	9/11 : [('ug/dL', 9), ('nG/mL', 2)]
# LAB 50889	83.34%	2931/3517 : [('mg/L', 2931), ('mg/dL', 565), ('MG/DL', 19), ('', 2)]
# LAB 51000	85.67%	11588/13526 : [('mg/dL', 11588), ('MG/DL', 1936), ('', 2)]
# LAB 51003	86.29%	57280/66384 : [('ng/mL', 57280), ('ng/ml', 9104)]
# LAB 50989	86.96%	20/23 : [('pg/mL', 20), ('ng/dL', 3)]
# LAB 51127	88.43%	2156/2438 : [('#/uL', 2156), ('#/CU MM', 282)]
# LAB 51128	88.72%	2218/2500 : [('#/uL', 2218), ('#/CU MM', 282)]
# LAB 50995	88.89%	3280/3690 : [('ng/dL', 3280), ('ng/dl', 408), ('', 2)]
# LAB 50993	89.25%	13178/14766 : [('uIU/mL', 13178), ('uU/ML', 1586), ('', 2)]
# LAB 50994	90.12%	1997/2216 : [('ug/dL', 1997), ('uG/DL', 219)]
# LAB 50974	90.12%	456/506 : [('ng/mL', 456), ('ug/L', 50)]
# LAB 51001	90.22%	1402/1554 : [('ng/dL', 1402), ('NG/DL', 152)]
# LAB 50935	90.80%	8491/9351 : [('mg/dL', 8491), ('MG/DL', 860)]
# LAB 50980	90.97%	433/476 : [('IU/mL', 433), ('I.U.', 43)]
# LAB 50973	92.63%	176/190 : [('ng/mL', 176), ('nG/mL', 14)]
# LAB 51274	93.02%	351831/378229 : [('sec', 351831), ('SECONDS', 26382), ('', 16)]
# LAB 50964	93.11%	16472/17690 : [('mOsm/kg', 16472), ('MOSM/KG', 741), ('MOSM/L', 477)]
# LAB 50924	93.14%	9963/10697 : [('ng/mL', 9963), ('ng/ml', 734)]
# LAB 50864	93.21%	783/840 : [('ng/mL', 783), ('nG/ML', 57)]
# LAB 51005	94.86%	332/350 : [('Ratio', 332), ('RATIO', 18)]
# LAB 50896	95.06%	327/344 : [('ug/dL', 327), ('uG/DL', 17)]
# LAB 50820	95.56%	501298/524600 : [('units', 501298), ('UNITS', 23277), ('', 25)]
# LAB 50804	95.85%	465453/485594 : [('mEq/L', 465453), ('MEQ/L', 20121), ('', 20)]
# LAB 50818	95.88%	465561/485552 : [('mm Hg', 465561), ('MM HG', 19971), ('', 20)]
# LAB 50821	95.88%	465595/485586 : [('mm Hg', 465595), ('MM HG', 19971), ('', 20)]
# LAB 51067	96.41%	322/334 : [('mg/24hr', 322), ('mg/24hours', 12)]
# LAB 51068	98.23%	111/113 : [('mg/24hr', 111), ('mg/24hours', 2)]

# %%
print(dropped_id, len(dropped_id))
# Out:
# [50800, 51183, 51506, 50935, 51337, 51307, 51486, 51502, 51306, 50874, 51075, 51462, 51240, 51426, 51518, 51155, 50864, 51468, 51157, 51466, 50968, 51327, 50957, 51236, 51407, 51230, 50924, 51280, 50942, 51234, 51489, 50939, 50829, 51286, 50901, 50906, 51331, 51405, 51233, 51372, 51011, 51517, 51092, 51309, 51304, 51315, 51519, 50937, 51085, 51412, 51425, 51027, 51268, 50854, 51192, 50959, 51100, 51156, 51487, 51293, 50932, 51416, 51314, 50856, 51463, 50886, 51411, 51332, 51252, 51003, 50880, 50929, 51393, 51154, 51161, 51413, 51421, 51414, 51184, 51342, 51182, 51188, 51318, 51041, 51396, 51330, 51333, 51074, 51189, 51187, 51238, 51090, 51537, 51180, 51478, 51216, 50877, 51323, 51329, 51178, 51477, 50989, 51499, 51179, 51465, 51321, 51076, 51473, 51500, 51215, 51064, 50921, 50938, 50835, 50879, 51420, 51056, 51173, 51194, 50827, 50999, 51400, 50991, 51325, 51312, 51091, 51291, 51258, 51115, 51373, 51507, 51474, 51482, 51247, 50926, 50955, 50933, 51239, 51071, 51079, 51408, 51516, 50946, 51158, 51281, 51069, 51228, 51470, 51479, 51287, 51197, 51350, 51523, 51278, 51520, 51002, 50990, 51220, 51339, 51490, 51512, 51460, 50922, 50873, 51515, 50899, 51391, 51511, 51135, 51513, 51308, 50871, 51025, 51488, 51370, 51171, 50920, 51316, 51406, 50958, 51172, 51394, 51086, 51299, 50828, 51399, 51193, 51445, 51046, 51225, 51335, 51098, 51402, 51303, 50948, 51176, 50855, 51311, 51392, 50919, 51168, 51319, 51229, 51326, 51292, 51403, 51219, 51334, 51422, 51242, 51159, 51404, 51295, 51260, 51294, 51152, 51266, 51164, 50943, 51147, 50913, 51231, 51103, 51495, 51504, 51493, 50981, 51481, 51472, 51492, 51207, 51262, 51177, 50974, 50992, 51062, 51211, 51461, 51264, 51340, 51196, 50925, 51305, 51190, 51503, 51310, 51296, 51096, 50915, 51401, 51328, 51469, 51142, 51061, 51134, 51235, 51317, 51313, 50918, 51398, 51341, 51137, 51476, 51201, 51508, 51261, 51191, 51501, 51322, 50872, 50857, 50980, 51195, 51395, 51505, 51151, 51485, 50911, 51424, 51423, 50979, 51150, 51418, 50859, 50941, 51038, 50940, 51388, 51167, 51083, 50875, 51397, 51243, 51198, 51389, 51153, 51160, 51374, 50961, 50812, 51217, 51464, 50975, 51338, 51514, 51320, 51415, 51369, 51417, 51483, 50944, 51290, 51390, 50845, 51017, 51267, 51471, 51203, 51484, 51475, 50837, 51213, 51494, 50876, 50858, 51246, 51087, 51336, 50887, 51409, 51510, 51141, 51324, 51497, 51145, 51410, 51016, 51089] 338

# %%
# valid_lab_num = [51475,50845,51280,50935,51479,50922,51501,50925,50856,50981,51213,50915,51497,51046,50835,51176,51180,51194,51196,51130,51131,51132,50906,51076,51422,51517,51229,50946,51471,50899,51515,51369,50992,50958,50926,50961,51228,50877,51494,50990,50991,51489,51488,51061,51225,50894,50989,51209,51516,51493,51476,50911,51003,51482]
# valid_lab_cate = [51519,51461,51495,51390,51096,51403,51391,51189,51405,50901,51407,51089,51153,51171,51220,51179,51468,51016,51401,51207,51472,51394,51291,51500,51161,51286,51410,51417,51389,51195,51322,51201,51142,51311,51135,51329,51396,51318,51421,50875,51485,51316,51308,51056,51537,51414,51304,51157,51079,51075,51071,51074,51092,51090,51512,50828,50933,51266,51246,51267,51137,51252,51268,51233,50955,50887,51523,51462,50979,51260,50919,51287,51296,51151,51474,51107,51103,51236,50940,50943,50941,51145,51294,50942,51240,51292,51518,50873,51505,51469,50975,51424,51134,51411,50944,50937,51197,51425,51426,51098,51243,51373,51147,51085,51216,51400,51388,51412,50872,51150,51423,51402,50938,50939,51234,51420,51338,51325,51183,51164,50948,51313,50857,51399,51239,51238,51416,51319,51230,51337,51152,51168,51184,51341,51340,51198,51326,51303,51315,50876,51261,51499,50871,51086,51192,51167,51332,51314,51342,51231,51321,51264,51374,51370,51372,51307,51235,51215,51317,51503,51335,51172,50874,51219,51305,51310,51323,51334,51320,51178,51156,51309,51306,51155,51324,51177,51158,51328,50913,51336,51159,51333,51154,51331,51262,51339,51182,51217,50918,51193,51460,51191,51510,51091,51465,51017,51160,51408,51418,51190,51187,51413,50932,51511,51350,51393,51481,51392,51490,51397,51470,51247,51312,51395,51295,51173,51502,51415,51508,51506,51466,51486,51464,51487,51463,50920,50800,50880,50879,50999,50812]
# valid_lab_set = set(valid_lab_num + valid_lab_cate)
# leftids = [d for d in dropped_id if d not in valid_lab_set]

dropped_value = []

for d in dropped_id:
# for d in leftids:
    print('LAB : ' + str(d))
    cur = conn.cursor()
    cur.execute('SELECT value, valueuom, count(*) as x FROM mimiciii.labevents as lb \
                WHERE itemid = '+ str(d) +' and hadm_id in (select * from admission_ids) GROUP BY value, valueuom ORDER BY x DESC')
    droped_outs = cur.fetchall()
    drop_array = [];
    ct =0
    total = 0;
    for dx in droped_outs:
        total += dx[2]
    print("Count ",total)
    for dx in droped_outs:
        ct+=1
        if(ct>20):
            break;
        dx = list(dx)
        print(dx[1],dx[0],"\t",dx[2])
    print('')
    dropped_value.append((d, droped_outs))
    
np.save('res/lab_dropped_value.npy', dropped_value)
# Out:
# LAB : 50800
# Count  398697
# None ART 	 353584
# None MIX 	 27174
# None VEN 	 17171
# None CENTRAL VENOUS 	 768
#
# LAB : 51183
# Count  165
# None DONE 	 133
# None D 	 31
# None DOME 	 1
#
# LAB : 51506
# Count  66052
# None Clear 	 46682
# None Hazy 	 8907
# None Cloudy 	 5506
# None SlHazy 	 2256
# None CLEAR 	 1050
# None SlCldy 	 562
# None SLHAZY 	 285
# None HAZY 	 273
# None CLOUDY 	 235
# None SlCloudy 	 134
# None Slcldy 	 72
# None TURBID 	 38
# None   	 17
# None Sl 	 13
# None CLO 	 4
# None HA 	 2
# None H 	 2
# None COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# None CLOU 	 2
# None SL 	 1
#
# LAB : 50935
# Count  9351
# mg/dL <20 	 1098
# MG/DL <20 	 105
# mg/dL 125 	 35
# mg/dL 44 	 34
# mg/dL LESS THAN 20 	 34
# mg/dL 195 	 34
# mg/dL 139 	 33
# mg/dL 108 	 33
# mg/dL 50 	 33
# mg/dL 110 	 33
# mg/dL 140 	 32
# mg/dL 88 	 31
# mg/dL 54 	 31
# mg/dL 142 	 31
# mg/dL 175 	 31
# mg/dL 113 	 31
# mg/dL 80 	 30
# mg/dL 96 	 30
# mg/dL 106 	 30
# mg/dL 160 	 30
#
# LAB : 51337
# Count  130
# None DONE 	 106
# None D 	 24
#
# LAB : 51307
# Count  91
# None DONE 	 75
# None D 	 16
#
# LAB : 51486
# Count  64229
# None NEG 	 45329
# None TR 	 6798
# None MOD 	 5833
# None SM 	 5120
# None LG 	 1121
# None   	 17
# None N 	 5
# None COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# None SMALL 	 1
# None L 	 1
# None TRACE 	 1
# None 3 	 1
#
# LAB : 51502
# Count  20
# None FEW 	 11
# None OCC 	 5
# None   	 2
# None RARE 	 2
#
# LAB : 51306
# Count  58
# None DONE 	 49
# None D 	 9
#
# LAB : 50874
# Count  292
# None 1:40 	 109
# None 1:160 	 30
# None 1:40 PATTERN-SPECKLED 	 29
# None 1:80 	 26
# None 1:320 	 23
# None 1:40 PATTERN-DIFFUSE 	 12
# None 1:1280 	 12
# None 1:640 	 9
# None 1:80 PATTERN-DIFFUSE 	 8
# None GREATER THAN 1:1280 	 5
# None 1:80 PATTERN-SPECKLED 	 5
# None 1:160 PATTERN-DIFFUSE 	 5
# None 1:320 PATTERN-DIFFUSE 	 4
# None 1:320 PATTERN-SPECKLED 	 2
# None LESS THAN 1:40 	 2
# None 1:160 PATTERN-SPECKLED 	 2
# None LESS THAN 1:40 PATTERN-SPECKLED 	 1
# None 1:640 PATTERN-SPECKLED 	 1
# None CORRECTED RESULT 1:80 	 1
# None 1:640 PATTERN-DIFFUSE 	 1
#
# LAB : 51075
# Count  7076
# None NEG 	 5396
# None POS 	 1678
# None NEGATIVE 	 1
# None POSITIVE 	 1
#
# LAB : 51462
# Count  5578
# None FEW 	 1919
# None MOD 	 1454
# None MANY 	 865
# None OCC 	 805
# None RARE 	 525
# None   	 4
# None NONE 	 3
# None MODERATE 	 1
# None M 	 1
# None LOADED 	 1
#
# LAB : 51240
# Count  4878
# None 1+ 	 2235
# None 3+ 	 1472
# None 2+ 	 1163
# None 8 	 4
# None A 	 2
# None LPLT 	 1
# None 124 	 1
#
# LAB : 51426
# Count  368
# None DONE 	 295
# None D 	 73
#
# LAB : 51518
# Count  1256
# None OCC 	 401
# None FEW 	 285
# None RARE 	 220
# None MOD 	 180
# None MANY 	 165
# None NONE 	 2
# None 0 	 1
# None O 	 1
# None F 	 1
#
# LAB : 51155
# Count  57
# None DONE 	 49
# None D 	 8
#
# LAB : 50864
# Count  840
# ng/mL <1.0 	 37
# ng/mL 2.0 	 25
# ng/mL 1.9 	 25
# ng/mL 1.5 	 25
# ng/mL 1.7 	 24
# ng/mL 1.6 	 23
# ng/mL 1.4 	 20
# ng/mL 2.4 	 19
# ng/mL 1.8 	 19
# ng/mL 2.3 	 18
# ng/mL 3.4 	 18
# ng/mL 2.6 	 18
# ng/mL 2.2 	 17
# ng/mL 3.0 	 16
# ng/mL 1.1 	 16
# ng/mL 1.0 	 16
# ng/mL 2.1 	 16
# ng/mL 2.8 	 15
# ng/mL 2.9 	 15
# ng/mL 1.3 	 14
#
# LAB : 51468
# Count  6
# None OCC 	 3
# None FEW 	 2
# None RARE 	 1
#
# LAB : 51157
# Count  2
# None D 	 2
#
# LAB : 51466
# Count  65945
# None NEG 	 18797
# None LG 	 14790
# None SM 	 6310
# None MOD 	 6261
# None TR 	 4872
# mg/dL NEG 	 3861
# mg/dL LG 	 2852
# None LGE 	 2833
# mg/dL SM 	 1667
# mg/dL MOD 	 1376
# mg/dL TR 	 1296
# mg/dL LGE 	 1001
# None   	 16
# mg/dL Mod 	 2
# mg/dL Neg 	 2
# None TRACE 	 2
# mg/dL COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# None N 	 1
# mg/dL Sm 	 1
# mg/dL Lg 	 1
#
# LAB : 50968
# Count  864
# ug/mL 1.7 	 55
# ug/mL 1.9 	 49
# ug/mL 1.4 	 48
# ug/mL 1.8 	 45
# ug/mL 1.6 	 42
# ug/mL 2.0 	 42
# ug/mL GREATER THAN 4.0 	 39
# ug/mL 1.0 	 39
# ug/mL 1.5 	 35
# ug/mL 2.2 	 32
# ug/mL 1.3 	 31
# ug/mL 2.1 	 30
# ug/mL 2.5 	 29
# ug/mL 2.4 	 28
# ug/mL 2.7 	 28
# ug/mL 1.2 	 27
# ug/mL 0.9 	 27
# ug/mL 2.8 	 26
# ug/mL 1.1 	 24
# ug/mL 2.6 	 23
#
# LAB : 51327
# Count  1
# None DONE 	 1
#
# LAB : 50957
# Count  661
# mmol/L 0.8 	 56
# mmol/L 0.7 	 51
# mmol/L 0.5 	 50
# mmol/L 0.3 	 48
# mmol/L LESS THAN 0.2 	 47
# mmol/L 0.6 	 39
# mmol/L 0.9 	 34
# mmol/L 0.4 	 31
# mmol/L 0.2 	 29
# mmol/L 1.2 	 28
# mmol/L 1.0 	 28
# mmol/L 1.1 	 25
# mmol/L 1.4 	 21
# mmol/L 1.3 	 19
# mmol/L 1.5 	 19
# mmol/L 1.9 	 14
# mmol/L 1.6 	 13
# mmol/L 1.7 	 12
# mmol/L 2.1 	 7
# mmol/L <0.2 	 7
#
# LAB : 51236
# Count  594
# None DONE 	 281
# None AVAILABLE AT THE EAST CAMPUS LAB 	 112
# None AVAILABLE AT THE WEST CAMPUS LAB 	 71
# None AV 	 38
# None D 	 34
# None SENT 	 15
# None DIFF 	 8
# None EAST 	 7
# None WEST 	 4
# None AVAILABLE ON EAST 	 3
# None MADE 	 2
# None AVAILABLE ON EAST CAMPUS 	 2
# None AVAILABLE ON WEST 	 2
# None A 	 2
# None AVA 	 1
# None UNABLE 	 1
# None SMEAR IS AVAILABLE ON EAST CAMPUS 	 1
# None SMEAR AVAILABLE AT WEST CAMPUS LAB 	 1
# None SEND 	 1
# None SMEAR AVAILABLE ON THE WEST 	 1
#
# LAB : 51407
# Count  11
# None DONE 	 7
# None D 	 4
#
# LAB : 51230
# Count  140
# None DONE 	 118
# None D 	 22
#
# LAB : 50924
# Count  10697
# ng/mL GREATER THAN 2000 	 434
# ng/ml GREATER THAN 1000 	 120
# ng/mL >2000 	 62
# ng/mL 68 	 25
# ng/mL 119 	 25
# ng/mL 29 	 24
# ng/mL 64 	 24
# ng/mL 43 	 24
# ng/mL 55 	 24
# ng/mL 79 	 24
# ng/mL 38 	 23
# ng/mL 30 	 23
# ng/mL 77 	 23
# ng/mL 42 	 23
# ng/mL 131 	 23
# ng/mL 127 	 23
# ng/mL 103 	 23
# ng/mL 112 	 22
# ng/mL 57 	 22
# ng/mL 129 	 22
#
# LAB : 51280
# Count  18
# sec 23.8 	 2
# sec 24.4 	 1
# sec 25.0 	 1
# sec 20.6 	 1
# sec 18.6 	 1
# sec 16.4 	 1
# sec 28.3 	 1
# sec 20.1 	 1
# sec 19.5 	 1
# sec 61.4 	 1
# sec 18.9 	 1
# sec >150 	 1
# sec 14.9 	 1
# sec 23.0 	 1
# sec 27.0 	 1
# sec 18.1 	 1
# sec 18.4 	 1
#
# LAB : 50942
# Count  1645
# None NEGATIVE 	 1347
# None POSITIVE 	 276
# None BORDERLINE POSITIVE 	 12
# None EQUIVOCAL 	 7
# None BORDERLINE POSITIVE -- C/W TITER OF ROUGHLY 10 MIU/ML 	 2
# None INDETERMINATE RESULT 	 1
#
# LAB : 51234
# Count  173
# None DONE 	 133
# None D 	 36
# None CANCEL 	 3
# None DOME 	 1
#
# LAB : 51489
# Count  134
# #/hpf <1 	 73
# #/hpf 2 	 25
# #/hpf 1 	 15
# #/hpf 3 	 8
# #/hpf 5 	 3
# #/hpf 4 	 2
# #/hpf <1 /HPF 	 2
# #/hpf 15 	 1
# #/hpf 8 	 1
# #/hpf 6 	 1
# #/hpf 0 	 1
# #/hpf 16 	 1
# #/hpf 7 	 1
#
# LAB : 50939
# Count  548
# None NEGATIVE 	 530
# None POSITIVE 	 13
# None NEG 	 4
# None BORDERLINE POSITIVE -- C/W TITER OF ROUGHLY 10 MIU/ML 	 1
#
# LAB : 50829
# Count  262
# None PLEURAL 	 212
# None OTHER 	 42
# None ASCITES 	 8
#
# LAB : 51286
# Count  8
# None NORMAL 	 7
# None NO ABNORMAL HYPER-RESPONSIVENESS TO LOW DOSE 	 1
#
# LAB : 50901
# Count  19
# None NEGATIVE 	 14
# None POSITIVE 	 5
#
# LAB : 50906
# Count  543
# mg/dL <50 	 60
# mg/dL 61 	 12
# mg/dL 77 	 11
# mg/dL 90 	 9
# mg/dL 120 	 9
# mg/dL LESS THAN 50 	 9
# mg/dL 96 	 9
# mg/dL 87 	 9
# mg/dL 98 	 9
# mg/dL 124 	 8
# mg/dL 52 	 8
# mg/dL 81 	 8
# mg/dL 110 	 8
# mg/dL 62 	 7
# mg/dL 55 	 7
# mg/dL 68 	 7
# mg/dL 130 	 6
# mg/dL 73 	 6
# mg/dL 104 	 6
# mg/dL 79 	 6
#
# LAB : 51331
# Count  52
# None DONE 	 44
# None D 	 8
#
# LAB : 51405
# Count  23
# None DONE 	 20
# None D 	 3
#
# LAB : 51233
# Count  37846
# None NORMAL 	 20934
# None 1+ 	 8874
# None 2+ 	 4003
# None 3+ 	 2823
# None OCCASIONAL 	 1211
# None 2 	 1
#
# LAB : 51372
# Count  156
# None I/E 	 114
# None INTRAC 	 26
# None EXTRAC 	 16
#
# LAB : 51011
# Count  22
# mg/dL 123.6 	 2
# mg/dL <1.0 	 1
# mg/dL 29.6 	 1
# mg/dL 25.8 	 1
# mg/dL 4.2 	 1
# mg/dL 33.9 	 1
# mg/dL 77.2 	 1
# mg/dL 186.3 	 1
# mg/dL 27 	 1
# mg/dL 17.0 	 1
# mg/dL 219 	 1
# mg/dL 48.3 	 1
# mg/dL 10.9 	 1
# mg/dL 156 	 1
# mg/dL 3.7 	 1
# mg/dL 140.3 	 1
# mg/dL 63.9 	 1
# mg/dL 12.5 	 1
# mg/dL LESS THAN 1 	 1
# mg/dL 20.9 	 1
#
# LAB : 51517
# Count  236
# #/lpf 0-2 	 113
# #/lpf <1 	 56
# #/lpf 1 	 13
# #/lpf 3-5 	 10
# #/lpf 3 	 9
# #/lpf 2 	 8
# #/lpf 4 	 6
# #/lpf 6-10 	 3
# #/lpf 17 	 2
# #/lpf 14 	 2
# #/lpf 24 	 2
# #/lpf 6 	 2
# #/lpf 22 	 1
# #/lpf 8 	 1
# #/lpf 23 	 1
# #/lpf 16 	 1
# #/lpf 10 	 1
# #/lpf 9 	 1
# #/lpf 38 	 1
# #/lpf 46 	 1
#
# LAB : 51092
# Count  7046
# None NEG 	 5616
# None POS 	 1427
# None NEGATIVE 	 2
# None POSITIVE 	 1
#
# LAB : 51309
# Count  59
# None DONE 	 49
# None D 	 10
#
# LAB : 51304
# Count  3
# None DONE 	 3
#
# LAB : 51315
# Count  124
# None DONE 	 100
# None D 	 24
#
# LAB : 51519
# Count  62074
# None NONE 	 55930
# None MANY 	 1673
# None FEW 	 1527
# None MOD 	 1345
# None OCC 	 839
# None RARE 	 654
# None 0 	 49
# None   	 25
# None NOTDONE 	 24
# None N 	 6
# None F 	 2
#
# LAB : 50937
# Count  948
# Pos/Neg POSITIVE 	 277
# Pos/Neg NEGATIVE 	 262
# None POSITIVE 	 224
# None NEGATIVE 	 180
# Pos/Neg NEG 	 2
# None BORDERLINE POSITIVE 	 1
# None EQUIVOCAL 	 1
# Pos/Neg BORDERLINE 	 1
#
# LAB : 51085
# Count  383
# +/- NEGATIVE 	 278
# +/- NEG 	 102
# +/- POSITIVE 	 2
# +/- POS 	 1
#
# LAB : 51412
# Count  258
# None DONE 	 216
# None D 	 42
#
# LAB : 51425
# Count  368
# None DONE 	 295
# None D 	 73
#
# LAB : 51027
# Count  46
# mEq/L 12 	 4
# mEq/L 31 	 4
# mEq/L 18 	 4
# mEq/L 16 	 3
# mEq/L 23 	 3
# mEq/L 26 	 2
# mEq/L 20 	 2
# mEq/L 13 	 2
# mEq/L 25 	 2
# mEq/L 7 	 2
# mEq/L 21 	 2
# mEq/L 19 	 2
# mEq/L 22 	 2
# mEq/L UNSATISFACTORY,SPECIMEN TOO VISCOUS 	 1
# mEq/L 47 	 1
# mEq/L LESS THAN 10 	 1
# mEq/L 14 	 1
# mEq/L 29 	 1
# mEq/L <5 	 1
# mEq/L 8 	 1
#
# LAB : 51268
# Count  31235
# None NORMAL 	 14579
# None 1+ 	 8127
# None OCCASIONAL 	 5592
# None 2+ 	 2569
# None 3+ 	 368
#
# LAB : 50854
# Count  1172
# None DONE 	 1171
# None 0.45 	 1
#
# LAB : 51192
# Count  113
# None DONE 	 96
# None D 	 17
#
# LAB : 50959
# Count  2
# None PROLACTIN ELEVATED, SO SAMPLE WAS TREATED WITH PEG, WHICH SHOWED 	 2
#
# LAB : 51100
# Count  21884
# mEq/L LESS THAN 10 	 1706
# mEq/L 10 	 483
# mEq/L 11 	 429
# mEq/L 12 	 390
# mEq/L 13 	 370
# mEq/L 15 	 355
# mEq/L 14 	 343
# mEq/L 18 	 307
# mEq/L 16 	 302
# mEq/L 19 	 301
# mEq/L 22 	 297
# mEq/L 17 	 292
# mEq/L <10 	 283
# mEq/L 23 	 281
# mEq/L 20 	 281
# mEq/L 24 	 280
# mEq/L 21 	 271
# mEq/L 25 	 263
# mEq/L 26 	 258
# mEq/L 32 	 247
#
# LAB : 51156
# Count  64
# None DONE 	 58
# None D 	 6
#
# LAB : 51487
# Count  65904
# None NEG 	 62290
# None POS 	 3585
# None   	 17
# None Neg 	 6
# None N 	 3
# None COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# None P 	 1
#
# LAB : 51293
# Count  2
# None NEGATIVE 	 2
#
# LAB : 50932
# Count  79
# None HOLD 	 79
#
# LAB : 51416
# Count  180
# None DONE 	 155
# None D 	 25
#
# LAB : 51314
# Count  100
# None DONE 	 82
# None D 	 18
#
# LAB : 50856
# Count  6816
# ug/mL NEG 	 5884
# ug/mL 5 	 24
# ug/mL 6 	 22
# ug/mL 8 	 15
# ug/mL 7 	 14
# ug/mL 6.0 	 14
# ug/mL 5.5 	 14
# ug/mL 9 	 13
# ug/mL 6.1 	 11
# ug/mL 5.6 	 11
# ug/mL 10 	 11
# ug/mL 5.0 	 11
# ug/mL 6.3 	 10
# ug/mL 5.2 	 9
# ug/mL 5.3 	 9
# ug/mL 5.1 	 9
# ug/mL 8.2 	 9
# ug/mL 5.7 	 8
# ug/mL 5.4 	 8
# ug/mL 5.8 	 8
#
# LAB : 51463
# Count  50019
# None FEW 	 13276
# None NONE 	 12874
# None OCC 	 6861
# None MOD 	 5795
# None MANY 	 4870
# None RARE 	 4586
# None NEG 	 912
# None 0 	 768
# None   	 27
# None NOTDONE 	 23
# None F 	 4
# None MO 	 3
# None O 	 2
# None 1 	 2
# None F' 	 2
# None  M 	 1
# None R 	 1
# None UNABLE TO QUANTITATE 	 1
# None LRG 	 1
# None 0CC 	 1
#
# LAB : 50886
# Count  118
# None HOLD 	 117
# None None 	 1
#
# LAB : 51411
# Count  463
# None DONE 	 375
# None D 	 88
#
# LAB : 51332
# Count  104
# None DONE 	 86
# None D 	 18
#
# LAB : 51252
# Count  35848
# None NORMAL 	 23401
# None 1+ 	 8102
# None OCCASIONAL 	 2106
# None 2+ 	 1670
# None 3+ 	 569
#
# LAB : 51003
# Count  66384
# ng/mL <0.01 	 14137
# ng/mL 0.02 	 3909
# ng/mL 0.03 	 3146
# ng/mL 0.04 	 2552
# ng/mL 0.01 	 2163
# ng/mL 0.05 	 1977
# ng/mL 0.06 	 1710
# ng/mL 0.07 	 1491
# ng/mL 0.08 	 1271
# ng/mL 0.09 	 1096
# ng/mL 0.10 	 1057
# ng/mL 0.11 	 908
# ng/mL 0.12 	 807
# ng/mL 0.13 	 758
# ng/mL 0.14 	 706
# ng/mL 0.15 	 602
# ng/mL 0.16 	 573
# ng/ml 0.02 	 554
# ng/ml 0.03 	 529
# ng/mL 0.18 	 515
#
# LAB : 50880
# Count  9103
# None NEG 	 8609
# None POS 	 483
# None NEGATIVE 	 8
# None ERROR 	 2
# None NEGATIVE - Level less than 10 miu/ml 	 1
#
# LAB : 50929
# Count  5897
# ug/mL <0.3 	 314
# ug/mL 0.4 	 215
# ug/mL 1.0 	 198
# ug/mL 0.7 	 188
# ug/mL 0.9 	 187
# ug/mL 0.5 	 187
# ug/mL 0.8 	 184
# ug/mL 0.6 	 178
# ug/mL 1.1 	 174
# ug/mL 1.2 	 173
# ug/mL 1.3 	 165
# ug/mL 0.3 	 164
# ug/mL 1.4 	 161
# ug/mL 1.5 	 141
# ug/mL 1.6 	 125
# ug/mL 1.7 	 111
# ug/mL 1.9 	 106
# ug/mL 1.8 	 101
# ug/mL 2.0 	 100
# ug/mL 2.4 	 90
#
# LAB : 51393
# Count  18
# None DONE 	 14
# None D 	 4
#
# LAB : 51154
# Count  54
# None DONE 	 49
# None D 	 5
#
# LAB : 51161
# Count  10
# None DONE 	 9
# None D 	 1
#
# LAB : 51413
# Count  29
# None DONE 	 27
# None D 	 2
#
# LAB : 51421
# Count  9
# None DONE 	 9
#
# LAB : 51414
# Count  1
# None DONE 	 1
#
# LAB : 51184
# Count  165
# None DONE 	 121
# None D 	 22
# None 191 	 1
# None 153 	 1
# None 186 	 1
# None 155 	 1
# None 74 	 1
# None 15 	 1
# None 264 	 1
# None 806 	 1
# None 242 	 1
# None 821 	 1
# None 4 	 1
# None 210 	 1
# None 3 	 1
# None 45 	 1
# None 132 	 1
# None 249 	 1
# None 538 	 1
# None 113 	 1
#
# LAB : 51342
# Count  249
# None DONE 	 249
#
# LAB : 51182
# Count  52
# None DONE 	 46
# None D 	 6
#
# LAB : 51188
# Count  64
# None DONE 	 53
# None D 	 8
# None 29 	 1
# None 6 	 1
# None 57 	 1
#
# LAB : 51318
# Count  3
# None DONE 	 3
#
# LAB : 51041
# Count  74
# mEq/L 3.0 	 4
# mEq/L 2.8 	 4
# mEq/L 5.3 	 3
# mEq/L GREATER THAN 10 	 3
# mEq/L 3.3 	 3
# mEq/L 4.0 	 3
# mEq/L 4.1 	 3
# mEq/L 6.6 	 2
# mEq/L 3.7 	 2
# mEq/L 2.9 	 2
# mEq/L 4.9 	 2
# mEq/L 8.7 	 2
# mEq/L 4.3 	 2
# mEq/L 3.5 	 2
# mEq/L 3.2 	 2
# mEq/L 4.7 	 2
# mEq/L 5.7 	 1
# mEq/L 3.9 	 1
# mEq/L 3.8 	 1
# mEq/L GREATER THAN 10.0 	 1
#
# LAB : 51396
# Count  2
# None DONE 	 2
#
# LAB : 51330
# Count  1
# None DONE 	 1
#
# LAB : 51333
# Count  47
# None DONE 	 40
# None D 	 7
#
# LAB : 51074
# Count  7043
# None NEG 	 6847
# None POS 	 194
# None NEGATIVE 	 2
#
# LAB : 51189
# Count  7
# None DONE 	 5
# None D 	 2
#
# LAB : 51187
# Count  23
# None DONE 	 14
# None D 	 9
#
# LAB : 51238
# Count  148
# None DONE 	 122
# None D 	 25
# None DOME 	 1
#
# LAB : 51090
# Count  7022
# None NEG 	 6672
# None POS 	 347
# None NEGATIVE 	 2
# None POSITIVE 	 1
#
# LAB : 51537
# Count  1
# None DONE 	 1
#
# LAB : 51180
# Count  658
# % DONE 	 76
# % 1 	 26
# % 0 	 23
# % 8 	 20
# % 18 	 18
# % 11 	 17
# % 9 	 16
# % 15 	 15
# % 17 	 15
# % 2 	 14
# % 14 	 14
# % 13 	 14
# % 25 	 14
# % 22 	 13
# % 20 	 13
# % 12 	 13
# % 26 	 13
# % 21 	 12
# % 5 	 11
# % D 	 11
#
# LAB : 51478
# Count  67506
# mg/dL NEG 	 57130
# mg/dL TR 	 2464
# mg/dL 100 	 2433
# mg/dL 1000 	 2247
# mg/dL 250 	 1559
# mg/dL 300 	 502
# mg/dL 150 	 399
# mg/dL 70 	 323
# mg/dL >1000 	 230
# mg/dL 500 	 185
# mg/dL   	 17
# mg/dL Neg 	 6
# mg/dL N 	 4
# mg/dL COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# None 1000 	 1
# None 100 	 1
# mg/dL 200 	 1
# None TR 	 1
# None 250 	 1
#
# LAB : 51216
# Count  1210
# None OCCASIONAL 	 1022
# None 1+ 	 172
# None 2+ 	 11
# None NORMAL 	 4
# None 3+ 	 1
#
# LAB : 50877
# Count  84
# IU/mL LESS THAN 20 	 56
# None ANTI-THYROGLOBULIN: NEGATIVE 	 14
# IU/mL 92 	 1
# None ANTI-THYROGLOBULIN: POSITIVE- 1:160 TITER 	 1
# IU/mL 22 	 1
# IU/mL 24 	 1
# IU/mL 2396 	 1
# IU/mL 62 	 1
# IU/mL 952 	 1
# None ANTI-THYROGLOBULIN:NEGATIVE 	 1
# IU/mL 929 	 1
# IU/mL <20 	 1
# IU/mL 167 	 1
# IU/mL 28 	 1
# IU/mL 50 	 1
# IU/mL 151 	 1
#
# LAB : 51323
# Count  61
# None DONE 	 55
# None D 	 6
#
# LAB : 51329
# Count  2
# None DONE 	 2
#
# LAB : 51178
# Count  65
# % DONE 	 59
# % D 	 6
#
# LAB : 51477
# Count  1
# None MOD 	 1
#
# LAB : 50989
# Count  23
# pg/mL LESS THAN 0.6 	 4
# pg/mL LESS THAN 0.5 	 2
# ng/dL 0.1 	 2
# pg/mL 0.8 	 2
# pg/mL 7.4 	 1
# pg/mL 3.4 	 1
# pg/mL 19 	 1
# pg/mL 0.6 	 1
# pg/mL 9.8 	 1
# pg/mL 3.1 	 1
# pg/mL 4.2 	 1
# ng/dL LESS THAN 0.05 	 1
# pg/mL 2.0 	 1
# pg/mL 11 	 1
# pg/mL 2.4 	 1
# pg/mL 22 	 1
# pg/mL 5.6 	 1
#
# LAB : 51499
# Count  270
# None FEW 	 78
# None OCC 	 61
# None RARE 	 55
# None MOD 	 43
# None MANY 	 21
# None   	 8
# None PRESENT 	 2
# None :PRESENT 	 1
# None R 	 1
#
# LAB : 51179
# Count  8
# None DONE 	 5
# None D 	 3
#
# LAB : 51465
# Count  65
# None FEW 	 45
# None MOD 	 10
# None OCC 	 5
# None RARE 	 3
# None MANY 	 1
# None NONE 	 1
#
# LAB : 51321
# Count  99
# None DONE 	 83
# None D 	 16
#
# LAB : 51076
# Count  848
# mEq/L LESS THAN 5 	 391
# None LESS THAN 5 	 207
# mEq/L <5 	 112
# mEq/L 6 	 11
# mEq/L LESS THAN 5.0 	 8
# mEq/L 8 	 6
# mEq/L 5 	 5
# mEq/L 10 	 5
# mEq/L 18 	 5
# mEq/L GREATER THAN 50 	 5
# None LESS THAN 5.0 	 4
# mEq/L 13 	 4
# mEq/L 11 	 4
# mEq/L 7 	 4
# mEq/L 17 	 4
# mEq/L >50 	 3
# None <5 	 3
# mEq/L 22 	 3
# mEq/L 15 	 3
# mEq/L 23 	 2
#
# LAB : 51473
# Count  1
# None MOD 	 1
#
# LAB : 51500
# Count  9
# None FEW 	 3
# None MOD 	 3
# None OCC 	 2
# None RARE 	 1
#
# LAB : 51215
# Count  93
# None DONE 	 76
# None D 	 17
#
# LAB : 51064
# Count  83
# mEq/L GREATER THAN 10 	 4
# mEq/L 27 	 2
# mEq/L 22 	 2
# mEq/L 19 	 2
# mEq/L 13.9 	 2
# mEq/L 55 	 2
# mEq/L 30 	 2
# mEq/L 4.7 	 2
# mEq/L 52 	 2
# mEq/L 34 	 2
# mEq/L 11 	 2
# mEq/L 5.0 	 2
# mEq/L GREATER THAN 10.0 	 2
# mEq/L 12 	 1
# mEq/L 13 	 1
# mEq/L 25 	 1
# mEq/L 22.1 	 1
# mEq/L 17 	 1
# mEq/L 21.6 	 1
# mEq/L 10.4 	 1
#
# LAB : 50921
# Count  10
# pg/mL 24 	 1
# pg/mL 42 	 1
# pg/mL 34 	 1
# pg/mL 19 	 1
# pg/mL 6 	 1
# pg/mL 219 	 1
# pg/mL 25 	 1
# pg/mL <30 	 1
# pg/mL 52 	 1
# pg/mL 20 	 1
#
# LAB : 50938
# Count  579
# None NEGATIVE 	 574
# None POSITIVE 	 3
# None BORDERLINE 	 2
#
# LAB : 50835
# Count  1183
# g/dL LESS THAN 1.0 	 295
# g/dL <1.0 	 185
# g/dL 1.0 	 58
# g/dL 1.5 	 58
# g/dL 1.2 	 54
# g/dL 1.3 	 54
# g/dL 1.1 	 53
# g/dL LESS THAN 1 	 47
# g/dL 1.4 	 41
# g/dL 1.6 	 39
# g/dL 1.7 	 36
# g/dL 1.8 	 30
# g/dL 1.9 	 28
# g/dL 2.0 	 24
# g/dL 2.2 	 23
# g/dL 2.1 	 21
# g/dL 2.3 	 12
# g/dL 2.5 	 11
# g/dL <1 	 9
# g/dL 2.4 	 8
#
# LAB : 50879
# Count  9051
# None NEG 	 8966
# None POS 	 75
# None NEGATIVE 	 8
# None ERROR 	 2
#
# LAB : 51420
# Count  214
# None DONE 	 181
# None D 	 33
#
# LAB : 51056
# Count  7
# None LIPASE = 36700 	 1
# None RF=16 IU/ML 	 1
# None PEP IS INDISTINGUISHABLE FROM THAT OF SERUM 	 1
# None POSITIVE ANA BY INDIRECT IMMUNOFLUORESCENCE AT 1:40 TITER 	 1
# None POSITIVE 	 1
# None FLUID LIPASE=162200 U/L 	 1
# None LIPASE = 8020 IU/L 	 1
#
# LAB : 51173
# Count  7
# None DONE 	 4
# None D 	 3
#
# LAB : 51194
# Count  570
# % DONE 	 75
# % 0 	 24
# % 1 	 15
# % 38 	 15
# % 40 	 14
# % 44 	 12
# % 61 	 12
# % 56 	 11
# % 47 	 11
# % 52 	 11
# % 53 	 11
# % D 	 11
# % 31 	 10
# % 63 	 9
# % 21 	 9
# % 80 	 9
# % 51 	 8
# % 41 	 8
# % 71 	 7
# % 58 	 7
#
# LAB : 50827
# Count  76995
# None /20 	 3081
# None 20/ 	 2683
# None 14/ 	 2645
# None 8/ 	 2571
# None 16/ 	 2365
# None 12/ 	 2296
# None 18/ 	 2284
# None /18 	 2059
# None /22 	 1984
# None /24 	 1950
# None /16 	 1916
# None /12 	 1735
# None /14 	 1685
# None 22/ 	 1499
# None 24/ 	 1456
# None /30 	 1332
# None /28 	 1276
# None /10 	 1270
# None 10/ 	 1216
# None /25 	 1123
#
# LAB : 50999
# Count  9028
# None NEG 	 8859
# None POS 	 159
# None NEGATIVE 	 8
# None ERROR 	 2
#
# LAB : 51400
# Count  256
# None DONE 	 215
# None D 	 41
#
# LAB : 50991
# Count  50
# ng/mL 4 	 4
# ng/mL UNABLE TO REPORT DUE TO PRESENCE OF ANTIBODIES TO THYROGLOBULIN 	 3
# ng/mL LESS THAN 0.2 	 3
# ng/mL 11 	 2
# ng/mL 8 	 2
# ng/mL 3 	 2
# ng/mL 128 	 1
# ng/mL UNABLE TO REPORT DUE TO ANTIBODIES 	 1
# ng/mL 189 	 1
# ng/mL 27 	 1
# ng/mL 9 	 1
# ng/mL 447 	 1
# ng/mL 1990 	 1
# ng/mL 630 	 1
# ng/mL 7 	 1
# ng/mL 324 	 1
# ng/mL 66 	 1
# ng/mL 916 	 1
# ng/mL 90 	 1
# ng/mL 0.6 	 1
#
# LAB : 51325
# Count  174
# None DONE 	 138
# None D 	 36
#
# LAB : 51312
# Count  10
# None DONE 	 10
#
# LAB : 51091
# Count  267
# None PRESUMPTIVELY NEGATIVE 	 205
# None PRESUMPTIVELY POSITIVE 	 42
# None PRESUMPTIVE NEGATIVE 	 5
# None PRESUMTIVELY NEGATIVE 	 5
# None PRESUMPIVELY NEGATIVE 	 2
# None PRESUMPTIVE POSITIVE 	 1
# None PRESUMTIVELY POSITIVE 	 1
# None PRESUMPTIVELY POSITITVE 	 1
# None PRESUPMTIVELY NEGATIVE 	 1
# None PRESUMPTIVELY POSTIVE 	 1
# None PRESUMPTIVELY NAGATIVE 	 1
# None UNABLE TO RESULT DUE TO LAB ERROR 	 1
# None PRESU,MPTIVELY NEGATIVE 	 1
#
# LAB : 51291
# Count  40
# None 1+ 	 15
# None OCCASIONAL 	 9
# None 2+ 	 8
# None NORMAL 	 5
# None 3+ 	 3
#
# LAB : 51258
# Count  2
# None INCREASED 	 1
# None INDETERMINANT 	 1
#
# LAB : 51115
# Count  153
# % 2 	 9
# % 3.0 	 9
# % 5.0 	 7
# % 2.0 	 7
# % 2.5 	 7
# % 6 	 5
# % 9 	 4
# % 9.0 	 4
# % 0 	 4
# % 14 	 4
# % <2.0 	 4
# % 3 	 3
# % 4 	 3
# % 3.5 	 3
# % 20 	 3
# % 7.5 	 3
# % LESS THAN 2 	 3
# % <2 	 3
# % 7.0 	 3
# % 13 	 2
#
# LAB : 51373
# Count  365
# None NONE 	 208
# None FEW 	 74
# None MOD 	 47
# None MANY 	 36
#
# LAB : 51507
# Count  140
# #/lpf 2 	 33
# #/lpf 0-2 	 25
# #/lpf 1 	 18
# #/lpf 4 	 14
# #/lpf 3 	 11
# #/lpf 0 	 7
# #/lpf 3-5 	 6
# #/lpf 6-10 	 3
# #/lpf 11-20 	 3
# #/lpf 7 	 3
# #/lpf 5 	 3
# #/lpf 6 	 3
# #/lpf 10 	 2
# #/lpf 20 	 1
# #/lpf   	 1
# #/lpf 8 	 1
# #/lpf 12 	 1
# #/lpf 19 	 1
# #/lpf 14 	 1
# #/lpf O 	 1
#
# LAB : 51474
# Count  2568
# None NEGATIVE NO EOS SEEN 	 2016
# None POSITIVE RARE EOS 	 431
# None POSITIVE MODERATE EOS 	 95
# None POSITIVE MANY EOS 	 22
# None NEGATIVE 	 4
#
# LAB : 51482
# Count  12341
# #/lpf 0-2 	 2792
# #/lpf 1 	 1539
# #/lpf 3-5 	 1025
# #/lpf 3 	 824
# #/lpf 2 	 706
# #/lpf 4 	 648
# #/lpf 6-10 	 429
# #/lpf <1 	 420
# #/lpf 5 	 343
# #/lpf 6 	 336
# #/lpf 7 	 270
# #/lpf 11-20 	 239
# #/lpf 8 	 238
# #/lpf 9 	 189
# #/lpf 12 	 170
# #/lpf 10 	 160
# #/lpf 13 	 128
# #/lpf 11 	 121
# #/lpf 21-50 	 115
# #/lpf 14 	 95
#
# LAB : 51247
# Count  57
# None OCCASIONAL 	 26
# None 1+ 	 25
# None 2+ 	 3
# None NORMAL 	 3
#
# LAB : 50926
# Count  87
# mIU/mL <1.0 	 8
# mIU/L <1.0 	 5
# mIU/mL 12 	 3
# mIU/mL 2.6 	 2
# mIU/mL 31 	 2
# mIU/mL 28 	 2
# mIU/L 1.7 	 2
# mIU/mL 2.3 	 2
# mIU/mL 53 	 2
# mIU/L 9.8 	 1
# mIU/mL 5.8 	 1
# mIU/mL 5.9 	 1
# mIU/mL 3.6 	 1
# mIU/mL 5.0 	 1
# mIU/L 51 	 1
# mIU/L 1.1 	 1
# mIU/L 1.0 	 1
# mIU/mL 2.5 	 1
# mIU/mL 1.1 	 1
# mIU/mL 5.5 	 1
#
# LAB : 50955
# Count  2316
# None HOLD 	 2316
#
# LAB : 50933
# Count  13110
# None HOLD 	 13103
# None DONE 	 7
#
# LAB : 51239
# Count  147
# None DONE 	 121
# None D 	 25
# None DONED 	 1
#
# LAB : 51071
# Count  7055
# None NEG 	 6885
# None POS 	 167
# None POSITIVE 	 2
# None NEGATIVE 	 1
#
# LAB : 51079
# Count  7104
# None NEG 	 6515
# None POS 	 586
# None NEGATIVE 	 3
#
# LAB : 51408
# Count  54
# None DONE 	 46
# None D 	 7
# None 16 	 1
#
# LAB : 51516
# Count  61284
# #/hpf 0-2 	 14536
# #/hpf 0 	 8639
# #/hpf 3-5 	 6790
# #/hpf 2 	 3355
# #/hpf 6-10 	 3157
# #/hpf 1 	 3089
# #/hpf 3 	 2329
# #/hpf >50 	 2303
# #/hpf 11-20 	 2081
# #/hpf 21-50 	 1488
# #/hpf 5 	 1331
# #/hpf 4 	 990
# #/hpf 6 	 947
# #/hpf 8 	 668
# #/hpf <1 	 638
# #/hpf 9 	 548
# #/hpf 7 	 487
# #/hpf 11 	 409
# #/hpf 10 	 377
# #/hpf 12 	 361
#
# LAB : 50946
# Count  432
# mIU/mL <5 	 326
# mIU/mL LESS THAN 5 	 22
# mIU/mL 5 	 4
# mIU/mL 6 	 4
# mIU/mL LESS THAN 5 IS NEGATIVE 	 3
# mIU/mL 7 	 3
# mIU/mL 19 	 2
# mIU/mL 10 	 2
# mIU/mL 13 	 2
# mIU/mL 22 	 2
# mIU/mL 54376 	 1
# mIU/mL 20357 	 1
# mIU/mL 382 	 1
# mIU/mL 17 	 1
# mIU/mL 17705 	 1
# mIU/mL 25 	 1
# mIU/mL 2032 	 1
# mIU/mL 2369 	 1
# mIU/mL 10816 	 1
# mIU/mL 320 	 1
#
# LAB : 51158
# Count  59
# None DONE 	 53
# None D 	 6
#
# LAB : 51281
# Count  18
# sec 17.2 	 2
# sec 19.5 	 2
# sec 16.3 	 1
# sec 18.5 	 1
# sec 16.1 	 1
# sec 19.3 	 1
# sec 19.9 	 1
# sec DONE AT BRIGHAM AND WOMENS 	 1
# sec 17.7 	 1
# sec DONE AT BRIGHAM AND WOMENS HOSPITAL 	 1
# sec 18.7 	 1
# sec 19.7 	 1
# sec 18.4 	 1
# sec 17.9 	 1
# sec 16.0 	 1
# sec 18.1 	 1
#
# LAB : 51069
# Count  480
# mg/dL <0.3 	 24
# mg/dL 0.3 	 12
# mg/dL 0.5 	 10
# mg/dL 2.4 	 9
# mg/dL 0.4 	 7
# mg/dL 1.1 	 7
# mg/dL 3.4 	 7
# mg/dL 1.2 	 6
# mg/dL 1.6 	 6
# mg/dL 1.5 	 6
# mg/dL 3.7 	 6
# mg/dL 4.6 	 6
# mg/dL 0.6 	 6
# mg/dL 1.4 	 5
# mg/dL 2.7 	 5
# mg/dL 2.3 	 5
# mg/dL 2.9 	 5
# mg/dL 10.4 	 4
# mg/dL 3.8 	 4
# mg/dL 7.0 	 4
#
# LAB : 51228
# Count  175
# U/mL LESS THAN 0.1 	 8
# U/mL 0.22 	 7
# U/mL 0.16 	 7
# U/mL 0.26 	 6
# U/mL 0.29 	 6
# U/mL 0.30 	 6
# U/mL 0.48 	 5
# U/mL 0.56 	 5
# U/mL LESS THAN 0.13 	 5
# U/mL <0.10 	 5
# U/mL 0.33 	 5
# U/mL 0.20 	 4
# U/mL 0.43 	 4
# U/mL 0.19 	 4
# U/mL 0.38 	 4
# U/mL 0.28 	 4
# U/mL 0.12 	 3
# U/mL 0.61 	 3
# U/mL 0.23 	 3
# U/mL 0.50 	 3
#
# LAB : 51470
# Count  16
# None FEW 	 7
# None OCC 	 3
# None MANY 	 2
# None RARE 	 2
# None MOD 	 2
#
# LAB : 51479
# Count  5758
# #/lpf 0-2 	 1959
# #/lpf 3-5 	 639
# #/lpf 1 	 501
# #/lpf <1 	 324
# #/lpf 3 	 315
# #/lpf 2 	 287
# #/lpf 4 	 254
# #/lpf 6-10 	 180
# #/lpf 5 	 151
# #/lpf 6 	 143
# #/lpf 7 	 97
# #/lpf 8 	 82
# #/lpf 11-20 	 69
# #/lpf 0-2 COARSE GRANULAR CASTS 	 65
# #/lpf 9 	 62
# #/lpf 12 	 54
# #/lpf 10 	 49
# #/lpf 11 	 39
# #/lpf 13 	 38
# #/lpf 15 	 33
#
# LAB : 51287
# Count  7242
# None OCCASIONAL 	 3948
# None 1+ 	 2981
# None 2+ 	 273
# None NORMAL 	 25
# None 3+ 	 15
#
# LAB : 51197
# Count  833
# None OCCASIONAL 	 425
# None 1+ 	 363
# None 2+ 	 35
# None 3+ 	 6
# None NORMAL 	 4
#
# LAB : 51350
# Count  13
# None CANCEL 	 12
# None D 	 1
#
# LAB : 51523
# Count  6403
# None HOLD 	 6401
# None DONE 	 2
#
# LAB : 51278
# Count  2024
# None NORMAL 	 2006
# None 1+ 	 18
#
# LAB : 51520
# Count  1
# None ANTI-MICROSOMAL: NEGATIVE 	 1
#
# LAB : 51002
# Count  8917
# ng/ml <0.3 	 3354
# ng/ml GREATER THAN 50 	 671
# ng/ml 0.3 	 315
# ng/ml 0.4 	 236
# ng/ml 0.5 	 196
# ng/ml 0.6 	 154
# ng/ml 0.7 	 149
# ng/ml 0.8 	 143
# ng/ml GREATER THAN 50.0 	 112
# ng/ml 0.9 	 109
# ng/ml 1.1 	 103
# ng/ml 1.0 	 102
# ng/ml 1.2 	 91
# ng/ml 1.4 	 79
# ng/ml 1.6 	 77
# ng/ml 1.5 	 75
# ng/ml 1.3 	 70
# ng/ml 1.7 	 56
# ng/ml 1.8 	 55
# ng/ml 1.9 	 53
#
# LAB : 50990
# Count  191
# ug/mL <0.8 	 35
# ug/ml 4.5 	 6
# ug/ml 3.4 	 4
# ug/ml 6.6 	 4
# ug/ml 5.4 	 3
# ug/ml 4.9 	 3
# ug/mL LESS THAN 0.8 	 3
# ug/mL 4.7 	 3
# ug/ml 3.7 	 3
# ug/ml 3.3 	 3
# ug/mL 11.3 	 2
# ug/ml 7.4 	 2
# ug/mL 2.4 	 2
# ug/ml 5.8 	 2
# ug/ml 5.7 	 2
# ug/ml 7.1 	 2
# ug/mL 13.0 	 2
# ug/ml 8.8 	 2
# ug/ml 2.3 	 2
# ug/ml 4.6 	 2
#
# LAB : 51220
# Count  28
# None NEGATIVE 	 22
# None POSITIVE 	 6
#
# LAB : 51339
# Count  145
# None DONE 	 145
#
# LAB : 51490
# Count  10
# None RARE 	 4
# None OCC 	 4
# None FEW 	 1
# None MOD 	 1
#
# LAB : 51512
# Count  9515
# None RARE 	 3987
# None FEW 	 2269
# None OCC 	 1710
# None MOD 	 991
# None MANY 	 551
# None 1 	 2
# None   	 2
# None 0 	 1
# None FEW] 	 1
# None MO 	 1
#
# LAB : 51460
# Count  132
# None NEGATIVE 	 104
# None POSITIVE 	 28
#
# LAB : 50922
# Count  6746
# mg/dL NEG 	 4958
# mg/dL 108 	 14
# mg/dL 163 	 13
# mg/dL 48 	 12
# mg/dL 14 	 12
# mg/dL 15 	 11
# mg/dL 17 	 11
# mg/dL 152 	 10
# mg/dL 29 	 10
# mg/dL 197 	 10
# mg/dL 274 	 10
# mg/dL 65 	 10
# mg/dL 161 	 10
# mg/dL 193 	 9
# mg/dL 229 	 9
# mg/dL 69 	 9
# mg/dL 252 	 9
# mg/dL 129 	 9
# mg/dL 273 	 9
# mg/dL 116 	 9
#
# LAB : 50873
# Count  1155
# None NEGATIVE 	 862
# None POSITIVE 	 292
# None POSITIVE -- C/W TITER OF MORE THAN 100 MIU/ML 	 1
#
# LAB : 51515
# Count  93
# #/lpf 0-2 	 43
# #/lpf <1 	 21
# #/lpf 1 	 13
# #/lpf 3-5 	 7
# #/lpf 2 	 5
# #/lpf 3 	 3
# #/lpf 4 	 1
#
# LAB : 50899
# Count  469
# ug/mL <1.0 	 38
# ug/mL 5.8 	 12
# ug/mL 4.1 	 11
# ug/mL 5.3 	 10
# ug/mL 5.9 	 10
# ug/mL 7.3 	 9
# ug/mL 5.2 	 9
# ug/mL <0.5 	 9
# ug/mL 5.5 	 8
# ug/mL 6.7 	 7
# ug/mL 5.7 	 7
# ug/mL 4.7 	 7
# ug/mL 6.3 	 7
# ug/mL 4.9 	 7
# ug/mL 5.1 	 7
# ug/mL 3.9 	 7
# ug/mL 3.2 	 7
# ug/mL 3.5 	 6
# ug/mL 4.3 	 6
# ug/mL 5.6 	 6
#
# LAB : 51391
# Count  20
# None DONE 	 19
# None D 	 1
#
# LAB : 51511
# Count  30
# None RARE 	 22
# None OCC 	 4
# None FEW 	 2
# None MOD 	 2
#
# LAB : 51135
# Count  7
# None NORMAL 	 7
#
# LAB : 51513
# Count  838
# None RANDOM 	 736
# None UNK 	 43
# None CLEAN 	 28
# None CATH 	 6
# None Random 	 3
# None   	 2
# None 3 	 2
# None 517L 	 1
# None 1.009 	 1
# None 1.044 	 1
# None ? 	 1
# None 1.004 	 1
# None A.AB 	 1
# None 175M 	 1
# None 1674M 	 1
# None 82G 	 1
# None 11104F 	 1
# None 2364L 	 1
# None 845M 	 1
# None 383E 	 1
#
# LAB : 51308
# Count  3
# None DONE 	 2
# None D 	 1
#
# LAB : 50871
# Count  232
# None NEGATIVE 	 227
# None POSITIVE 	 4
# None POSITIVE AT A TITER OF 1:80 	 1
#
# LAB : 51025
# Count  390
# g/dL 2.8 	 25
# g/dL 3.1 	 25
# g/dL LESS THAN 1.0 	 24
# g/dL 2.9 	 24
# g/dL 3.0 	 22
# g/dL 2.7 	 21
# g/dL 3.3 	 16
# g/dL 3.2 	 16
# g/dL 2.6 	 16
# g/dL 2.1 	 14
# g/dL 2.5 	 14
# g/dL 2.3 	 13
# g/dL 2.2 	 12
# g/dL 3.5 	 12
# g/dL 2.4 	 11
# g/dL 1.7 	 10
# g/dL 3.4 	 10
# g/dL 2.0 	 9
# g/dL 3.6 	 9
# g/dL 1.5 	 8
#
# LAB : 51488
# Count  13
# #/hpf 0 	 4
# #/hpf <1 	 2
# #/hpf 1 	 2
# #/hpf ERROR 	 1
# #/hpf 3-5 	 1
# #/hpf 2 	 1
# #/hpf 0-2 	 1
# #/hpf   	 1
#
# LAB : 51370
# Count  156
# None NEG 	 127
# None POS 	 28
# None UNDEF 	 1
#
# LAB : 51171
# Count  6
# None DONE 	 4
# None D 	 2
#
# LAB : 50920
# Count  24626
# None See Comments 	 24626
#
# LAB : 51316
# Count  2
# None DONE 	 2
#
# LAB : 51406
# Count  124
# None DONE 	 33
# #/uL DONE 	 31
# #/uL D 	 12
# #/uL 24 	 2
# #/uL 84 	 1
# #/uL 48 	 1
# #/uL 1026 	 1
# #/uL 3242 	 1
# #/uL 518 	 1
# #/uL 497 	 1
# #/uL 2332 	 1
# #/uL 54 	 1
# #/uL 2249 	 1
# #/uL 1213 	 1
# #/uL 1263 	 1
# #/uL 2047 	 1
# #/uL 169 	 1
# #/uL 103 	 1
# #/uL 1864 	 1
# #/uL 3226 	 1
#
# LAB : 50958
# Count  76
# mIU/mL <1.0 	 16
# mIU/L <1.0 	 9
# mIU/mL 2.2 	 3
# mIU/mL 6.8 	 3
# mIU/mL 15 	 3
# mIU/mL 16 	 3
# mIU/L 2.8 	 2
# mIU/mL 4.8 	 2
# mIU/mL 3.5 	 2
# mIU/mL 10 	 2
# mIU/mL 4.7 	 2
# mIU/mL 13 	 2
# mIU/L 1.4 	 2
# mIU/mL 28 	 1
# mIU/mL LESS THAN 1.0 	 1
# mIU/mL 1.7 	 1
# mIU/L 39 	 1
# mIU/L 7.6 	 1
# mIU/mL 23 	 1
# mIU/mL 8.0 	 1
#
# LAB : 51172
# Count  92
# None DONE 	 75
# None D 	 17
#
# LAB : 51394
# Count  14
# None DONE 	 13
# None D 	 1
#
# LAB : 51086
# Count  421
# None NO MONOCLONAL IMMUNOGLOBULIN SEEN 	 307
# None NEGATIVE FOR BENCE-JONES PROTEIN 	 40
# None MONOCLONAL FREE (BENCE-JONES) KAPPA DETECTED 	 9
# None MONOCLONAL FREE (BENCE-JONES) LAMBDA DETECTED 	 4
# None MONOCLONAL FREE (BENCE-JONES) LAMBDA 	 3
# None TRACE MONOCLONAL FREE (BENCE-JONES) LAMBDA DETECTED 	 3
# None NO PROTEIN DETECTED 	 3
# None MONOCLONAL FREE (BENCE-JONES) LAMBDA CONFIRMED 	 2
# None MONOCLONAL IGG LAMBDA 	 2
# None MONOCLONAL FREE (BENCE JONES) KAPPA DETECTED 	 2
# None MONOCLONAL FREE (BENCE-JONES) KAPPA 	 2
# None MONOCLONAL IGG KAPPA DETECTED 	 2
# None TWO TRACE MONOCLONAL FREE (BENCE-JONES) KAPPA DETECTED 	 1
# None TWO TRACE MONOCLONAL FREE (BENCE-JONES) KAPPA BANDS DETECTED 	 1
# None A BAND OF MONOCLONAL FREE (BENCE-JONES) KAPPA IS SEEN 	 1
# None TRACE MONOCLONAL INTACT IGG LAMBDA DETECTED 	 1
# None TWO BANDS OF FREE (BENCE JONES) LAMBDA SEEN 	 1
# None TRACE BANDS OF MONOCLONAL INTACT IGG LAMBDA 	 1
# None MONOCLONAL IGG KAPPA AND 	 1
# None NO DEFINITE M PROTEIN SEEN 	 1
#
# LAB : 51299
# Count  83
# % GREATER THAN 200 	 16
# % >200 	 7
# % 68 	 2
# % 121 	 2
# % 59 	 2
# % 193 	 2
# % 60 	 2
# % 180 	 1
# % 185 	 1
# % 174 	 1
# % 28 	 1
# % 126 	 1
# % 131 	 1
# % 200 	 1
# % 169 	 1
# % 26 	 1
# % 181 	 1
# % 192 	 1
# % 41 	 1
# % 47 	 1
#
# LAB : 50828
# Count  59806
# None CONTROLLED 	 28425
# None SPONTANEOUS 	 18192
# None IMV 	 13189
#
# LAB : 51399
# Count  180
# None DONE 	 155
# None D 	 25
#
# LAB : 51193
# Count  50
# None DONE 	 44
# None D 	 6
#
# LAB : 51445
# Count  228
# % 2.5 	 27
# % 2.0 	 19
# % 2 	 13
# % 4.0 	 11
# % 4.5 	 9
# % 3 	 9
# % 3.0 	 8
# % 5 	 7
# % 0 	 6
# % 3.5 	 6
# % 5.5 	 6
# % 7.0 	 5
# % 6.0 	 5
# % <2.0 	 5
# % 22 	 4
# % 4 	 4
# % 10.0 	 4
# % 7 	 4
# % 1.0 	 3
# % 8.0 	 3
#
# LAB : 51046
# Count  962
# g/dL LESS THAN 1.0 	 102
# g/dL <1.0 	 92
# g/dL 1.2 	 72
# g/dL 1.3 	 68
# g/dL 1.1 	 61
# g/dL 1.4 	 54
# g/dL 1.5 	 50
# g/dL 1.6 	 49
# g/dL 1.7 	 48
# g/dL 1.0 	 44
# g/dL 1.8 	 44
# g/dL 1.9 	 40
# g/dL 2.0 	 32
# g/dL 2.1 	 29
# g/dL 2.3 	 23
# g/dL 2.2 	 22
# g/dL 2.5 	 19
# g/dL 2.4 	 18
# g/dL 2.6 	 15
# g/dL LESS THAN 1 	 15
#
# LAB : 51225
# Count  35
# % <0.5 	 14
# % 0.8 	 2
# % 2.0 	 2
# % 0.6 	 1
# % 5.8 	 1
# % 5.2 	 1
# % 0.7 	 1
# % 75.3 	 1
# % 12.8 	 1
# % 2.6 	 1
# % 6.3 	 1
# % 43.5 	 1
# % 1.8 	 1
# % 37.2 	 1
# % 1.0 	 1
# % 1.1 	 1
# % 42 	 1
# % 16.0 	 1
# % 2.4 	 1
# % 26.8 	 1
#
# LAB : 51335
# Count  75
# None DONE 	 58
# None D 	 17
#
# LAB : 51098
# Count  809
# +/- MULTIPLE PROTEIN BANDS SEEN, WITH ALBUMIN PREDOMINATING 	 296
# +/- ONLY ALBUMIN DETECTED 	 157
# +/- NO PROTEIN DETECTED 	 100
# None MULTIPLE PROTEIN BANDS SEEN, WITH ALBUMIN PREDOMINATING 	 84
# None NO PROTEIN DETECTED 	 47
# None NEGATIVE FOR BENCE-JONES PROTEIN 	 37
# None ABNORMAL BAND IN GAMMA REGION 	 13
# +/- ABNORMAL BAND IN GAMMA REGION 	 11
# +/- ALBUMIN ONLY 	 6
# None ONLY ALBUMIN DETECTED 	 6
# +/- None 	 5
# None MULTIPLE BANDS SEEN 	 4
# +/- NON-SELECTIVE PROTEINURIA PATTERN 	 4
# None ALBUMIN IS THE ONLY PROTEIN DETECTED 	 3
# +/- ALBUMIN AND ONE OTHER BAND SEEN 	 3
# None TWO ABNORMAL BANDS IN GAMMA REGION 	 2
# None NON-SELECTIVE PROTEINURIA PATTERN 	 2
# +/- ALBUMIN PLUS ONE OTHER BAND SEEN 	 2
# None NEGATIVE 	 2
# +/- TWO ABNORMAL BANDS 	 1
#
# LAB : 51402
# Count  215
# None DONE 	 182
# None D 	 33
#
# LAB : 51303
# Count  125
# None DONE 	 101
# None D 	 24
#
# LAB : 50948
# Count  381
# None NO MONOCLONAL IMMUNOGLOBULIN SEEN 	 255
# None MONOCLONAL IGG KAPPA DETECTED 	 10
# None MONOCLONAL IGG LAMBDA DETECTED 	 7
# None TRACE MONOCLONAL IGG KAPPA DETECTED 	 7
# None MONOCLONAL IGG KAPPA SEEN 	 6
# None MONOCLONAL IGM LAMBDA DETECTED 	 5
# None MONOCLONAL IGG LAMBDA SEEN 	 4
# None TRACE MONOCLONAL IGG KAPPA IDENTIFIED 	 3
# None MONOCLONAL IGA KAPPA DETECTED 	 3
# None MONOCLONAL IGA KAPPA CONFIRMED 	 3
# None MONOCLONAL IGM KAPPA SEEN 	 2
# None MONOCLONAL IGG KAPPA IDENTIFIED 	 2
# None MONOCLONAL IGM KAPPA DETECTED 	 2
# None MONOCLONAL IGG LAMBDA IDENTIFIED 	 2
# None TRACE MONOCLONAL IGG LAMBDA DETECTED 	 2
# None MONOCLONAL IGG KAPPA 	 2
# None NO DEFINITIVE MONOCLONAL PROTEIN IDENTIFIED 	 2
# None TWO TRACE MONOCLONAL IGG LAMBDA BANDS DETECTED 	 1
# None THEY MIGRATE SO CLOSE TO EACH OTHER THEY APPEAR AS ONE PEP BAND 	 1
# None MONOCLONAL IGM LAMBDA CONFIRMED 	 1
#
# LAB : 51176
# Count  670
# % DONE 	 123
# % D 	 24
# % 83 	 17
# % 74 	 16
# % 79 	 16
# % 87 	 14
# % 76 	 14
# % 1 	 14
# % 84 	 12
# % 75 	 12
# % 81 	 12
# % 89 	 12
# % 77 	 12
# % 80 	 12
# % 0 	 11
# % 85 	 11
# % 82 	 11
# % 78 	 11
# % 73 	 10
# % 88 	 10
#
# LAB : 50855
# Count  1172
# None DONE 	 1171
# None 7.3 	 1
#
# LAB : 51311
# Count  3
# None DONE 	 3
#
# LAB : 51392
# Count  37
# None DONE 	 27
# None D 	 10
#
# LAB : 50919
# Count  4962
# None HOLD 	 4961
# None DONE 	 1
#
# LAB : 51168
# Count  171
# None DONE 	 118
# None D 	 22
# None LESS THAN 1 	 8
# None LESS THAN 3 	 4
# None 0 	 3
# None LESS THAN 2 	 3
# None 2 	 3
# None 1 	 2
# None LESS THAN 5 	 1
# None 4 	 1
# None 0.87 	 1
# None 0.9 	 1
# None 0.12 	 1
# None 5 	 1
# None LESS THAN 10 	 1
# None 0.06 	 1
#
# LAB : 51319
# Count  130
# None DONE 	 106
# None D 	 24
#
# LAB : 51229
# Count  429
# U/mL LESS THAN 0.1 	 32
# U/mL 0.53 	 11
# U/mL 0.28 	 8
# U/mL 0.36 	 7
# U/mL 0.76 	 7
# U/mL GREATER THAN 1.0 	 7
# U/mL 0.44 	 7
# U/mL 0.54 	 7
# U/mL LESS THAN 0.13 	 7
# U/mL 0.22 	 7
# U/mL 0.13 	 6
# U/mL 0.31 	 6
# U/mL 0.52 	 6
# U/mL <0.13 	 6
# U/mL 0.62 	 6
# U/mL 0.64 	 5
# U/mL 0.33 	 5
# U/mL 0.70 	 5
# U/mL 0.51 	 5
# U/mL 0.80 	 5
#
# LAB : 51326
# Count  124
# None DONE 	 101
# None D 	 23
#
# LAB : 51292
# Count  2016
# None OCCASIONAL 	 1044
# None 1+ 	 823
# None 2+ 	 128
# None 3+ 	 13
# None NORMAL 	 8
#
# LAB : 51403
# Count  5
# None DONE 	 5
#
# LAB : 51219
# Count  101
# None SENT 	 40
# None DONE 	 27
# None D 	 15
# None AVAILABLE AT THE EAST CAMPUS LAB 	 8
# None AVAILABLE AT THE WEST CAMPUS LAB 	 4
# None S 	 2
# None SEND 	 2
# None WEST CAMPUS 	 1
# None LEFTINLABFORMD 	 1
# None EAST 	 1
#
# LAB : 51334
# Count  59
# None DONE 	 53
# None D 	 6
#
# LAB : 51422
# Count  279
# % 7.0 	 11
# % 3.0 	 11
# % 4.5 	 11
# % 5.0 	 9
# % 0 	 9
# % 5 	 9
# % <2.0 	 8
# % 3.5 	 7
# % 2.5 	 7
# % 6.5 	 6
# % 10.0 	 6
# % 8.0 	 6
# % 8.5 	 6
# % 12.0 	 6
# % 2.0 	 6
# % 14.0 	 5
# % <2 	 5
# % 15.0 	 5
# % 9.5 	 5
# % 8 	 4
#
# LAB : 51242
# Count  2
# % ERROR 	 2
#
# LAB : 51159
# Count  54
# None DONE 	 49
# None D 	 5
#
# LAB : 51404
# Count  308
# None DONE 	 226
# None D 	 36
# None 74 	 3
# None 72 	 2
# None 66.0 	 1
# None 63 	 1
# None 79.7 	 1
# None 58.7 	 1
# None 82.1 	 1
# None 61.9 	 1
# None 60.6 	 1
# None 70 	 1
# None 74.9 	 1
# None 51.5 	 1
# None 73.0 	 1
# None 68.2 	 1
# None 84.3 	 1
# None 73.8 	 1
# None 78.9 	 1
# None 69.8 	 1
#
# LAB : 51295
# Count  7
# None DONE 	 6
# None D 	 1
#
# LAB : 51260
# Count  9761
# None 1+ 	 6025
# None OCCASIONAL 	 3235
# None 2+ 	 466
# None NORMAL 	 23
# None 3+ 	 12
#
# LAB : 51294
# Count  4294
# None OCCASIONAL 	 2289
# None 1+ 	 1627
# None 2+ 	 334
# None 3+ 	 27
# None NORMAL 	 17
#
# LAB : 51152
# Count  144
# None DONE 	 121
# None D 	 22
# None 14 	 1
#
# LAB : 51266
# Count  30161
# None NORMAL 	 13259
# None LOW 	 7402
# None VERY LOW 	 5424
# None HIGH 	 1651
# None VERY HIGH 	 1141
# None RARE 	 793
# None UNABLE TO ESTIMATE DUE TO PLATELET CLUMPS 	 491
#
# LAB : 51164
# Count  183
# None DONE 	 126
# None D 	 28
# None 0 	 3
# None 5 	 2
# None 10 	 2
# None 6 	 1
# None 147 	 1
# None 0.6 	 1
# None LESS THAN 2 	 1
# None 19 	 1
# None 87 	 1
# None 2 	 1
# None 30 	 1
# None 41 	 1
# None 4.3 	 1
# None 3 	 1
# None 17 	 1
# None 233 	 1
# None 20 	 1
# None 51 	 1
#
# LAB : 50943
# Count  2106
# None NEGATIVE 	 1836
# None POSITIVE 	 254
# None EQUIVOCAL 	 7
# None INDETERMINATE RESULT 	 7
# None POS 	 1
# None INDETERMINATE 	 1
#
# LAB : 51147
# Count  964
# None OCCASIONAL 	 772
# None 1+ 	 147
# None 2+ 	 42
# None NORMAL 	 3
#
# LAB : 50913
# Count  197
# None NO CRYOGLOBULIN DETECTED 	 124
# None NEGATIVE 	 54
# None POSITIVE 	 9
# None TRACE POSITIVE 	 4
# None TRACE CRYOGLOBULIN DETECTED 	 2
# None UNABLE TO INTERPRET 	 1
# None POSITIVE FOR CRYOGLOBULIN 	 1
# None TRACE POSITIVE FOR CRYOGLOBULIN 	 1
# None UNINTERPRETABLE DUE TO HEMOLYSIS 	 1
#
# LAB : 51231
# Count  463
# None OCCASIONAL 	 284
# None 1+ 	 157
# None NORMAL 	 11
# None 2+ 	 10
# None 3+ 	 1
#
# LAB : 51103
# Count  1822
# None HOLD 	 1820
# None DONE 	 2
#
# LAB : 51495
# Count  32
# None OCC 	 13
# None RARE 	 11
# None FEW 	 4
# None MOD 	 3
# None MANY 	 1
#
# LAB : 51504
# Count  2
# None MANY 	 1
# None MOD 	 1
#
# LAB : 51493
# Count  60883
# #/hpf 0-2 	 11115
# #/hpf 0 	 8033
# #/hpf 3-5 	 5751
# #/hpf >50 	 4326
# #/hpf 6-10 	 3594
# #/hpf 1 	 3249
# #/hpf 11-20 	 2763
# #/hpf 2 	 2753
# #/hpf 21-50 	 2330
# #/hpf 3 	 1711
# #/hpf 5 	 1047
# #/hpf 6 	 772
# #/hpf 4 	 725
# #/hpf >1000 	 656
# #/hpf <1 	 623
# #/hpf 8 	 593
# #/hpf 9 	 459
# #/hpf 7 	 454
# #/hpf 11 	 400
# #/hpf 12 	 333
#
# LAB : 50981
# Count  6385
# mg/dL NEG 	 6024
# mg/dL 4 	 50
# mg/dL 5 	 20
# mg/dL 6 	 15
# mg/dL NEGATIVE 	 13
# mg/dL 9 	 12
# mg/dL 7 	 8
# mg/dL 31 	 6
# mg/dL 23 	 6
# mg/dL 28 	 6
# mg/dL 11 	 6
# mg/dL 17 	 6
# mg/dL 19 	 5
# mg/dL 8 	 5
# mg/dL 15 	 5
# mg/dL 33 	 5
# mg/dL 36 	 5
# mg/dL 26 	 5
# mg/dL 16 	 4
# mg/dL 41 	 4
#
# LAB : 51481
# Count  108
# None NEGATIVE 	 90
# None POSITIVE 	 18
#
# LAB : 51472
# Count  4
# None OCC 	 2
# None FEW 	 1
# None MOD 	 1
#
# LAB : 51492
# Count  72632
# mg/dL NEG 	 28978
# mg/dL 30 	 15859
# mg/dL TR 	 14181
# mg/dL 100 	 6353
# mg/dL 25 	 2007
# mg/dL 500 	 1685
# mg/dL 75 	 1316
# mg/dL >300 	 1249
# mg/dL 300 	 465
# mg/dL 150 	 400
# mg/dL 600 	 63
# mg/dL   	 37
# mg/dL >600 	 16
# mg/dL 15 	 12
# mg/dL COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# mg/dL Neg 	 2
# None NEG 	 2
# mg/dL NEGATIVE 	 1
# mg/dL N 	 1
# None TR 	 1
#
# LAB : 51207
# Count  32
# None POS 	 16
# None FACTOR VIII INHIBITOR IN BETHSDA UNITS/ML = 2.0 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML =14.5 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML=15.2 	 1
# None NO FACTOR INHIBITOR FOUND IN FACTORS 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML=64 	 1
# None LESS THAN 0.5 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML= 22.4 	 1
# None FACTOR VIII INHIBITOR LEVEL IN BETHESDA UNITS= 1.0 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML=54 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML = 30.4 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML = 57.6 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML= 3.4 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML = 1.0 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML = 7.2 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS = 3.4 	 1
# None FACTOR VIII INHIBITOR IN BETHESDA UNITS/ML=14 	 1
#
# LAB : 51262
# Count  150
# None OCCASIONAL 	 95
# None 1+ 	 40
# None NORMAL 	 9
# None 2+ 	 6
#
# LAB : 51177
# Count  59
# None DONE 	 52
# None D 	 7
#
# LAB : 50974
# Count  506
# ng/mL 0.1 	 42
# ng/mL <0.1 	 35
# ng/mL 0.3 	 19
# ng/mL 0.4 	 19
# ng/mL 0.2 	 19
# ng/mL 0.5 	 18
# ng/mL 0.6 	 16
# ng/mL 0.7 	 15
# ng/mL 1.2 	 15
# ng/mL 1.1 	 15
# ng/mL 0.8 	 13
# ng/mL 1.0 	 13
# ng/mL 1.3 	 11
# ng/mL 0.9 	 8
# ug/L <0.3 	 8
# ng/mL 2.5 	 7
# ng/mL 1.5 	 6
# ng/mL LESS THAN 0.1 	 6
# ng/mL 6.0 	 5
# ng/mL 2.0 	 5
#
# LAB : 50992
# Count  67
# IU/mL LESS THAN 10 	 28
# IU/mL 14 	 5
# IU/mL GREATER THAN 1000 	 3
# IU/mL 17 	 2
# IU/mL 16 	 2
# IU/mL 13 	 2
# IU/mL 11 	 2
# IU/mL 23 	 1
# IU/mL 39 	 1
# IU/mL 22 	 1
# IU/mL 15 	 1
# IU/mL 24 	 1
# IU/mL 255 	 1
# IU/mL 19 	 1
# IU/mL 30 	 1
# IU/mL 11.3 	 1
# IU/mL 21 	 1
# IU/mL 18 	 1
# IU/mL 294 	 1
# IU/mL 122 	 1
#
# LAB : 51062
# Count  51
# mEq/L 68 	 3
# mEq/L 85 	 2
# mEq/L 75 	 2
# mEq/L 40 	 2
# mEq/L 89 	 2
# mEq/L 105 	 2
# mEq/L LESS THAN 45 	 2
# mEq/L 95 	 2
# mEq/L 77 	 2
# mEq/L 56 	 2
# mEq/L 98 	 1
# mEq/L 128 	 1
# mEq/L 132 	 1
# mEq/L 70 	 1
# mEq/L 87 	 1
# mEq/L 48 	 1
# mEq/L 130 	 1
# mEq/L 30 	 1
# mEq/L 41 	 1
# mEq/L 31 	 1
#
# LAB : 51211
# Count  8
# % NORMAL 	 8
#
# LAB : 51461
# Count  17
# None FEW 	 6
# None MANY 	 5
# None MOD 	 4
# None NONE 	 1
# None OCC 	 1
#
# LAB : 51264
# Count  395
# None 1+ 	 394
# None 8 	 1
#
# LAB : 51340
# Count  128
# None DONE 	 102
# None D 	 26
#
# LAB : 51196
# Count  3579
# ng/mL >2000 	 330
# ng/mL <500 	 271
# ng/mL 500-1000 	 264
# ng/mL 1000-2000 	 234
# None None 	 199
# ng/mL >10000 	 88
# ng/mL 10000 	 14
# ng/mL GREATER THAN 10000 	 6
# ng/mL GREATER THAN 10,000 	 6
# ng/mL 1427 	 5
# ng/mL 1246 	 4
# ng/mL 1318 	 4
# ng/mL 1682 	 3
# ng/mL 277 	 3
# ng/mL 1162 	 3
# ng/mL 1903 	 3
# ng/mL 3258 	 3
# ng/mL 756 	 3
# ng/mL 750 	 3
# ng/mL 1956 	 3
#
# LAB : 50925
# Count  4981
# ng/mL GREATER THAN 20 NG/ML 	 310
# ng/mL GREATER THAN 20 	 224
# ng/mL GREATER THAN 20.0 	 116
# ng/mL 10.3 	 59
# ng/mL 11.9 	 47
# ng/mL 9.9 	 45
# ng/mL 9.3 	 44
# ng/mL 10.4 	 43
# ng/mL 10.9 	 43
# ng/mL 10.5 	 42
# ng/mL 9.1 	 42
# ng/mL 8.6 	 42
# ng/mL 7.1 	 42
# ng/mL 11.8 	 42
# ng/mL 9.4 	 41
# ng/mL 11.6 	 41
# ng/mL 8.4 	 40
# ng/mL 8.0 	 40
# ng/mL 9.8 	 40
# ng/mL 10.2 	 40
#
# LAB : 51305
# Count  75
# None DONE 	 62
# None D 	 13
#
# LAB : 51190
# Count  23
# None DONE 	 14
# None D 	 9
#
# LAB : 51503
# Count  202
# None MOD 	 54
# None MANY 	 52
# None FEW 	 48
# None OCC 	 29
# None RARE 	 19
#
# LAB : 51310
# Count  73
# None DONE 	 63
# None D 	 10
#
# LAB : 51296
# Count  5336
# None OCCASIONAL 	 3624
# None 1+ 	 1543
# None 2+ 	 148
# None NORMAL 	 18
# None 3+ 	 3
#
# LAB : 51096
# Count  18
# +/- NEGATIVE 	 16
# +/- PRESUMPTIVELY POSITIVE FOR PORPHOBILINOGEN 	 2
#
# LAB : 50915
# Count  978
# ng/mL GREATER THAN 21000 	 38
# ng/mL <150 	 12
# ng/mL >21000 	 6
# ng/mL >21,000 	 4
# ng/mL 671 	 3
# ng/mL 210 	 3
# ng/mL 177 	 2
# ng/mL 3012 	 2
# ng/mL 8098 	 2
# ng/mL 630 	 2
# ng/mL 1020 	 2
# ng/mL 2898 	 2
# ng/mL 1157 	 2
# ng/mL 510 	 2
# ng/mL 338 	 2
# ng/mL 3053 	 2
# ng/mL 1666 	 2
# ng/mL 1960 	 2
# ng/mL 5879 	 2
# ng/mL 417 	 2
#
# LAB : 51401
# Count  5
# None DONE 	 5
#
# LAB : 51328
# Count  53
# None DONE 	 47
# None D 	 6
#
# LAB : 51469
# Count  825
# None FEW 	 266
# None OCC 	 234
# None RARE 	 211
# None MOD 	 76
# None MANY 	 36
# None NONE 	 2
#
# LAB : 51142
# Count  7
# None NORMAL 	 5
# None ABNORMAL 	 2
#
# LAB : 51061
# Count  37
# mEq/L LESS THAN 5 	 6
# mEq/L <5 	 4
# mEq/L 5 	 3
# mEq/L 6 	 3
# mEq/L 8 	 2
# mEq/L 12 	 1
# mEq/L 7 	 1
# mEq/L 17 	 1
# mEq/L 66 	 1
# mEq/L 9 	 1
# mEq/L 17.0 	 1
# mEq/L 41 	 1
# mEq/L 16 	 1
# mEq/L 14 	 1
# mEq/L 32 	 1
# mEq/L 22 	 1
# mEq/L 44 	 1
# mEq/L 65 	 1
# mEq/L 37 	 1
# mEq/L 36 	 1
#
# LAB : 51134
# Count  1819
# None OCCASIONAL 	 943
# None 1+ 	 650
# None 2+ 	 185
# None 3+ 	 26
# None NORMAL 	 15
#
# LAB : 51235
# Count  123
# None NEG 	 87
# None POS 	 23
# None BORDERLINE 	 6
# None INDETERMINATE 	 2
# None POSTIVE FOR PT 	 1
# None BORDERLINE POSITIVE 	 1
# None BORDERLINE WITH INITIAL CORRECTION 	 1
# None BORDERLINE INHIBITOR SCREEN RESULTS 	 1
# None MIXING STUDY CORRECTS INITIALLY 	 1
#
# LAB : 51317
# Count  75
# None DONE 	 58
# None D 	 17
#
# LAB : 51313
# Count  142
# None DONE 	 113
# None D 	 29
#
# LAB : 50918
# Count  120
# U/mL NEGATIVE 	 112
# U/mL POSITIVE 	 6
# U/mL POSITIVE AT A TITER OF 1:640 	 1
# U/mL POSITIVE AT A TITER OF 1:10 	 1
#
# LAB : 51398
# Count  449
# None DONE 	 330
# None D 	 73
# None 14.3 	 2
# None 16.0 	 2
# None 16.5 	 2
# None 15 	 1
# None 26.5 	 1
# None 12.9 	 1
# None 13.89 	 1
# None 13.7 	 1
# None 16 	 1
# None 11.5 	 1
# None 12.2 	 1
# None 14 	 1
# None 18.0 	 1
# None 11.1 	 1
# None 21 	 1
# None 18.8 	 1
# None 16.8 	 1
# None 21.2 	 1
#
# LAB : 51341
# Count  128
# None DONE 	 102
# None D 	 26
#
# LAB : 51137
# Count  37485
# None 1+ 	 16127
# None NORMAL 	 10211
# None 2+ 	 8179
# None 3+ 	 1531
# None OCCASIONAL 	 1435
# None 1 	 2
#
# LAB : 51476
# Count  59809
# #/hpf 0 	 25927
# #/hpf 0-2 	 15611
# #/hpf <1 	 7242
# #/hpf 1 	 3225
# #/hpf 3-5 	 3179
# #/hpf 2 	 1117
# #/hpf 6-10 	 877
# #/hpf 3 	 575
# #/hpf 11-20 	 341
# #/hpf 4 	 307
# #/hpf 5 	 237
# #/hpf 6 	 161
# #/hpf 7 	 108
# #/hpf 21-50 	 105
# #/hpf 8 	 82
# #/hpf NOTDONE 	 76
# #/hpf >50 	 69
# #/hpf 10 	 62
# #/hpf 9 	 54
# #/hpf <1 /HPF 	 45
#
# LAB : 51201
# Count  7
# None NORMAL 	 4
# None ABNORMAL 	 3
#
# LAB : 51508
# Count  66589
# None Yellow 	 37291
# None Straw 	 15399
# None Amber 	 6622
# None LtAmb 	 2023
# None YELLOW 	 1422
# None Red 	 921
# None DkAmb 	 497
# None Orange 	 495
# None Brown 	 410
# None AMBER 	 350
# None STRAW 	 292
# None RED 	 148
# None Pink 	 120
# None DKAMB 	 98
# None ORANGE 	 77
# None BROWN 	 69
# None None 	 64
# None Green 	 40
# None Other 	 29
# None PINK 	 28
#
# LAB : 51261
# Count  743
# None 1+ 	 358
# None OCCASIONAL 	 247
# None 2+ 	 119
# None 3+ 	 14
# None NORMAL 	 5
#
# LAB : 51191
# Count  51
# None DONE 	 46
# None D 	 5
#
# LAB : 51501
# Count  3650
# #/hpf 0-2 	 1420
# #/hpf <1 	 707
# #/hpf 1 	 582
# #/hpf 3-5 	 482
# #/hpf 2 	 145
# #/hpf 6-10 	 116
# #/hpf 3 	 49
# #/hpf 11-20 	 30
# #/hpf 5 	 21
# #/hpf 4 	 15
# #/hpf 7 	 12
# #/hpf <1 /HPF 	 12
# #/hpf 21-50 	 12
# #/hpf 6 	 8
# #/hpf 8 	 6
# #/hpf >50 	 3
# #/hpf 18 	 3
# #/hpf 50 	 3
# #/hpf 9 	 3
# #/hpf 16 	 3
#
# LAB : 51322
# Count  2
# None DONE 	 2
#
# LAB : 50872
# Count  538
# None NEGATIVE BY INDIRECT IMMUNOFLUORESCENCE 	 422
# None NEGATIVE 	 80
# None POSITIVE 	 22
# None WEAKLY POSITIVE 	 4
# None None 	 2
# None BORDERLINE POSITIVE 	 2
# None NEGATIVE - Level less than 10 miu/ml 	 1
# None POSITIVE C-ANCA PATTERN 	 1
# None POSITIVE BY INDIRECT IMMUNOFLUORESCENCE 	 1
# None POSITIVE FOR C-ANCA BY INDIRECT IMMUNOFLUORESCENCE 	 1
# None BY INDIRECT IMMUNOFLUORESCENCE 	 1
# None NEGATIVE BY INIDRECT IMMUNOFLUORESCENCE 	 1
#
# LAB : 50857
# Count  1012
# None NEGATIVE 	 390
# None SMALL 	 160
# None LARGE 	 149
# None NEG 	 112
# None MODERATE 	 97
# None TRACE 	 64
# None POS 	 11
# None POSITIVE 	 4
# None ABSENT 	 3
# None UNABLE TO PERFORM TEST DUE TO HEMOLYSIS 	 3
# None ACETONE NOT DONE DUE TO INTERFERENCE OF HEMOLYSIS 	 3
# None NOT DONE 	 2
# None TEST NOT PERFORMED DUE TO HEMOLYSIS 	 2
# None NOT DONE DUE TO INTERFERENCE OF HEMOLYSIS 	 2
# None ACETONE NOT DONE, DUE TO PRESENCE OF HEMOLYSIS 	 1
# None 331 	 1
# None SAMPLE IS TOO OLD 	 1
# None TEST CANCELLED BY LAB DUE TO HEMOLYSIS 	 1
# None CAN NOT BE DONE DUE TO INTERFERENCE OF HEMOLYSIS 	 1
# None ACETONE NOT DONE DUE TO THE INTERFERENCE OF HEMOLYSIS 	 1
#
# LAB : 50980
# Count  476
# IU/mL 9 	 44
# IU/mL 8 	 36
# IU/mL 10 	 34
# IU/mL 7 	 30
# I.U. NEG 	 27
# IU/mL <3 	 26
# IU/mL 11 	 23
# IU/mL 15 	 20
# IU/mL 6 	 19
# IU/mL 12 	 18
# IU/mL 13 	 17
# IU/mL 14 	 17
# IU/mL 4 	 13
# IU/mL 17 	 12
# IU/mL 3 	 11
# IU/mL 16 	 10
# IU/mL 5 	 10
# IU/mL 18 	 8
# IU/mL 21 	 7
# IU/mL 19 	 7
#
# LAB : 51195
# Count  7
# None NORMAL 	 6
# None ABNORMAL 	 1
#
# LAB : 51395
# Count  22
# None DONE 	 20
# None D 	 2
#
# LAB : 51505
# Count  896
# None FEW 	 275
# None MOD 	 202
# None MANY 	 181
# None OCC 	 131
# None RARE 	 105
# None NONE 	 1
# None ,OD 	 1
#
# LAB : 51151
# Count  7083
# None 1+ 	 3088
# None OCCASIONAL 	 2572
# None 2+ 	 1213
# None 3+ 	 194
# None NORMAL 	 16
#
# LAB : 51485
# Count  2
# None FEW 	 1
# None RARE 	 1
#
# LAB : 50911
# Count  89879
# ng/mL NotDone 	 23833
# ng/mL 3 	 9027
# ng/mL 2 	 7723
# ng/mL 4 	 7253
# ng/mL 5 	 5255
# ng/mL 6 	 4094
# ng/mL 7 	 3088
# ng/mL 8 	 2511
# ng/mL 1 	 2298
# ng/mL 9 	 1928
# ng/mL 10 	 1610
# ng/mL 11 	 1312
# ng/mL 12 	 1196
# ng/mL 13 	 985
# ng/mL 14 	 910
# ng/mL 15 	 787
# ng/mL 16 	 651
# ng/mL 17 	 646
# ng/mL 18 	 561
# ng/mL None 	 515
#
# LAB : 51424
# Count  401
# None DONE 	 303
# None D 	 84
# None CANCEL 	 13
# None NOT DONE 	 1
#
# LAB : 51423
# Count  225
# None DONE 	 192
# None D 	 33
#
# LAB : 50979
# Count  11033
# None HOLD 	 11023
# None DONE 	 8
# None DONE-NC 	 1
# None DISCARDED 	 1
#
# LAB : 51150
# Count  404
# None NEGATIVE 	 184
# None NEG 	 96
# None POSITIVE 	 57
# None POS 	 25
# None NEGATIVE THIN AND THICK SMEAR REVIEWED 	 3
# None NEGATIVE THICK SMEAR 	 3
# None THICK SMEAR NEGATIVE 	 2
# None NEG FOR THICK SMEAR 	 2
# None NEGATIVE FOR INTRA OR EXTRACELLULAR FORMS 	 2
# None NEGATIVE FOR THICK AND THIN SMEARS 	 2
# None NEGATIVE FOR INTRA AND EXTRACELLULAR FORMS PENDING REVIEW OF THICK SMEARS 	 1
# None 0.1PARASITEMIA 	 1
# None 12.5% PARASITIMIA BABESIA SPECIES REVIEWED BY QUIN,QINFANG,MD 	 1
# None 12.7% 	 1
# None 1.4% PARASITEMIA 	 1
# None THICK SMEAR REVIEWED 	 1
# None NEGATIVE THICK AND THIN SMEAR 	 1
# None NEGATIVE FOR INTRA AND EXTRA CELLULAR PARASITES 	 1
# None 30% PARASITEMIA 	 1
# None NEGATIVE THICK SMEAR REVIEW 	 1
#
# LAB : 51418
# Count  50
# None DONE 	 42
# None D 	 7
# None 22 	 1
#
# LAB : 50859
# Count  1
# IU/L SEE COMPLETE REPORT IN OUTSIDE LAB SYSTEM 	 1
#
# LAB : 50941
# Count  2292
# None NEGATIVE 	 2246
# None POSITIVE 	 46
#
# LAB : 51038
# Count  27
# None ANA IS POSITIVE 	 2
# None RF= 7 MG/DL 	 1
# None GREATER THAN 100 UG/ML 	 1
# None VANCOMYCIN = 8.3 	 1
# None LITHIUM LEVEL = 1.7 MMOL/L 	 1
# None VANCOMYCIN = 10.7 	 1
# None LIPASE = 9 	 1
# None RF= 6MG/DL 	 1
# None METHOTREXATE = 97 UMOL/L 	 1
# None LIPASE = 190 	 1
# None LIPASE=1320 	 1
# None VANCOMYCIN = 10.9 	 1
# None LIPASE = 22250 MG/DL 	 1
# None 216 	 1
# None 107 	 1
# None HOLD 	 1
# None 5130 	 1
# None CEA = 5604 NG/ML 	 1
# None LIPASE=9 	 1
# None GENTA =0.8 	 1
#
# LAB : 50940
# Count  2278
# None NEGATIVE 	 1233
# None POSITIVE 	 859
# None BORDERLINE POSITIVE -- C/W TITER OF ROUGHLY 10 MIU/ML 	 57
# None BORDERLINE POSITIVE 	 33
# None POSITIVE,TITER IS GREATER THAN 450 MIU/ML 	 17
# None POSITIVE,TITER IS >450 MIU/ML 	 14
# None POSITIVE, TITER IS >450 MIU/ML 	 9
# None POSITIVE, TITER IS GREATER THAN 450 MIU/ML 	 7
# None POSITIVE TITER IS > 450 MIU/ML 	 6
# None POSITIVE TITER IS >450 MIU/ML 	 5
# None POSITIVE TITER IS GREATER THAN 450 MIU/ML 	 4
# None POSITIVE, TITER IS BETWEEN 100 AND 450 MIU/ML 	 3
# None POSITIVE,TITER IS GREATER THAN 450/MIU/ML 	 3
# None POSITIVE,TITER IS > 450 MIU/ML 	 3
# None POSITIVE, TITER IS BETWEEN 100 AND 450MIU/ML 	 2
# None POSITIVE - TITER IS GREATER THAN 450 MIU/ML 	 2
# None POSITIVE,POSITIVE TITER IS GREATER THAN 450 	 1
# None POSITIVE,TITER GREATER THAN 450 MIU/ML 	 1
# None NEGATIVE - Level less than 10 miu/ml 	 1
# None POSITIVE,TITER IS GREATER THAN 450MIU/ML 	 1
#
# LAB : 51388
# Count  253
# None DONE 	 215
# None D 	 38
#
# LAB : 51167
# Count  111
# None DONE 	 94
# None D 	 17
#
# LAB : 51083
# Count  7
# None NEG 	 4
# None NEGATIVE 	 2
# None 217 	 1
#
# LAB : 50875
# Count  7
# None NEGATIVE 	 7
#
# LAB : 51397
# Count  24
# None DONE 	 19
# None D 	 5
#
# LAB : 51243
# Count  374
# None NEG 	 311
# None POS 	 62
# None LUPUS NOT DONE 	 1
#
# LAB : 51198
# Count  309
# None OCCASIONAL 	 181
# None 1+ 	 90
# None 2+ 	 33
# None NORMAL 	 5
#
# LAB : 51389
# Count  2
# None DONE 	 2
#
# LAB : 51153
# Count  4
# None D 	 2
# None DONE 	 2
#
# LAB : 51160
# Count  30
# None DONE 	 27
# None D 	 2
# None 79 	 1
#
# LAB : 51374
# Count  156
# None NEEDLE 	 126
# None RHOMBOID 	 26
# None ROD 	 4
#
# LAB : 50961
# Count  193
# umol/L 0.04 	 18
# umol/L LESS THAN 0.02 	 13
# umol/L 0.02 	 9
# umol/L 0.05 	 8
# umol/L 0.03 	 7
# umol/L 0.07 	 7
# umol/L 0.11 	 6
# umol/L 0.08 	 6
# umol/L 0.13 	 5
# umol/L 0.06 	 5
# umol/L LESS THAN 0.1 	 4
# umol/L 1.7 	 3
# umol/L 0.12 	 3
# umol/L 0.15 	 3
# umol/L 0.10 	 3
# umol/L 0.17 	 3
# umol/L 0.20 	 3
# umol/L 0.29 	 3
# umol/L 0.14 	 3
# umol/L 0.33 	 2
#
# LAB : 50812
# Count  161016
# None INTUBATED 	 129927
# None NOT INTUBATED 	 31089
#
# LAB : 51217
# Count  49
# None DONE 	 43
# None D 	 6
#
# LAB : 51464
# Count  65911
# EU/dL NEG 	 34700
# mg/dL NEG 	 22325
# EU/dL SM 	 3613
# mg/dL SM 	 2762
# mg/dL MOD 	 697
# EU/dL MOD 	 688
# EU/dL LG 	 581
# mg/dL LG 	 513
# mg/dL   	 16
# EU/dL Neg 	 4
# None NEG 	 4
# EU/dL COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# EU/dL N 	 2
# mg/dL M 	 1
# mg/dL BEH 	 1
# EU/dL   	 1
# EU/dL Specimen 	 1
#
# LAB : 50975
# Count  1089
# None NO SPECIFIC ABNORMALITIES SEEN 	 737
# None POLYCLONAL HYPERGAMMAGLOBULINEMIA 	 94
# None HYPOGAMMAGLOBULINEMIA 	 90
# None ABNORMAL BAND IN GAMMA REGION 	 81
# None TRACE ABNORMAL BAND IN GAMMA REGION 	 14
# None SLIGHT HYPOGAMMAGLOBULINEMIA 	 4
# None TWO ABNORMAL BANDS IN GAMMA REGION 	 4
# None TRACE BAND SEEN IN GAMMA REGION 	 3
# None ABNORMAL BAND IN FAST GAMMA REGION 	 3
# None TWO TRACE BANDS IN GAMMA REGION 	 2
# None TWO LOW CONCENTRATION BANDS SEEN IN GAMMA REGION 	 2
# None TWO TRACE ABNORMAL BANDS IN GAMMA REGION 	 2
# None TRACE BAND IN GAMMA REGION 	 2
# None MULTIPLE BANDS IN GAMMA REGION 	 2
# None THICKENED ALPHA-2 BAND 	 2
# None TRACE ABNORMAL BAND IN FAST GAMMA REGION 	 2
# None SLIGHT HYPOGAMMAGLOBINEMIA NOTED 	 2
# None BROAD-BASED ABNORMAL BAND IN GAMMA REGION 	 1
# None OLIGOCLONAL/POLYCLONAL HYPERGAMMAGLOBULINEMIA 	 1
# None MULTIPLE LOW CONCENTRATION BANDS SEEN IN GAMMA REGION 	 1
#
# LAB : 51338
# Count  178
# None DONE 	 138
# None D 	 36
# None CANCEL 	 4
#
# LAB : 51514
# Count  68043
# mg/dL NEG 	 33764
# EU/dL NEG 	 14520
# EU/dL 0.2 	 5009
# mg/dL 1 	 2802
# mg/dL 4 	 2375
# EU/dL 1 	 2071
# mg/dL 2 	 1988
# mg/dL 0.2 	 1951
# EU/dL 4 	 954
# mg/dL 8 	 899
# EU/dL .2 	 647
# mg/dL 12 	 322
# EU/dL 8 	 296
# EU/dL 2 	 156
# EU/dL 12 	 147
# EU/dL >8 	 42
# mg/dL >8 	 34
# mg/dL >12 	 19
# mg/dL   	 16
# EU/dL NotDone 	 15
#
# LAB : 51320
# Count  67
# None DONE 	 57
# None D 	 10
#
# LAB : 51415
# Count  20
# None DONE 	 17
# None D 	 3
#
# LAB : 51369
# Count  54
# % 3.5 	 4
# % 2.5 	 4
# % 6 	 3
# % 5 	 2
# % 4.0 	 2
# % 0 	 2
# % 2.0 	 2
# % 12.0 	 2
# % <2.0 	 2
# % 9.0 	 1
# % 41.0 	 1
# % 30 	 1
# % 22.5 	 1
# % 16 	 1
# % 17 	 1
# % 7 	 1
# % LESS THAN 2.0% 	 1
# % 6.5 	 1
# % 25.5 	 1
# % 14.4 	 1
#
# LAB : 51417
# Count  10
# None DONE 	 10
#
# LAB : 51483
# Count  1
# None MANY 	 1
#
# LAB : 50944
# Count  873
# None NEGATIVE 	 840
# None POSITIVE 	 22
# None NEGATIVE FOR HIV-1 BY TRINITY RAPID HIV METHOD 	 3
# None COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 1
# None CALL 667-LABS FOR MORE INFORMATION 	 1
# None NEGATIVE FOR HIV 1 ANTIBODIES 	 1
# None NEGATIVE FOR HIV-1 ANTIBODY 	 1
# None CONFIRMED BY WESTERN BLOT AT QUEST DIAGNOSTICS 	 1
# None NEG 	 1
# None INDETERMINATE 	 1
# None NEGATIVE FOR HIV 1 BY RAPID TRINITY UNIGOLD METHOD 	 1
#
# LAB : 51290
# Count  10
# None POS 	 8
# None NEG 	 2
#
# LAB : 51390
# Count  22
# None DONE 	 18
# None D 	 4
#
# LAB : 50845
# Count  7
# None BUN=37 MG/DL 	 1
# None LIPASE = 5 IU/L 	 1
# None ALK PHOS = <3 	 1
# None ALKP = 75 	 1
# None LIPASE=5 MG/DL 	 1
# None BUN=36 MG/DL 	 1
# None LIPASE =34595 IU/ML 	 1
#
# LAB : 51017
# Count  108
# None NO OLIGOCLONAL BANDING SEEN 	 91
# None OLIGOCLONAL BANDING SEEN 	 2
# None TWO LOW CONCENTRATION BANDS SEEN IN CSF 	 1
# None SINGLE BAND SEEN IN GAMMA REGION 	 1
# None 1-2 TRACE BANDS SEEN 	 1
# None NO BETA-2 TRANSFERRIN BAND DETECTED 	 1
# None THE PATIENT'S KNOWN MONOCLONAL IGG KAPPA IS DETECTED IN THE CSF 	 1
# None SINGLE ABNORMAL BAND IN GAMMA REGION 	 1
# None OLIGOCLONAL BANDING IS PRESENT IN THE CSF 	 1
# None DONE ON EAR FLUID 	 1
# None ONE STRONG BAND SEEN IN GAMMA REGION 	 1
# None 3-5 BANDS IN GAMMA REGION 	 1
# None SINGLE PROMINENT BAND SEEN IN GAMMA REGION 	 1
# None A SINGLE ABNORMAL BAND IS PRESENT 	 1
# None HEMOLYZED SPECIMEN 	 1
# None BORDERLINE POSITIVE 	 1
# None OLIGOCLONAL BANDS ARE SEEN 	 1
#
# LAB : 51267
# Count  35634
# None NORMAL 	 15769
# None 1+ 	 12597
# None OCCASIONAL 	 3295
# None 2+ 	 3234
# None 3+ 	 737
# None 1 	 2
#
# LAB : 51471
# Count  129
# #/lpf 1 	 45
# #/lpf 2 	 21
# #/lpf 0-2 	 19
# #/lpf 3 	 8
# #/lpf <1 	 6
# #/lpf 8 	 5
# #/lpf 5 	 5
# #/lpf 6 	 4
# #/lpf 9 	 2
# #/lpf 3-5 	 2
# #/lpf 10 	 2
# #/lpf 14 	 2
# #/lpf 0 	 1
# #/lpf 12 	 1
# #/lpf 68 	 1
# #/lpf 16 	 1
# #/lpf 13 	 1
# #/lpf 21 	 1
# #/lpf 4 	 1
# #/lpf 158 	 1
#
# LAB : 51203
# Count  38
# % 66 	 2
# % 30 	 2
# % 89 	 2
# % 100 	 2
# % 77 	 1
# % 60 	 1
# % 149 	 1
# % 36 	 1
# % 95 	 1
# % 169 	 1
# % 61 	 1
# % 87 	 1
# % 129 	 1
# % 41 	 1
# % 173 	 1
# % 120 	 1
# % LESS THAN 1.7% ACTIVITY 	 1
# % 1.5 	 1
# % 110 	 1
# % 97 	 1
#
# LAB : 51484
# Count  67847
# mg/dL NEG 	 49136
# mg/dL TR 	 9581
# mg/dL 15 	 3406
# mg/dL 50 	 1528
# mg/dL 10 	 1517
# mg/dL 150 	 1383
# mg/dL 40 	 894
# mg/dL 80 	 213
# mg/dL >80 	 156
# mg/dL   	 19
# mg/dL Neg 	 4
# None NEG 	 4
# mg/dL Tr 	 2
# mg/dL COMPUTER NETWORK FAILURE. TEST NOT RESULTED. 	 2
# mg/dL N 	 1
# mg/dL T 	 1
#
# LAB : 51475
# Count  2
# #/lpf <1 	 2
#
# LAB : 50837
# Count  39
# mEq/L 20 	 4
# mEq/L 29 	 3
# mEq/L 18 	 3
# mEq/L 22 	 3
# mEq/L LESS THAN 5 	 2
# mEq/L 21 	 2
# mEq/L 16 	 2
# mEq/L 19 	 2
# mEq/L 13 	 2
# mEq/L 23 	 2
# mEq/L 24 	 2
# mEq/L 27 	 2
# mEq/L 26 	 1
# mEq/L 10 	 1
# mEq/L LESS THAN 10 	 1
# mEq/L 25 	 1
# mEq/L 9 	 1
# mEq/L 14 	 1
# mEq/L 8 	 1
# mEq/L 15 	 1
#
# LAB : 51213
# Count  4821
# ug/mL 10-40 	 2052
# ug/mL 0-10 	 1051
# ug/mL 40-80 	 751
# ug/mL 80-160 	 453
# ug/mL 160-320 	 262
# ug/mL 320-640 	 125
# ug/mL 640-1280 	 71
# ug/mL >1280 	 55
# ug/mL None 	 1
#
# LAB : 51494
# Count  46
# #/lpf 0-2 	 17
# #/lpf <1 	 16
# #/lpf 3 	 5
# #/lpf 1 	 3
# #/lpf 3-5 	 2
# #/lpf 13 	 1
# #/lpf 5 	 1
# #/lpf 127 	 1
#
# LAB : 50876
# Count  246
# None NEGATIVE 	 163
# None POSITIVE 	 76
# None POSITIVE AT A TITER OF 1:20 	 3
# None POSITIVE AT A TITER OF 1:320 	 1
# None POSITIVE AT A TITER OF 1:40 	 1
# None POSITIVE - TITER 1:20 	 1
# None POSITIVE -- C/W TITER OF MORE THAN 100 MIU/ML 	 1
#
# LAB : 50858
# Count  1
# IU/L SEE COMPLETE REPORT IN OUTSIDE LAB SYSTEM 	 1
#
# LAB : 51246
# Count  37309
# None NORMAL 	 15573
# None 1+ 	 9418
# None 2+ 	 6231
# None 3+ 	 4376
# None OCCASIONAL 	 1711
#
# LAB : 51087
# Count  27946
# None RANDOM 	 27267
# None 24 	 648
# None 12 	 14
# None 2 	 4
# None 6 	 3
# None 4 	 2
# None 8 	 2
# None 14 	 1
# None 48 	 1
# None 9 	 1
# None UNKNOWN 	 1
# None SPECIMEN RECEIVED UNLABELED 	 1
# None 60 	 1
#
# LAB : 51336
# Count  45
# None DONE 	 38
# None D 	 7
#
# LAB : 50887
# Count  10863
# None HOLD 	 10862
# None DONE 	 1
#
# LAB : 51409
# Count  4
# None None 	 1
# None 1.5 	 1
# None 1.2 	 1
# None DONE 	 1
#
# LAB : 51510
# Count  103
# None RARE 	 41
# None OCC 	 20
# None MANY 	 15
# None FEW 	 11
# None MOD 	 5
# None NONE 	 4
# None   	 3
# None SODIUM URATES RARE 	 1
# None 0CC 	 1
# None OCC  	 1
# None 0 	 1
#
# LAB : 51141
# Count  2
# None NEGATIVE 	 2
#
# LAB : 51324
# Count  55
# None DONE 	 46
# None D 	 9
#
# LAB : 51497
# Count  1508
# #/hpf 0-2 	 765
# #/hpf <1 	 318
# #/hpf 3-5 	 227
# #/hpf 1 	 73
# #/hpf 6-10 	 49
# #/hpf 2 	 24
# #/hpf 3 	 11
# #/hpf 11-20 	 9
# #/hpf 5 	 4
# #/hpf 4 	 4
# #/hpf 21-50 	 4
# #/hpf <1 /HPF 	 2
# #/hpf 9 	 2
# #/hpf >50 	 2
# #/hpf 13 	 2
# #/hpf 552 	 1
# #/hpf 88 	 1
# #/hpf 10 	 1
# #/hpf 12 	 1
# #/hpf 1584 	 1
#
# LAB : 51145
# Count  2759
# None OCCASIONAL 	 1721
# None 1+ 	 928
# None 2+ 	 91
# None NORMAL 	 14
# None 3+ 	 5
#
# LAB : 51410
# Count  10
# None DONE 	 9
# None D 	 1
#
# LAB : 51016
# Count  12
# None CEA = LESS THAN 1.0 NG/ML 	 2
# None CEA = <1.0NG/ML 	 1
# None HCG=<5 	 1
# None AFP LESS THAN 1.0 	 1
# None AMYLASE = 1 IU/L 	 1
# None VANCOMYCIN = 2.6 	 1
# None CEA LESS THAN 1.0 	 1
# None 1.6 	 1
# None BETE-2 MICROGLOBULIN = 3.1MG/L 	 1
# None CEA=26 	 1
# None CA125 = 1.3 	 1
#
# LAB : 51089
# Count  91
# None NEGATIVE 	 50
# None NEG 	 34
# None POSITIVE 	 3
# None POS 	 2
# None PRESUMPTIVELY POSITIVE 	 1
# None INVALID 	 1

# %%
dropped_value = np.load('res/lab_dropped_value.npy').tolist()
valid_lab_num = []
valid_lab_num_unit = []
valid_lab_cate = []
valid_lab_ratio = []
for d, droped_outs in dropped_value:
    ascnum = 0
    rationum = 0
    for value, valueuom, count in droped_outs:
        value = str(value)
        isasc = re.search(r'(\d+\.\d*)|(\d*\.\d+)|(\d+)', value) is None
        isratio = re.fullmatch(r'{0}\/{0}'.format(r'((\d+\.\d*)|(\d*\.\d+)|(\d+))'), value) is not None
        if isasc:
            ascnum += 1
        if isratio:
            rationum += 1
    if ascnum / len(droped_outs) >= 0.5:
        valid_lab_cate.append(d)
    elif rationum / len(droped_outs) >= 0.5:
        valid_lab_ratio.append(d)
        print(droped_outs)
    else:
        valid_lab_num.append(d)
        if droped_outs[0][1] is None:
            valid_lab_num_unit.append('')
        else:
            valid_lab_num_unit.append(droped_outs[0][1])
#         print(droped_outs)
        
print(len(valid_lab_num), len(valid_lab_cate), len(valid_lab_ratio))
# print(valid_lab_num, valid_lab_num_unit)
# Out:
# [('/20', None, 3081), ('20/', None, 2683), ('14/', None, 2645), ('8/', None, 2571), ('16/', None, 2365), ('12/', None, 2296), ('18/', None, 2284), ('/18', None, 2059), ('/22', None, 1984), ('/24', None, 1950), ('/16', None, 1916), ('/12', None, 1735), ('/14', None, 1685), ('22/', None, 1499), ('24/', None, 1456), ('/30', None, 1332), ('/28', None, 1276), ('/10', None, 1270), ('10/', None, 1216), ('/25', None, 1123), ('30/', None, 1111), ('/26', None, 1072), ('26/', None, 1056), ('/15', None, 1017), ('28/', None, 1000), ('/8', None, 913), ('/23', None, 824), ('/17', None, 802), ('/21', None, 790), ('/19', None, 679), ('25/', None, 645), ('/32', None, 552), ('15/', None, 529), ('14/0', None, 523), ('/27', None, 511), ('32/', None, 488), ('20/0', None, 480), ('16/0', None, 458), ('/13', None, 447), ('/11', None, 408), ('35/', None, 403), ('12/0', None, 399), ('18/0', None, 381), ('34/', None, 329), ('/40', None, 315), ('14/2', None, 302), ('/9', None, 300), ('24/0', None, 297), ('/29', None, 296), ('12/2', None, 280), ('22/0', None, 274), ('/36', None, 267), ('/35', None, 266), ('20/2', None, 250), ('14/4', None, 243), ('12/4', None, 238), ('/34', None, 238), ('12/12', None, 234), ('/33', None, 233), ('16/2', None, 210), ('23/', None, 199), ('16/4', None, 192), ('18/2', None, 185), ('30/0', None, 183), ('/31', None, 183), ('14/6', None, 183), ('17/', None, 183), ('14/3', None, 179), ('/7', None, 176), ('14/10', None, 174), ('14/14', None, 173), ('12/8', None, 171), ('10/2', None, 168), ('/38', None, 166), ('10/10', None, 161), ('26/0', None, 160), ('/6', None, 159), ('9/', None, 158), ('10/0', None, 156), ('12/6', None, 155), ('27/', None, 154), ('36/', None, 153), ('20/5', None, 151), ('20/4', None, 150), ('12/3', None, 150), ('20/20', None, 149), ('14/1', None, 148), ('28/0', None, 144), ('12/10', None, 139), ('13/', None, 138), ('14/5', None, 135), ('20/3', None, 133), ('22/2', None, 130), ('12/5', None, 129), ('21/', None, 128), ('12/1', None, 127), ('16/1', None, 118), ('10/4', None, 116), ('18/4', None, 109), ('16/16', None, 107), ('38/', None, 107), ('24/2', None, 103), ('20/1', None, 101), ('40/', None, 100), ('16/5', None, 99), ('19/', None, 98), ('18/1', None, 97), ('7/', None, 96), ('16/8', None, 94), ('16/10', None, 92), ('14/8', None, 90), ('16/3', None, 89), ('0/16', None, 87), ('15/0', None, 86), ('11/', None, 86), ('5/', None, 86), ('20/6', None, 86), ('10/6', None, 83), ('12/14', None, 81), ('0/20', None, 80), ('18/6', None, 80), ('16/6', None, 79), ('6/', None, 79), ('/37', None, 77), ('0/22', None, 76), ('10/5', None, 76), ('24/24', None, 76), ('20/10', None, 76), ('10/1', None, 75), ('10/8', None, 75), ('18/18', None, 74), ('14/7', None, 73), ('18/3', None, 72), ('0/12', None, 72), ('22/4', None, 71), ('32/0', None, 70), ('0/14', None, 69), ('33/', None, 69), ('12/20', None, 69), ('10/3', None, 68), ('25/0', None, 68), ('0/18', None, 68), ('10/12', None, 68), ('26/2', None, 68), ('30/30', None, 68), ('20/8', None, 68), ('12/7', None, 67), ('28/2', None, 64), ('18/5', None, 64), ('24/4', None, 63), ('22/3', None, 62), ('34/0', None, 61), ('24/1', None, 60), ('29/', None, 60), ('14/12', None, 58), ('12/15', None, 57), ('/42', None, 56), ('24/3', None, 56), ('20/7', None, 55), ('12/16', None, 54), ('/44', None, 54), ('30/2', None, 53), ('/50', None, 51), ('12/18', None, 51), ('8/8', None, 51), ('22/1', None, 49), ('14/16', None, 49), ('14/15', None, 49), ('8/0', None, 48), ('0/10', None, 47), ('0/15', None, 47), ('14/20', None, 46), ('30/3', None, 46), ('26/4', None, 46), ('/39', None, 46), ('/45', None, 45), ('35/0', None, 45), ('0/24', None, 45), ('18/10', None, 45), ('26/1', None, 43), ('/48', None, 43), ('16/12', None, 43), ('22/22', None, 43), ('24/6', None, 42), ('12/13', None, 42), ('10/7', None, 42), ('10/14', None, 41), ('14/9', None, 41), ('28/1', None, 40), ('24/5', None, 39), ('28/4', None, 39), ('10/13', None, 39), ('0/17', None, 38), ('8/12', None, 37), ('30/4', None, 37), ('28/3', None, 36), ('15/3 ...
# 113 224 1

# %%
# Here we directly do some manual selection to get the list of valid_lab_num and valid_lab_cat

# %%
print(valid_lab_cate)
# Out:
# [50800, 51183, 51506, 51337, 51307, 51486, 51502, 51306, 51075, 51462, 51426, 51518, 51155, 51468, 51157, 51466, 51327, 51236, 51407, 51230, 50942, 51234, 50939, 50829, 51286, 50901, 51331, 51405, 51372, 51092, 51309, 51304, 51315, 51519, 50937, 51085, 51412, 51425, 50854, 51192, 50959, 51156, 51487, 51293, 50932, 51416, 51314, 51463, 50886, 51411, 51332, 50880, 51393, 51154, 51161, 51413, 51421, 51414, 51342, 51182, 51318, 51396, 51330, 51333, 51074, 51189, 51187, 51238, 51090, 51537, 51323, 51329, 51178, 51477, 51499, 51179, 51465, 51321, 51473, 51500, 51215, 50938, 50879, 51420, 51173, 50999, 51400, 51325, 51312, 51091, 51258, 51373, 51474, 51247, 50955, 50933, 51239, 51071, 51079, 51408, 51158, 51470, 51350, 51523, 51278, 51520, 51220, 51339, 51490, 51512, 51460, 50873, 51391, 51511, 51135, 51308, 50871, 51370, 51171, 50920, 51316, 51172, 51394, 51086, 50828, 51399, 51193, 51335, 51098, 51402, 51303, 50948, 50855, 51311, 51392, 50919, 51319, 51326, 51403, 51219, 51334, 51242, 51159, 51295, 51152, 51266, 50943, 51147, 50913, 51103, 51495, 51504, 51481, 51472, 51262, 51177, 51211, 51461, 51340, 51305, 51190, 51503, 51310, 51096, 51401, 51328, 51469, 51142, 51235, 51317, 51313, 50918, 51341, 51201, 51508, 51191, 51322, 50872, 50857, 51195, 51395, 51505, 51485, 51424, 51423, 50979, 51150, 51418, 50859, 50941, 51388, 51167, 51083, 50875, 51397, 51243, 51198, 51389, 51153, 51160, 51374, 50812, 51217, 51464, 50975, 51338, 51320, 51415, 51417, 51483, 50944, 51290, 51390, 51017, 51484, 50858, 51336, 50887, 51409, 51510, 51141, 51324, 51410, 51089]

# %%
print(len(valid_lab_num), len(valid_lab_num_unit), len(valid_lab_cate))
np.save('res/filtered_lab_num',{'id':valid_lab_num,'unit':valid_lab_num_unit})
np.save('res/filtered_lab_cate',{'id':valid_lab_cate,'unit':None})
np.save('res/filtered_lab_ratio', {'id': valid_lab_ratio, 'unit': None})
# Out:
# 113 113 224
